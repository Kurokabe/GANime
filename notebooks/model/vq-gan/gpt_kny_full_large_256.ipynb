# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0, 1"
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
#for device in tf.config.list_physical_devices("GPU"):
#    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
#strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.ReductionToOneDevice())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/kny_video_gpt2_large_256.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
dataset_length = 789 
#dataset_length = 10000
# dataset_length = 35267
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = normalize(element)
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/kny/videos_tfrecords_full_256/01").load()
dataset = (dataset.shuffle(5000, reshuffle_each_iteration=True, seed=0)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(8)
                          .map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.padded_batch(8)
                              .map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
# take_train = [1, 8, 9, 12, 21, 25, 30, 47]
# train_sample_data = postprocess({key: value[take_train] for key, value in train_sample_data.items()})
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# take_validation = [3, 8, 13, 16, 21, 33, 56, 61]
# validation_sample_data = postprocess({key: value[take_validation] for key, value in validation_sample_data.items()})
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_images(train_sample_data["last_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)

# %%
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)

# %%
train_sample_data["n_frames"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d7de663bc4e> in <module>
# ----> 1 train_sample_data["n_frames"]
#
# NameError: name 'train_sample_data' is not defined

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = get_logdir("../../../logs/ganime/transformers", experiment_name="kny_large_256")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# All model checkpoint layers were used when initializing TFGPT2Model.
#
# Some layers of TFGPT2Model were not initialized from the model checkpoint at gpt2-large and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Restoring weights from ../../../checkpoints/kny_video_light_gpt2_large_256/checkpoint

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 1/10000
# 4/4 [==============================] - 268s 42s/step - total_loss: 2.5978 - scce_loss: 1.6415 - perceptual_loss: 0.9562
# Epoch 2/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 4.1860 - scce_loss: 1.4490 - perceptual_loss: 2.7370
# Epoch 3/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 3.3802 - scce_loss: 1.1399 - perceptual_loss: 2.2402
# Epoch 4/10000
# 4/4 [==============================] - 111s 33s/step - total_loss: 1.8886 - scce_loss: 1.1037 - perceptual_loss: 0.7849
# Epoch 5/10000
# 4/4 [==============================] - 108s 33s/step - total_loss: 1.6785 - scce_loss: 0.8814 - perceptual_loss: 0.7972
# Epoch 6/10000
# 4/4 [==============================] - 106s 32s/step - total_loss: 1.5187 - scce_loss: 0.8124 - perceptual_loss: 0.7062
# Epoch 7/10000
# 4/4 [==============================] - 107s 32s/step - total_loss: 1.0259 - scce_loss: 0.6364 - perceptual_loss: 0.3895
# Epoch 8/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1782 - scce_loss: 0.7388 - perceptual_loss: 0.4394
# Epoch 9/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.4398 - scce_loss: 0.8101 - perceptual_loss: 0.6297
# Epoch 10/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.8453 - scce_loss: 1.0490 - perceptual_loss: 0.7963
# Epoch 11/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0489 - scce_loss: 0.5973 - perceptual_loss: 0.4515
# Epoch 12/10000
# 4/4 [==============================] - 89s 27s/step - total_loss: 1.4814 - scce_loss: 0.9069 - perceptual_loss: 0.5745
# Epoch 13/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0604 - scce_loss: 0.7144 - perceptual_loss: 0.3460
# Epoch 14/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1431 - scce_loss: 0.7743 - perceptual_loss: 0.3688
# Epoch 15/10000
# 4/4 [==============================] - 106s 32s/step - total_loss: 0.9732 - scce_loss: 0.6308 - perceptual_loss: 0.3425
# Epoch 16/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.8003 - scce_loss: 1.0417 - perceptual_loss: 0.7586
# Epoch 17/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0288 - scce_loss: 0.6435 - perceptual_loss: 0.3853
# Epoch 18/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.2242 - scce_loss: 0.7425 - perceptual_loss: 0.4817
# Epoch 19/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0550 - scce_loss: 0.6022 - perceptual_loss: 0.4528
# Epoch 20/10000
# 4/4 [==============================] - 89s 27s/step - total_loss: 1.0163 - scce_loss: 0.6674 - perceptual_loss: 0.3489
# Epoch 21/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0801 - scce_loss: 0.6672 - perceptual_loss: 0.4129
# Epoch 22/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0122 - scce_loss: 0.6337 - perceptual_loss: 0.3784
# Epoch 23/10000
# 4/4 [==============================] - 107s 33s/step - total_loss: 0.8648 - scce_loss: 0.4758 - perceptual_loss: 0.3891
# Epoch 24/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.2636 - scce_loss: 0.7303 - perceptual_loss: 0.5333
# Epoch 25/10000
# 4/4 [==============================] - 89s 27s/step - total_loss: 1.2292 - scce_loss: 0.7612 - perceptual_loss: 0.4680
# Epoch 26/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2431 - scce_loss: 0.7466 - perceptual_loss: 0.4965
# Epoch 27/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2256 - scce_loss: 0.7366 - perceptual_loss: 0.4889
# Epoch 28/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0148 - scce_loss: 0.5924 - perceptual_loss: 0.4223
# Epoch 29/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2944 - scce_loss: 0.7998 - perceptual_loss: 0.4946
# Epoch 30/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.4530 - scce_loss: 0.8259 - perceptual_loss: 0.6271
# Epoch 31/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.3802 - scce_loss: 0.7044 - perceptual_loss: 0.6758
# Epoch 32/10000
# 4/4 [==============================] - 105s 32s/step - total_loss: 0.7842 - scce_loss: 0.5282 - perceptual_loss: 0.2561
# Epoch 33/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.4074 - scce_loss: 0.8519 - perceptual_loss: 0.5555
# Epoch 34/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1747 - scce_loss: 0.6019 - perceptual_loss: 0.5728
# Epoch 35/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 1.1525 - scce_loss: 0.6180 - perceptual_loss: 0.5345
# Epoch 36/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1690 - scce_loss: 0.5757 - perceptual_loss: 0.5933
# Epoch 37/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1153 - scce_loss: 0.5997 - perceptual_loss: 0.5156
# Epoch 38/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7926 - scce_loss: 0.3800 - perceptual_loss: 0.4127
# Epoch 39/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3322 - scce_loss: 0.6544 - perceptual_loss: 0.6779
# Epoch 40/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8896 - scce_loss: 0.5039 - perceptual_loss: 0.3857
# Epoch 41/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1657 - scce_loss: 0.5349 - perceptual_loss: 0.6308
# Epoch 42/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9236 - scce_loss: 0.5855 - perceptual_loss: 0.3381
# Epoch 43/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2281 - scce_loss: 0.6698 - perceptual_loss: 0.5583
# Epoch 44/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1850 - scce_loss: 0.6267 - perceptual_loss: 0.5583
# Epoch 45/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8261 - scce_loss: 0.4903 - perceptual_loss: 0.3358
# Epoch 46/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.3965 - scce_loss: 0.7695 - perceptual_loss: 0.6270
# Epoch 47/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1930 - scce_loss: 0.6143 - perceptual_loss: 0.5787
# Epoch 48/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2661 - scce_loss: 0.7508 - perceptual_loss: 0.5153
# Epoch 49/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3756 - scce_loss: 0.7569 - perceptual_loss: 0.6188
# Epoch 50/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.6399 - scce_loss: 1.0110 - perceptual_loss: 0.6289
# Epoch 51/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.2107 - scce_loss: 0.7250 - perceptual_loss: 0.4857
# Epoch 52/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9046 - scce_loss: 0.5002 - perceptual_loss: 0.4044
# Epoch 53/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0923 - scce_loss: 0.6101 - perceptual_loss: 0.4822
# Epoch 54/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.8763 - scce_loss: 0.3758 - perceptual_loss: 0.5004
# Epoch 55/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8724 - scce_loss: 0.4291 - perceptual_loss: 0.4433
# Epoch 56/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9395 - scce_loss: 0.5536 - perceptual_loss: 0.3859
# Epoch 57/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.4950 - scce_loss: 0.8883 - perceptual_loss: 0.6067
# Epoch 58/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.5872 - scce_loss: 0.9246 - perceptual_loss: 0.6626
# Epoch 59/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3488 - scce_loss: 0.8611 - perceptual_loss: 0.4877
# Epoch 60/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1383 - scce_loss: 0.7357 - perceptual_loss: 0.4026
# Epoch 61/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0480 - scce_loss: 0.7502 - perceptual_loss: 0.2978
# Epoch 62/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9821 - scce_loss: 0.5568 - perceptual_loss: 0.4252
# Epoch 63/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0267 - scce_loss: 0.5439 - perceptual_loss: 0.4828
# Epoch 64/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.4100 - scce_loss: 0.7056 - perceptual_loss: 0.7043
# Epoch 65/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9732 - scce_loss: 0.6374 - perceptual_loss: 0.3358
# Epoch 66/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1498 - scce_loss: 0.6450 - perceptual_loss: 0.5048
# Epoch 67/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2292 - scce_loss: 0.6819 - perceptual_loss: 0.5473
# Epoch 68/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.6526 - scce_loss: 0.8499 - perceptual_loss: 0.8027
# Epoch 69/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9182 - scce_loss: 0.6243 - perceptual_loss: 0.2939
# Epoch 70/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9214 - scce_loss: 0.5358 - perceptual_loss: 0.3856
# Epoch 71/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1066 - scce_loss: 0.6676 - perceptual_loss: 0.4391
# Epoch 72/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2851 - scce_loss: 0.7957 - perceptual_loss: 0.4894
# Epoch 73/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2840 - scce_loss: 0.7538 - perceptual_loss: 0.5302
# Epoch 74/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8127 - scce_loss: 0.5093 - perceptual_loss: 0.3033
# Epoch 75/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0047 - scce_loss: 0.5339 - perceptual_loss: 0.4708
# Epoch 76/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8364 - scce_loss: 0.5802 - perceptual_loss: 0.2562
# Epoch 77/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2364 - scce_loss: 0.6667 - perceptual_loss: 0.5697
# Epoch 78/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.3099 - scce_loss: 0.8206 - perceptual_loss: 0.4894
# Epoch 79/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0083 - scce_loss: 0.4773 - perceptual_loss: 0.5310
# Epoch 80/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3110 - scce_loss: 0.7230 - perceptual_loss: 0.5881
# Epoch 81/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2380 - scce_loss: 0.6241 - perceptual_loss: 0.6138
# Epoch 82/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9418 - scce_loss: 0.4890 - perceptual_loss: 0.4527
# Epoch 83/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0806 - scce_loss: 0.6195 - perceptual_loss: 0.4611
# Epoch 84/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1841 - scce_loss: 0.7690 - perceptual_loss: 0.4151
# Epoch 85/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2328 - scce_loss: 0.7724 - perceptual_loss: 0.4604
# Epoch 86/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2768 - scce_loss: 0.6990 - perceptual_loss: 0.5778
# Epoch 87/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2846 - scce_loss: 0.8075 - perceptual_loss: 0.4771
# Epoch 88/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9226 - scce_loss: 0.5014 - perceptual_loss: 0.4213
# Epoch 89/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.7292 - scce_loss: 0.9682 - perceptual_loss: 0.7611
# Epoch 90/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8049 - scce_loss: 0.5055 - perceptual_loss: 0.2995
# Epoch 91/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2317 - scce_loss: 0.7667 - perceptual_loss: 0.4650
# Epoch 92/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9385 - scce_loss: 0.6201 - perceptual_loss: 0.3185
# Epoch 93/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3656 - scce_loss: 0.6578 - perceptual_loss: 0.7079
# Epoch 94/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1700 - scce_loss: 0.6222 - perceptual_loss: 0.5477
# Epoch 95/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8851 - scce_loss: 0.4942 - perceptual_loss: 0.3909
# Epoch 96/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.4519 - scce_loss: 0.7685 - perceptual_loss: 0.6834
# Epoch 97/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0486 - scce_loss: 0.5728 - perceptual_loss: 0.4757
# Epoch 98/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8147 - scce_loss: 0.4595 - perceptual_loss: 0.3552
# Epoch 99/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0549 - scce_loss: 0.5983 - perceptual_loss: 0.4565
# Epoch 100/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0280 - scce_loss: 0.5876 - perceptual_loss: 0.4404
# Epoch 101/10000
# 4/4 [==============================] - 113s 33s/step - total_loss: 0.7502 - scce_loss: 0.4302 - perceptual_loss: 0.3200
# Epoch 102/10000
# 4/4 [==============================] - 109s 33s/step - total_loss: 0.7207 - scce_loss: 0.3662 - perceptual_loss: 0.3545
# Epoch 103/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.3325 - scce_loss: 0.6859 - perceptual_loss: 0.6465
# Epoch 104/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1381 - scce_loss: 0.6339 - perceptual_loss: 0.5041
# Epoch 105/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.2437 - scce_loss: 0.5868 - perceptual_loss: 0.6569
# Epoch 106/10000
# 4/4 [==============================] - 108s 33s/step - total_loss: 0.5681 - scce_loss: 0.2332 - perceptual_loss: 0.3349
# Epoch 107/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.3936 - scce_loss: 0.8049 - perceptual_loss: 0.5887
# Epoch 108/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9260 - scce_loss: 0.5942 - perceptual_loss: 0.3318
# Epoch 109/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 1.2329 - scce_loss: 0.7077 - perceptual_loss: 0.5252
# Epoch 110/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8804 - scce_loss: 0.4632 - perceptual_loss: 0.4172
# Epoch 111/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8528 - scce_loss: 0.4692 - perceptual_loss: 0.3836
# Epoch 112/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.8458 - scce_loss: 0.4228 - perceptual_loss: 0.4229
# Epoch 113/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1332 - scce_loss: 0.5957 - perceptual_loss: 0.5374
# Epoch 114/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1128 - scce_loss: 0.6340 - perceptual_loss: 0.4788
# Epoch 115/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0247 - scce_loss: 0.4442 - perceptual_loss: 0.5805
# Epoch 116/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.7829 - scce_loss: 0.5008 - perceptual_loss: 0.2821
# Epoch 117/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.5138 - scce_loss: 0.7444 - perceptual_loss: 0.7693
# Epoch 118/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9010 - scce_loss: 0.4504 - perceptual_loss: 0.4506
# Epoch 119/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1608 - scce_loss: 0.6128 - perceptual_loss: 0.5480
# Epoch 120/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9961 - scce_loss: 0.5289 - perceptual_loss: 0.4672
# Epoch 121/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9284 - scce_loss: 0.5415 - perceptual_loss: 0.3869
# Epoch 122/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0406 - scce_loss: 0.6560 - perceptual_loss: 0.3846
# Epoch 123/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.5420 - scce_loss: 0.8146 - perceptual_loss: 0.7273
# Epoch 124/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8467 - scce_loss: 0.4355 - perceptual_loss: 0.4112
# Epoch 125/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9336 - scce_loss: 0.5641 - perceptual_loss: 0.3695
# Epoch 126/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7741 - scce_loss: 0.4282 - perceptual_loss: 0.3459
# Epoch 127/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8238 - scce_loss: 0.4327 - perceptual_loss: 0.3910
# Epoch 128/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0634 - scce_loss: 0.5895 - perceptual_loss: 0.4738
# Epoch 129/10000
# 4/4 [==============================] - 93s 27s/step - total_loss: 1.0674 - scce_loss: 0.5752 - perceptual_loss: 0.4923
# Epoch 130/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 0.8415 - scce_loss: 0.3299 - perceptual_loss: 0.5117
# Epoch 131/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9185 - scce_loss: 0.5688 - perceptual_loss: 0.3497
# Epoch 132/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7773 - scce_loss: 0.4381 - perceptual_loss: 0.3392
# Epoch 133/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9523 - scce_loss: 0.4578 - perceptual_loss: 0.4945
# Epoch 134/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1233 - scce_loss: 0.6549 - perceptual_loss: 0.4685
# Epoch 135/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.3467 - scce_loss: 0.7342 - perceptual_loss: 0.6125
# Epoch 136/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6854 - scce_loss: 0.3218 - perceptual_loss: 0.3636
# Epoch 137/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1132 - scce_loss: 0.6039 - perceptual_loss: 0.5093
# Epoch 138/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8586 - scce_loss: 0.3337 - perceptual_loss: 0.5249
# Epoch 139/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8095 - scce_loss: 0.3620 - perceptual_loss: 0.4476
# Epoch 140/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.4244 - scce_loss: 0.6036 - perceptual_loss: 0.8208
# Epoch 141/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.8231 - scce_loss: 0.5707 - perceptual_loss: 0.2524
# Epoch 142/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1795 - scce_loss: 0.6408 - perceptual_loss: 0.5386
# Epoch 143/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3959 - scce_loss: 0.7389 - perceptual_loss: 0.6571
# Epoch 144/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.1116 - scce_loss: 0.6031 - perceptual_loss: 0.5085
# Epoch 145/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6159 - scce_loss: 0.2968 - perceptual_loss: 0.3192
# Epoch 146/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8336 - scce_loss: 0.4388 - perceptual_loss: 0.3947
# Epoch 147/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8668 - scce_loss: 0.4484 - perceptual_loss: 0.4185
# Epoch 148/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7055 - scce_loss: 0.2369 - perceptual_loss: 0.4686
# Epoch 149/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8503 - scce_loss: 0.4670 - perceptual_loss: 0.3833
# Epoch 150/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8244 - scce_loss: 0.5169 - perceptual_loss: 0.3075
# Epoch 151/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9703 - scce_loss: 0.4733 - perceptual_loss: 0.4970
# Epoch 152/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.6766 - scce_loss: 0.2770 - perceptual_loss: 0.3996
# Epoch 153/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6024 - scce_loss: 0.2534 - perceptual_loss: 0.3490
# Epoch 154/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1248 - scce_loss: 0.6141 - perceptual_loss: 0.5107
# Epoch 155/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8427 - scce_loss: 0.3900 - perceptual_loss: 0.4527
# Epoch 156/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.7434 - scce_loss: 0.4113 - perceptual_loss: 0.3322
# Epoch 157/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8004 - scce_loss: 0.5121 - perceptual_loss: 0.2884
# Epoch 158/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7247 - scce_loss: 0.3876 - perceptual_loss: 0.3372
# Epoch 159/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.3597 - scce_loss: 0.6691 - perceptual_loss: 0.6907
# Epoch 160/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7331 - scce_loss: 0.2886 - perceptual_loss: 0.4445
# Epoch 161/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0216 - scce_loss: 0.5788 - perceptual_loss: 0.4428
# Epoch 162/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8923 - scce_loss: 0.5404 - perceptual_loss: 0.3519
# Epoch 163/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8733 - scce_loss: 0.5055 - perceptual_loss: 0.3678
# Epoch 164/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9485 - scce_loss: 0.4925 - perceptual_loss: 0.4560
# Epoch 165/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2963 - scce_loss: 0.6821 - perceptual_loss: 0.6142
# Epoch 166/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6011 - scce_loss: 0.2571 - perceptual_loss: 0.3440
# Epoch 167/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8690 - scce_loss: 0.4415 - perceptual_loss: 0.4275
# Epoch 168/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9891 - scce_loss: 0.5944 - perceptual_loss: 0.3947
# Epoch 169/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9931 - scce_loss: 0.5581 - perceptual_loss: 0.4350
# Epoch 170/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7970 - scce_loss: 0.3432 - perceptual_loss: 0.4538
# Epoch 171/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0823 - scce_loss: 0.6308 - perceptual_loss: 0.4515
# Epoch 172/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7652 - scce_loss: 0.3600 - perceptual_loss: 0.4052
# Epoch 173/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8071 - scce_loss: 0.4933 - perceptual_loss: 0.3138
# Epoch 174/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7348 - scce_loss: 0.3105 - perceptual_loss: 0.4243
# Epoch 175/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8420 - scce_loss: 0.4215 - perceptual_loss: 0.4205
# Epoch 176/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9830 - scce_loss: 0.4865 - perceptual_loss: 0.4965
# Epoch 177/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7298 - scce_loss: 0.3617 - perceptual_loss: 0.3681
# Epoch 178/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2133 - scce_loss: 0.6564 - perceptual_loss: 0.5569
# Epoch 179/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 0.8649 - scce_loss: 0.4054 - perceptual_loss: 0.4594
# Epoch 180/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.1293 - scce_loss: 0.5554 - perceptual_loss: 0.5739
# Epoch 181/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.4005 - scce_loss: 0.5103 - perceptual_loss: 0.8902
# Epoch 182/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1920 - scce_loss: 0.5294 - perceptual_loss: 0.6626
# Epoch 183/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7805 - scce_loss: 0.5429 - perceptual_loss: 0.2376
# Epoch 184/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2787 - scce_loss: 0.6811 - perceptual_loss: 0.5977
# Epoch 185/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9298 - scce_loss: 0.5520 - perceptual_loss: 0.3778
# Epoch 186/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6509 - scce_loss: 0.3330 - perceptual_loss: 0.3179
# Epoch 187/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2001 - scce_loss: 0.7230 - perceptual_loss: 0.4771
# Epoch 188/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9330 - scce_loss: 0.3916 - perceptual_loss: 0.5414
# Epoch 189/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2277 - scce_loss: 0.5540 - perceptual_loss: 0.6736
# Epoch 190/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0731 - scce_loss: 0.7087 - perceptual_loss: 0.3645
# Epoch 191/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0977 - scce_loss: 0.5763 - perceptual_loss: 0.5214
# Epoch 192/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.6471 - scce_loss: 0.3152 - perceptual_loss: 0.3319
# Epoch 193/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0221 - scce_loss: 0.5068 - perceptual_loss: 0.5153
# Epoch 194/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2716 - scce_loss: 0.6495 - perceptual_loss: 0.6222
# Epoch 195/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0229 - scce_loss: 0.5896 - perceptual_loss: 0.4333
# Epoch 196/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7576 - scce_loss: 0.4347 - perceptual_loss: 0.3228
# Epoch 197/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8491 - scce_loss: 0.4638 - perceptual_loss: 0.3853
# Epoch 198/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8704 - scce_loss: 0.5051 - perceptual_loss: 0.3653
# Epoch 199/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.4466 - scce_loss: 0.6861 - perceptual_loss: 0.7604
# Epoch 200/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7802 - scce_loss: 0.3020 - perceptual_loss: 0.4782
# Epoch 201/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0082 - scce_loss: 0.5786 - perceptual_loss: 0.4296
# Epoch 202/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8943 - scce_loss: 0.4404 - perceptual_loss: 0.4539
# Epoch 203/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1179 - scce_loss: 0.5510 - perceptual_loss: 0.5669
# Epoch 204/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0599 - scce_loss: 0.5908 - perceptual_loss: 0.4691
# Epoch 205/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8557 - scce_loss: 0.3981 - perceptual_loss: 0.4576
# Epoch 206/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1470 - scce_loss: 0.6482 - perceptual_loss: 0.4988
# Epoch 207/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.7936 - scce_loss: 0.4461 - perceptual_loss: 0.3475
# Epoch 208/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9799 - scce_loss: 0.3692 - perceptual_loss: 0.6108
# Epoch 209/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.6555 - scce_loss: 0.3408 - perceptual_loss: 0.3147
# Epoch 210/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1956 - scce_loss: 0.5820 - perceptual_loss: 0.6135
# Epoch 211/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8097 - scce_loss: 0.4148 - perceptual_loss: 0.3949
# Epoch 212/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8825 - scce_loss: 0.4685 - perceptual_loss: 0.4140
# Epoch 213/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8940 - scce_loss: 0.5610 - perceptual_loss: 0.3330
# Epoch 214/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9624 - scce_loss: 0.6008 - perceptual_loss: 0.3616
# Epoch 215/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7638 - scce_loss: 0.3395 - perceptual_loss: 0.4243
# Epoch 216/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8838 - scce_loss: 0.5808 - perceptual_loss: 0.3030
# Epoch 217/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9139 - scce_loss: 0.4402 - perceptual_loss: 0.4738
# Epoch 218/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 1.0151 - scce_loss: 0.5645 - perceptual_loss: 0.4506
# Epoch 219/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6564 - scce_loss: 0.2595 - perceptual_loss: 0.3969
# Epoch 220/10000
# 4/4 [==============================] - 108s 33s/step - total_loss: 0.5605 - scce_loss: 0.2602 - perceptual_loss: 0.3003
# Epoch 221/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1685 - scce_loss: 0.5300 - perceptual_loss: 0.6384
# Epoch 222/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9756 - scce_loss: 0.5631 - perceptual_loss: 0.4124
# Epoch 223/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8152 - scce_loss: 0.3803 - perceptual_loss: 0.4349
# Epoch 224/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9015 - scce_loss: 0.5057 - perceptual_loss: 0.3957
# Epoch 225/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8404 - scce_loss: 0.3807 - perceptual_loss: 0.4598
# Epoch 226/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8810 - scce_loss: 0.4485 - perceptual_loss: 0.4325
# Epoch 227/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.7921 - scce_loss: 0.3263 - perceptual_loss: 0.4658
# Epoch 228/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 0.7774 - scce_loss: 0.4073 - perceptual_loss: 0.3701
# Epoch 229/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.4262 - scce_loss: 0.7411 - perceptual_loss: 0.6852
# Epoch 230/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9602 - scce_loss: 0.4702 - perceptual_loss: 0.4900
# Epoch 231/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9657 - scce_loss: 0.4634 - perceptual_loss: 0.5023
# Epoch 232/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.5861 - scce_loss: 0.2612 - perceptual_loss: 0.3249
# Epoch 233/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8934 - scce_loss: 0.4880 - perceptual_loss: 0.4055
# Epoch 234/10000
# 4/4 [==============================] - 107s 33s/step - total_loss: 0.5106 - scce_loss: 0.2291 - perceptual_loss: 0.2815
# Epoch 235/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 1.1501 - scce_loss: 0.6088 - perceptual_loss: 0.5412
# Epoch 236/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2505 - scce_loss: 0.6670 - perceptual_loss: 0.5835
# Epoch 237/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7102 - scce_loss: 0.4070 - perceptual_loss: 0.3032
# Epoch 238/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8851 - scce_loss: 0.4688 - perceptual_loss: 0.4162
# Epoch 239/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9163 - scce_loss: 0.4760 - perceptual_loss: 0.4403
# Epoch 240/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.3419 - scce_loss: 0.5724 - perceptual_loss: 0.7695
# Epoch 241/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9887 - scce_loss: 0.4181 - perceptual_loss: 0.5706
# Epoch 242/10000
# 4/4 [==============================] - 109s 33s/step - total_loss: 0.4044 - scce_loss: 0.2620 - perceptual_loss: 0.1424
# Epoch 243/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.8109 - scce_loss: 0.3751 - perceptual_loss: 0.4358
# Epoch 244/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.6404 - scce_loss: 0.2510 - perceptual_loss: 0.3894
# Epoch 245/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.0852 - scce_loss: 0.5842 - perceptual_loss: 0.5010
# Epoch 246/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8148 - scce_loss: 0.3157 - perceptual_loss: 0.4991
# Epoch 247/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0308 - scce_loss: 0.4553 - perceptual_loss: 0.5756
# Epoch 248/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9642 - scce_loss: 0.4395 - perceptual_loss: 0.5247
# Epoch 249/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.7450 - scce_loss: 0.4519 - perceptual_loss: 0.2930
# Epoch 250/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8219 - scce_loss: 0.4129 - perceptual_loss: 0.4090
# Epoch 251/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 0.8365 - scce_loss: 0.4887 - perceptual_loss: 0.3478
# Epoch 252/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1003 - scce_loss: 0.6067 - perceptual_loss: 0.4936
# Epoch 253/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7618 - scce_loss: 0.3339 - perceptual_loss: 0.4279
# Epoch 254/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0210 - scce_loss: 0.5365 - perceptual_loss: 0.4845
# Epoch 255/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.8761 - scce_loss: 0.4540 - perceptual_loss: 0.4221
# Epoch 256/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1367 - scce_loss: 0.6545 - perceptual_loss: 0.4822
# Epoch 257/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7535 - scce_loss: 0.4030 - perceptual_loss: 0.3505
# Epoch 258/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9592 - scce_loss: 0.4933 - perceptual_loss: 0.4659
# Epoch 259/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.8535 - scce_loss: 0.5276 - perceptual_loss: 0.3259
# Epoch 260/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1554 - scce_loss: 0.5035 - perceptual_loss: 0.6519
# Epoch 261/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.9337 - scce_loss: 0.4618 - perceptual_loss: 0.4718
# Epoch 262/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9777 - scce_loss: 0.5294 - perceptual_loss: 0.4483
# Epoch 263/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2938 - scce_loss: 0.7351 - perceptual_loss: 0.5587
# Epoch 264/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0014 - scce_loss: 0.5091 - perceptual_loss: 0.4923
# Epoch 265/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7976 - scce_loss: 0.4002 - perceptual_loss: 0.3974
# Epoch 266/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 0.9651 - scce_loss: 0.5109 - perceptual_loss: 0.4542
# Epoch 267/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7628 - scce_loss: 0.4098 - perceptual_loss: 0.3530
# Epoch 268/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.6774 - scce_loss: 0.2205 - perceptual_loss: 0.4569
# Epoch 269/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.8903 - scce_loss: 0.5135 - perceptual_loss: 0.3768
# Epoch 270/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1982 - scce_loss: 0.5153 - perceptual_loss: 0.6829
# Epoch 271/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7953 - scce_loss: 0.3428 - perceptual_loss: 0.4524
# Epoch 272/10000
# 4/4 [==============================] - 93s 27s/step - total_loss: 0.7735 - scce_loss: 0.4923 - perceptual_loss: 0.2812
# Epoch 273/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.6923 - scce_loss: 0.3006 - perceptual_loss: 0.3918
# Epoch 274/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7935 - scce_loss: 0.3597 - perceptual_loss: 0.4338
# Epoch 275/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2302 - scce_loss: 0.7567 - perceptual_loss: 0.4735
# Epoch 276/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0404 - scce_loss: 0.4936 - perceptual_loss: 0.5467
# Epoch 277/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7265 - scce_loss: 0.3547 - perceptual_loss: 0.3719
# Epoch 278/10000
# 4/4 [==============================] - 93s 27s/step - total_loss: 0.9781 - scce_loss: 0.5991 - perceptual_loss: 0.3789
# Epoch 279/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9690 - scce_loss: 0.4296 - perceptual_loss: 0.5394
# Epoch 280/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 1.1607 - scce_loss: 0.5909 - perceptual_loss: 0.5698
# Epoch 281/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0864 - scce_loss: 0.5554 - perceptual_loss: 0.5310
# Epoch 282/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.5788 - scce_loss: 0.2773 - perceptual_loss: 0.3015
# Epoch 283/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2942 - scce_loss: 0.5823 - perceptual_loss: 0.7119
# Epoch 284/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.5989 - scce_loss: 0.1927 - perceptual_loss: 0.4062
# Epoch 285/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0548 - scce_loss: 0.5742 - perceptual_loss: 0.4806
# Epoch 286/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0692 - scce_loss: 0.6648 - perceptual_loss: 0.4044
# Epoch 287/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8923 - scce_loss: 0.3563 - perceptual_loss: 0.5360
# Epoch 288/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8734 - scce_loss: 0.6343 - perceptual_loss: 0.2392
# Epoch 289/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0762 - scce_loss: 0.5170 - perceptual_loss: 0.5592
# Epoch 290/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8605 - scce_loss: 0.4854 - perceptual_loss: 0.3751
# Epoch 291/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0483 - scce_loss: 0.5849 - perceptual_loss: 0.4634
# Epoch 292/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0045 - scce_loss: 0.6096 - perceptual_loss: 0.3949
# Epoch 293/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8716 - scce_loss: 0.4862 - perceptual_loss: 0.3855
# Epoch 294/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8376 - scce_loss: 0.3742 - perceptual_loss: 0.4634
# Epoch 295/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 0.8362 - scce_loss: 0.3391 - perceptual_loss: 0.4971
# Epoch 296/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0797 - scce_loss: 0.5777 - perceptual_loss: 0.5020
# Epoch 297/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1478 - scce_loss: 0.6197 - perceptual_loss: 0.5281
# Epoch 298/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.5904 - scce_loss: 0.2111 - perceptual_loss: 0.3794
# Epoch 299/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9869 - scce_loss: 0.5571 - perceptual_loss: 0.4298
# Epoch 300/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.6563 - scce_loss: 0.7882 - perceptual_loss: 0.8681
# Epoch 301/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9860 - scce_loss: 0.5216 - perceptual_loss: 0.4645
# Epoch 302/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1519 - scce_loss: 0.5566 - perceptual_loss: 0.5953
# Epoch 303/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.9253 - scce_loss: 0.4346 - perceptual_loss: 0.4907
# Epoch 304/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.2241 - scce_loss: 0.5942 - perceptual_loss: 0.6299
# Epoch 305/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9121 - scce_loss: 0.4576 - perceptual_loss: 0.4545
# Epoch 306/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.2420 - scce_loss: 0.8207 - perceptual_loss: 0.4212
# Epoch 307/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7125 - scce_loss: 0.3197 - perceptual_loss: 0.3927
# Epoch 308/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1381 - scce_loss: 0.6651 - perceptual_loss: 0.4730
# Epoch 309/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1812 - scce_loss: 0.5490 - perceptual_loss: 0.6322
# Epoch 310/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1741 - scce_loss: 0.6596 - perceptual_loss: 0.5145
# Epoch 311/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0305 - scce_loss: 0.6066 - perceptual_loss: 0.4240
# Epoch 312/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9508 - scce_loss: 0.5805 - perceptual_loss: 0.3702
# Epoch 313/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0802 - scce_loss: 0.5195 - perceptual_loss: 0.5607
# Epoch 314/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8345 - scce_loss: 0.4885 - perceptual_loss: 0.3460
# Epoch 315/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0285 - scce_loss: 0.4229 - perceptual_loss: 0.6056
# Epoch 316/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1808 - scce_loss: 0.5736 - perceptual_loss: 0.6071
# Epoch 317/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7702 - scce_loss: 0.3472 - perceptual_loss: 0.4230
# Epoch 318/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9977 - scce_loss: 0.4841 - perceptual_loss: 0.5136
# Epoch 319/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9808 - scce_loss: 0.5211 - perceptual_loss: 0.4597
# Epoch 320/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1030 - scce_loss: 0.5974 - perceptual_loss: 0.5056
# Epoch 321/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8563 - scce_loss: 0.4406 - perceptual_loss: 0.4156
# Epoch 322/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7368 - scce_loss: 0.3962 - perceptual_loss: 0.3405
# Epoch 323/10000
# 4/4 [==============================] - 90s 27s/step - total_loss: 0.6858 - scce_loss: 0.3335 - perceptual_loss: 0.3523
# Epoch 324/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.0413 - scce_loss: 0.5730 - perceptual_loss: 0.4683
# Epoch 325/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0228 - scce_loss: 0.5790 - perceptual_loss: 0.4438
# Epoch 326/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.2736 - scce_loss: 0.7720 - perceptual_loss: 0.5015
# Epoch 327/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.5642 - scce_loss: 0.2194 - perceptual_loss: 0.3449
# Epoch 328/10000
# 4/4 [==============================] - 93s 27s/step - total_loss: 0.9076 - scce_loss: 0.4617 - perceptual_loss: 0.4459
# Epoch 329/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7262 - scce_loss: 0.3759 - perceptual_loss: 0.3503
# Epoch 330/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.8621 - scce_loss: 0.4683 - perceptual_loss: 0.3938
# Epoch 331/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.9946 - scce_loss: 0.6204 - perceptual_loss: 0.3742
# Epoch 332/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.1261 - scce_loss: 0.6674 - perceptual_loss: 0.4587
# Epoch 333/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7090 - scce_loss: 0.3635 - perceptual_loss: 0.3455
# Epoch 334/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9092 - scce_loss: 0.4173 - perceptual_loss: 0.4919
# Epoch 335/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.9087 - scce_loss: 0.4396 - perceptual_loss: 0.4690
# Epoch 336/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7613 - scce_loss: 0.4655 - perceptual_loss: 0.2958
# Epoch 337/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.1851 - scce_loss: 0.6710 - perceptual_loss: 0.5141
# Epoch 338/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.5194 - scce_loss: 0.6776 - perceptual_loss: 0.8418
# Epoch 339/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 0.7499 - scce_loss: 0.4315 - perceptual_loss: 0.3184
# Epoch 340/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0593 - scce_loss: 0.5774 - perceptual_loss: 0.4819
# Epoch 341/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7850 - scce_loss: 0.4334 - perceptual_loss: 0.3516
# Epoch 342/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7108 - scce_loss: 0.3353 - perceptual_loss: 0.3755
# Epoch 343/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.9535 - scce_loss: 0.4784 - perceptual_loss: 0.4751
# Epoch 344/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8760 - scce_loss: 0.3515 - perceptual_loss: 0.5245
# Epoch 345/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7071 - scce_loss: 0.4329 - perceptual_loss: 0.2742
# Epoch 346/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 0.7428 - scce_loss: 0.3450 - perceptual_loss: 0.3978
# Epoch 347/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.4303 - scce_loss: 0.6442 - perceptual_loss: 0.7861
# Epoch 348/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1787 - scce_loss: 0.6678 - perceptual_loss: 0.5109
# Epoch 349/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 1.1157 - scce_loss: 0.7680 - perceptual_loss: 0.3478
# Epoch 350/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 0.7974 - scce_loss: 0.4219 - perceptual_loss: 0.3755
# Epoch 351/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7258 - scce_loss: 0.4316 - perceptual_loss: 0.2942
# Epoch 352/10000
# 4/4 [==============================] - 92s 27s/step - total_loss: 1.0909 - scce_loss: 0.6169 - perceptual_loss: 0.4740
# Epoch 353/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8671 - scce_loss: 0.5420 - perceptual_loss: 0.3251
# Epoch 354/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.7920 - scce_loss: 0.2645 - perceptual_loss: 0.5275
# Epoch 355/10000
# 4/4 [==============================] - 97s 29s/step - total_loss: 0.9920 - scce_loss: 0.5101 - perceptual_loss: 0.4819
# Epoch 356/10000
# 4/4 [==============================] - 91s 27s/step - total_loss: 0.8405 - scce_loss: 0.4430 - perceptual_loss: 0.3975
# Epoch 357/10000
# ...
# Epoch 5609/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 0.8776 - scce_loss: 0.5932 - perceptual_loss: 0.2844
# Epoch 5610/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.0279 - scce_loss: 0.5851 - perceptual_loss: 0.4428
# Epoch 5611/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.6117 - scce_loss: 1.0039 - perceptual_loss: 0.6078
# Epoch 5612/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.4676 - scce_loss: 0.8983 - perceptual_loss: 0.5693
# Epoch 5613/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.0891 - scce_loss: 0.6553 - perceptual_loss: 0.4338
# Epoch 5614/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 1.1403 - scce_loss: 0.7070 - perceptual_loss: 0.4334
# Epoch 5615/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 0.7732 - scce_loss: 0.5485 - perceptual_loss: 0.2247
# Epoch 5616/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.2014 - scce_loss: 0.6951 - perceptual_loss: 0.5063
# Epoch 5617/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 0.9743 - scce_loss: 0.6463 - perceptual_loss: 0.3280
# Epoch 5618/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.0444 - scce_loss: 0.6141 - perceptual_loss: 0.4303
# Epoch 5619/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.3032 - scce_loss: 0.8157 - perceptual_loss: 0.4875
# Epoch 5620/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.2398 - scce_loss: 0.7196 - perceptual_loss: 0.5203
# Epoch 5621/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 0.9833 - scce_loss: 0.6382 - perceptual_loss: 0.3451
# Epoch 5622/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.1049 - scce_loss: 0.7411 - perceptual_loss: 0.3638
# Epoch 5623/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.0129 - scce_loss: 0.6046 - perceptual_loss: 0.4084
# Epoch 5624/10000
# 4/4 [==============================] - 92s 28s/step - total_loss: 1.0973 - scce_loss: 0.5821 - perceptual_loss: 0.5152
# Epoch 5625/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.1406 - scce_loss: 0.7721 - perceptual_loss: 0.3685
# Epoch 5626/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 1.4752 - scce_loss: 0.9573 - perceptual_loss: 0.5179
# Epoch 5627/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 0.9444 - scce_loss: 0.5920 - perceptual_loss: 0.3525
# Epoch 5628/10000
# 4/4 [==============================] - 97s 29s/step - total_loss: 0.9099 - scce_loss: 0.5709 - perceptual_loss: 0.3390
# Epoch 5629/10000
# 4/4 [==============================] - 96s 29s/step - total_loss: 1.0772 - scce_loss: 0.5585 - perceptual_loss: 0.5186
# Epoch 5630/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 0.9445 - scce_loss: 0.6444 - perceptual_loss: 0.3001
# Epoch 5631/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.4175 - scce_loss: 1.0011 - perceptual_loss: 0.4164
# Epoch 5632/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.3204 - scce_loss: 0.9809 - perceptual_loss: 0.3394
# Epoch 5633/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 1.1653 - scce_loss: 0.6565 - perceptual_loss: 0.5087
# Epoch 5634/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.3944 - scce_loss: 0.8842 - perceptual_loss: 0.5101
# Epoch 5635/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.1699 - scce_loss: 0.7057 - perceptual_loss: 0.4642
# Epoch 5636/10000
# 4/4 [==============================] - 98s 29s/step - total_loss: 1.1191 - scce_loss: 0.7697 - perceptual_loss: 0.3494
# Epoch 5637/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.6399 - scce_loss: 1.0103 - perceptual_loss: 0.6296
# Epoch 5638/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.1584 - scce_loss: 0.5775 - perceptual_loss: 0.5809
# Epoch 5639/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.2237 - scce_loss: 0.7413 - perceptual_loss: 0.4824
# Epoch 5640/10000
# 4/4 [==============================] - 93s 28s/step - total_loss: 1.6190 - scce_loss: 0.9207 - perceptual_loss: 0.6983
# Epoch 5641/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.4826 - scce_loss: 0.8626 - perceptual_loss: 0.6200
# Epoch 5642/10000
# 4/4 [==============================] - 96s 28s/step - total_loss: 1.1230 - scce_loss: 0.7424 - perceptual_loss: 0.3805
# Epoch 5643/10000
# 4/4 [==============================] - 95s 28s/step - total_loss: 1.1233 - scce_loss: 0.6277 - perceptual_loss: 0.4956
# Epoch 5644/10000
# 4/4 [==============================] - 94s 28s/step - total_loss: 1.1242 - scce_loss: 0.5822 - perceptual_loss: 0.5420
# Epoch 5645/10000
# 4/4 [==============================] - ETA: 0s - total_loss: 1.0831 - scce_loss: 0.6969 - perceptual_loss: 0.3862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b04241c966a4> in <module>
# ----> 1 model.fit(train_ds, validation_data=validation_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#       2 #model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1265           epoch_logs.update(val_logs)
#    1266
# -> 1267         callbacks.on_epoch_end(epoch, epoch_logs)
#    1268         training_logs = epoch_logs
#    1269         if self.stop_training:
#
# /usr/local/lib/python3.8/dist-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     412     logs = self._process_logs(logs)
#     413     for callback in self.callbacks:
# --> 414       callback.on_epoch_end(epoch, logs)
#     415
#     416   def on_train_batch_begin(self, batch, logs=None):
#
# /GANime/ganime/utils/callbacks.py in on_epoch_end(self, epoch, logs)
#     110         # train_X, train_y = self.train
#     111         # train_X, train_y = self.truncate_X_y(train_X, train_y, self.n_videos)
# --> 112         train_pred = self.model.predict(self.train)
#     113         self.write_to_tensorboard(
#     114             unnormalize_if_necessary(self.train["y"]),
#
# /GANime/ganime/model/vqgan_clean/experimental/net2net_v3.py in predict(self, data, sample, temperature)
#     106
#     107     def predict(self, data, sample=False, temperature=1.0):
# --> 108         video = self.predict_video(
#     109             data,
#     110             training=False,
#
# /GANime/ganime/model/vqgan_clean/experimental/net2net_v3.py in predict_video(self, inputs, training, return_losses, sample, temperature)
#     163                 target_frame = None
#     164
# --> 165             y_pred, losses = self.predict_next_frame(
#     166                 remaining_frames[:, current_frame_index],
#     167                 previous_frames,
#
# /GANime/ganime/model/vqgan_clean/experimental/net2net_v3.py in predict_next_frame(self, remaining_frames, previous_frames, last_frame, indices_last, quant_last, target_frame, training, sample, temperature)
#     255             )
#     256         else:
# --> 257             next_frame, losses = self.predict_next_frame_body(
#     258                 remaining_frames,
#     259                 indices_last,
#
# /GANime/ganime/model/vqgan_clean/experimental/net2net_v3.py in predict_next_frame_body(self, remaining_frames, last_frame_indices, previous_frame_indices, quant_shape, indices_shape, target_indices, target_frame, sample, temperature)
#     284             (remaining_frames, last_frame_indices, previous_frame_indices)
#     285         )
# --> 286         next_frame = self.convert_logits_to_image(
#     287             logits,
#     288             quant_shape=quant_shape,
#
# /GANime/ganime/model/vqgan_clean/experimental/net2net_v3.py in convert_logits_to_image(self, logits, quant_shape, indices_shape, sample, temperature)
#     370         )
#     371
# --> 372         return self.first_stage_model.decode(quant)
#     373
#     374     def train_step(self, data):
#
# /GANime/ganime/model/vqgan_clean/vqgan.py in decode(self, quant)
#     217     def decode(self, quant):
#     218         quant = self.post_quant_conv(quant)
# --> 219         dec = self.decoder(quant)
#     220         return dec
#     221
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /GANime/ganime/model/vqgan_clean/diffusion/decoder.py in call(self, inputs, training, mask)
#     103         # middle
#     104         h = self.mid["block_1"](h)
# --> 105         h = self.mid["attn_1"](h)
#     106         h = self.mid["block_2"](h)
#     107
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /GANime/ganime/model/vqgan_clean/diffusion/layers.py in call(self, x)
#     123         v = tf.reshape(v, [b, h * w, c])
#     124
# --> 125         h_ = self.attention([q, v, k])
#     126
#     127         h_ = tf.reshape(h_, [b, h, w, c])
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/dense_attention.py in call(self, inputs, mask, training, return_attention_scores)
#     162       causal_mask = None
#     163     scores_mask = _merge_masks(v_mask, causal_mask)
# --> 164     result, attention_scores = self._apply_scores(
#     165         scores=scores, value=v, scores_mask=scores_mask, training=training)
#     166     if q_mask is not None:
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/dense_attention.py in _apply_scores(self, scores, value, scores_mask, training)
#     129       return tf.nn.dropout(weights, rate=self.dropout)
#     130
# --> 131     weights = control_flow_util.smart_cond(training, dropped_weights,
#     132                                            lambda: tf.identity(weights))
#     133     return tf.matmul(weights, value), weights
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     103     return tf.cond(
#     104         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 105   return tf.__internal__.smart_cond.smart_cond(
#     106       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     107
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      55   if pred_value is not None:
#      56     if pred_value:
# ---> 57       return true_fn()
#      58     else:
#      59       return false_fn()
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/dense_attention.py in dropped_weights()
#     127
#     128     def dropped_weights():
# --> 129       return tf.nn.dropout(weights, rate=self.dropout)
#     130
#     131     weights = control_flow_util.smart_cond(training, dropped_weights,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py in dropout_v2(x, rate, noise_shape, seed, name)
#    5417   def dummy_rng_step():
#    5418     random_seed.get_seed(seed)
# -> 5419   return _dropout(x=x, rate=rate, noise_shape=noise_shape,
#    5420                   uniform_sampler=uniform_sampler,
#    5421                   dummy_rng_step=dummy_rng_step, name=name,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/nn_ops.py in _dropout(x, rate, noise_shape, uniform_sampler, dummy_rng_step, name, default_name)
#    5595                        f"range [0, 1). Received: rate={rate}")
#    5596     x = ops.convert_to_tensor(x, name="x")
# -> 5597     x_dtype = x.dtype
#    5598     if not x_dtype.is_floating:
#    5599       raise ValueError(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in dtype(self)
#    1121     # Note: using the intern table directly here as this is
#    1122     # performance-sensitive in some models.
# -> 1123     return dtypes._INTERN_TABLE[self._datatype_enum()]  # pylint: disable=protected-access
#    1124
#    1125   def numpy(self):
#
# KeyboardInterrupt:

# %%
generated = model(train_sample_data)
display_videos(generated, n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
model.load_weights("./gpt_kny_light_large_256/checkpoint")

# %%
generated = model(train_sample_data)
display_videos(generated, n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...
