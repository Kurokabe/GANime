# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
#for device in tf.config.list_physical_devices("GPU"):
#    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
#strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.ReductionToOneDevice())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/kny_video_gpt2_medium.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
#dataset_length = 1578 
#dataset_length = 10000
dataset_length = 35267
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = normalize(element)
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/kny/videos_tfrecords_full").load()
dataset = (dataset.shuffle(5000, reshuffle_each_iteration=True, seed=0)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(64)
                          #.map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.padded_batch(64)
                              #.map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
take_train = [1, 8, 9, 12, 21, 25, 30, 47]
train_sample_data = postprocess({key: value[take_train] for key, value in train_sample_data.items()})
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
take_validation = [3, 8, 13, 16, 21, 33, 56, 61]
validation_sample_data = postprocess({key: value[take_validation] for key, value in validation_sample_data.items()})
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_images(train_sample_data["last_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
train_sample_data["n_frames"]
# Out:
# <tf.Tensor: shape=(8,), dtype=int32, numpy=array([7, 7, 7, 7, 7, 7, 7, 7], dtype=int32)>

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = get_logdir("../../../logs/ganime/transformers", experiment_name="kny_medium")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='val_total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 512, 16, 16) = 131072 dimensions.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step - ETA - ETA - ETA:
# 80150528/80134624 [==============================] - 1s 0us/step
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# Some layers of TFGPT2LMHeadModel were not initialized from the model checkpoint at gpt2-medium and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Restoring weights from ../../../checkpoints/kny_video_full_gpt2_medium/checkpoint

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 1/500
# 2022-08-21 11:43:19.916222: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-21 11:43:20.931062: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 220/220 [==============================] - 575s 2s/step - total_loss: 2.2026 - scce_loss: 1.6061 - perceptual_loss: 0.5965 - val_total_loss: 3.1523 - val_scce_loss: 2.0543 - val_perceptual_loss: 1.0981
# Epoch 2/500
# 220/220 [==============================] - 479s 2s/step - total_loss: 1.3731 - scce_loss: 0.9604 - perceptual_loss: 0.4127 - val_total_loss: 2.0465 - val_scce_loss: 1.3623 - val_perceptual_loss: 0.6842
# Epoch 3/500
500
# 220/220 [==============================] - 454s 2s/step - total_loss: 1.5859 - scce_loss: 1.2231 - perceptual_loss: 0.3627 - val_total_loss: 1.9760 - val_scce_loss: 1.3448 - val_perceptual_loss: 0.6312
# Epoch 449/500
# 220/220 [==============================] - 449s 2s/step - total_loss: 1.6556 - scce_loss: 1.2741 - perceptual_loss: 0.3816 - val_total_loss: 2.0092 - val_scce_loss: 1.3787 - val_perceptual_loss: 0.6305
# Epoch 450/500
# 220/220 [==============================] - 451s 2s/step - total_loss: 1.6976 - scce_loss: 1.3027 - perceptual_loss: 0.3950 - val_total_loss: 2.0257 - val_scce_loss: 1.4156 - val_perceptual_loss: 0.6101
# Epoch 451/500
# 220/220 [==============================] - 451s 2s/step - total_loss: 1.7056 - scce_loss: 1.3253 - perceptual_loss: 0.3802 - val_total_loss: 2.0676 - val_scce_loss: 1.4527 - val_perceptual_loss: 0.6149
# Epoch 452/500
# 220/220 [==============================] - 454s 2s/step - total_loss: 1.7746 - scce_loss: 1.3728 - perceptual_loss: 0.4018 - val_total_loss: 2.1169 - val_scce_loss: 1.4780 - val_perceptual_loss: 0.6390
# Epoch 453/500
# 220/220 [==============================] - 454s 2s/step - total_loss: 1.8406 - scce_loss: 1.4045 - perceptual_loss: 0.4360 - val_total_loss: 2.1638 - val_scce_loss: 1.5150 - val_perceptual_loss: 0.6488
# Epoch 454/500
# 220/220 [==============================] - 454s 2s/step - total_loss: 1.8205 - scce_loss: 1.4309 - perceptual_loss: 0.3896 - val_total_loss: 2.2110 - val_scce_loss: 1.5504 - val_perceptual_loss: 0.6606
# Epoch 455/500
# 220/220 [==============================] - 459s 2s/step - total_loss: 1.8900 - scce_loss: 1.4634 - perceptual_loss: 0.4266 - val_total_loss: 2.2751 - val_scce_loss: 1.5802 - val_perceptual_loss: 0.6948
# Epoch 456/500
# 220/220 [==============================] - 444s 2s/step - total_loss: 1.9472 - scce_loss: 1.4963 - perceptual_loss: 0.4509 - val_total_loss: 2.2751 - val_scce_loss: 1.6067 - val_perceptual_loss: 0.6683
# Epoch 457/500
# 220/220 [==============================] - 450s 2s/step - total_loss: 2.0583 - scce_loss: 1.5344 - perceptual_loss: 0.5239 - val_total_loss: 2.4835 - val_scce_loss: 1.6427 - val_perceptual_loss: 0.8408
# Epoch 458/500
# 220/220 [==============================] - 452s 2s/step - total_loss: 2.1683 - scce_loss: 1.5821 - perceptual_loss: 0.5861 - val_total_loss: 2.5781 - val_scce_loss: 1.6735 - val_perceptual_loss: 0.9046
# Epoch 459/500
# 220/220 [==============================] - 448s 2s/step - total_loss: 2.2283 - scce_loss: 1.5918 - perceptual_loss: 0.6365 - val_total_loss: 2.6420 - val_scce_loss: 1.7042 - val_perceptual_loss: 0.9378
# Epoch 460/500
# 220/220 [==============================] - 447s 2s/step - total_loss: 2.3834 - scce_loss: 1.6348 - perceptual_loss: 0.7486 - val_total_loss: 2.8899 - val_scce_loss: 1.7401 - val_perceptual_loss: 1.1498
# Epoch 461/500
# 220/220 [==============================] - 454s 2s/step - total_loss:
500
# 220/220 [==============================] - 454s 2s/step - total_loss: 9.5771 - scce_loss: 2.4332 - perceptual_loss: 7.1439 - val_total_loss: 9.2018 - val_scce_loss: 2.5354 - val_perceptual_loss: 6.6664
# Epoch 478/500
# 220/220 [==============================] - 454s 2s/step - total_loss: 10.3427 - scce_loss: 2.4942 - perceptual_loss: 7.8484 - val_total_loss: 9.1222 - val_scce_loss: 2.5863 - val_perceptual_loss: 6.5359
# Epoch 479/500
# 220/220 [==============================] - 454s 2s/step - total_loss: 9.2874 - scce_loss: 2.5506 - perceptual_loss: 6.7369 - val_total_loss: 9.1073 - val_scce_loss: 2.6400 - val_perceptual_loss: 6.4673
# Epoch 480/500
# 220/220 [==============================] - 449s 2s/step - total_loss: 10.3985 - scce_loss: 2.6069 - perceptual_loss: 7.7916 - val_total_loss: 9.4128 - val_scce_loss: 2.6911 - val_perceptual_loss: 6.7217
# Epoch 481/500
# 220/220 [==============================] - 451s 2s/step - total_loss: 10.2479 - scce_loss: 2.6658 - perceptual_loss: 7.5820 - val_total_loss: 9.4356 - val_scce_loss: 2.7469 - val_perceptual_loss: 6.6887
# Epoch 482/500
# 220/220 [==============================] - 447s 2s/step - total_loss: 9.8743 - scce_loss: 2.7218 - perceptual_loss: 7.1525 - val_total_loss: 9.3388 - val_scce_loss: 2.7959 - val_perceptual_loss: 6.5428
# Epoch 483/500
# 220/220 [==============================] - 451s 2s/step - total_loss: 9.9400 - scce_loss: 2.7761 - perceptual_loss: 7.1639 - val_total_loss: 9.5202 - val_scce_loss: 2.8584 - val_perceptual_loss: 6.6618
# Epoch 484/500
# 220/220 [==============================] - ETA: 0s - total_loss: 9.9919 - scce_loss: 2.8337 - perceptual_loss: 7.1582

# %%
import cv2
import numpy as np
import tempfile

def save_video(video):
    output_file = tempfile.NamedTemporaryFile(suffix=".mp4")
    b, f, w, h, c = video.shape
    writer = cv2.VideoWriter(output_file.name, cv2.VideoWriter_fourcc(*'MP4V'), 25, (w, h), False)
    for i in range(f):
        writer.write(video[0][i])
    return output_file.name

# %%
def save_video(video):
    b, f, h, w, c = 1, 20, 500, 500, 3

    # filename = output_file.name
    filename = "./test_video.avi"

    writer = cv2.VideoWriter(
        filename, cv2.VideoWriter_fourcc(*'DIVX'), 10, (h, w), False
    )
    for i in range(f):
        # image = video[0][i].numpy()
        # image = 255 * image  # Now scale by 255
        # image = image.astype(np.uint8)
        image = np.random.randint(0, 255, (h, w, c), dtype=np.uint8)

        writer.write(image)

    writer.release()
    return filename

# %%
import ffmpegio
def save_video(video):
    b, f, h, w, c = 1, 20, 500, 500, 3

    # filename = output_file.name
    filename = "./test_video.mp4"
    images = []
    for i in range(f):
        # image = video[0][i].numpy()
        # image = 255 * image  # Now scale by 255
        # image = image.astype(np.uint8)
        images.append(np.random.randint(0, 255, (h, w, c), dtype=np.uint8))

    ffmpegio.video.write(filename, 20, np.array(images), overwrite=True)
    return filename

# %%
save_video("")
# Out:
# './test_video.avi'

# %%
generated = model(train_sample_data)

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(generated, n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...
