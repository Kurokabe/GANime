# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
#for device in tf.config.list_physical_devices("GPU"):
#    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
#strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.ReductionToOneDevice())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/kny_video_gpt2_xl.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
#dataset_length = 1578 
#dataset_length = 10000
dataset_length = 35267
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = normalize(element)
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/kny/videos_tfrecords_full").load()
dataset = (dataset.shuffle(5000, reshuffle_each_iteration=True, seed=0)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(64)
                          #.map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.padded_batch(64)
                              #.map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
take_train = [1, 8, 9, 12, 21, 25, 30, 47]
train_sample_data = postprocess({key: value[take_train] for key, value in train_sample_data.items()})
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
take_validation = [3, 8, 13, 16, 21, 33, 56, 61]
validation_sample_data = postprocess({key: value[take_validation] for key, value in validation_sample_data.items()})
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_images(train_sample_data["last_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1600" height="900" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
train_sample_data["n_frames"]
# Out:
# <tf.Tensor: shape=(8,), dtype=int32, numpy=array([7, 7, 7, 7, 7, 7, 7, 7], dtype=int32)>

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = get_logdir("../../../logs/ganime/transformers", experiment_name="kny_xl_masking")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='val_total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 512, 16, 16) = 131072 dimensions.
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# Downloading:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.23G [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# Some layers of TFGPT2LMHeadModel were not initialized from the model checkpoint at gpt2-xl and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 1/500
# 440/440 [==============================] - 7352s 17s/step - total_loss: 2.4185 - scce_loss: 1.7014 - perceptual_loss: 0.7170 - val_total_loss: 10.2160 - val_scce_loss: 4.5371 - val_perceptual_loss: 5.6790
# Epoch 2/500
# 440/440 [==============================] - 7136s 16s/step - total_loss: 1.7392 - scce_loss: 1.1559 - perceptual_loss: 0.5833 - val_total_loss: 10.5423 - val_scce_loss: 4.7119 - val_perceptual_loss: 5.8304
# Epoch 3/500
# 440/440 [==============================] - 7165s 16s/step - total_loss: 1.7018 - scce_loss: 1.0889 - perceptual_loss: 0.6129 - val_total_loss: 10.3791 - val_scce_loss: 4.5613 - val_perceptual_loss: 5.8179
# Epoch 4/500
# 440/440 [==============================] - 7167s 16s/step - total_loss: 1.5111 - scce_loss: 0.9402 - perceptual_loss: 0.5709 - val_total_loss: 10.8792 - val_scce_loss: 4.9298 - val_perceptual_loss: 5.9494
# Epoch 5/500
# 440/440 [==============================] - 7155s 16s/step - total_loss: 1.5018 - scce_loss: 0.8846 - perceptual_loss: 0.6172 - val_total_loss: 11.3874 - val_scce_loss: 5.4795 - val_perceptual_loss: 5.9079
# Epoch 6/500
# 440/440 [==============================] - 7162s 16s/step - total_loss: 1.4658 - scce_loss: 0.9310 - perceptual_loss: 0.5347 - val_total_loss: 10.3333 - val_scce_loss: 4.5592 - val_perceptual_loss: 5.7741
# Epoch 7/500
# 440/440 [==============================] - 7158s 16s/step - total_loss: 1.3908 - scce_loss: 0.8136 - perceptual_loss: 0.5772 - val_total_loss: 11.0304 - val_scce_loss: 5.3283 - val_perceptual_loss: 5.7021
# Epoch 8/500
# 440/440 [==============================] - 7166s 16s/step - total_loss: 1.4805 - scce_loss: 0.9335 - perceptual_loss: 0.5471 - val_total_loss: 11.5411 - val_scce_loss: 5.5848 - val_perceptual_loss: 5.9563
# Epoch 9/500
# 440/440 [==============================] - 7105s 16s/step - total_loss: 1.3721 - scce_loss: 0.8138 - perceptual_loss: 0.5583 - val_total_loss: 10.5586 - val_scce_loss: 4.5845 - val_perceptual_loss: 5.9740
# Epoch 10/500
# 440/440 [==============================] - 7173s 16s/step - total_loss: 1.4783 - scce_loss: 0.8766 - perceptual_loss: 0.6017 - val_total_loss: 10.8927 - val_scce_loss: 4.8378 - val_perceptual_loss: 6.0549
# Epoch 11/500
# 440/440 [==============================] - 7144s 16s/step - total_loss: 1.4424 - scce_loss: 0.8547 - perceptual_loss: 0.5878 - val_total_loss: 10.3394 - val_scce_loss: 4.4766 - val_perceptual_loss: 5.8627
# Epoch 12/500
# 440/440 [==============================] - 7188s 16s/step - total_loss: 1.4364 - scce_loss: 0.8564 - perceptual_loss: 0.5800 - val_total_loss: 10.9952 - val_scce_loss: 5.1731 - val_perceptual_loss: 5.8221
# Epoch 13/500
# 440/440 [==============================] - 7188s 16s/step - total_loss: 1.5095 - scce_loss: 0.9524 - perceptual_loss: 0.5571 - val_total_loss: 10.3683 - val_scce_loss: 4.4092 - val_perceptual_loss: 5.9591
# Epoch 14/500
# 440/440 [==============================] - 7165s 16s/step - total_loss: 1.4501 - scce_loss: 0.8709 - perceptual_loss: 0.5792 - val_total_loss: 10.8066 - val_scce_loss: 4.7577 - val_perceptual_loss: 6.0489
# Epoch 15/500
# 440/440 [==============================] - 7200s 16s/step - total_loss: 1.3932 - scce_loss: 0.8428 - perceptual_loss: 0.5505 - val_total_loss: 10.8502 - val_scce_loss: 4.9877 - val_perceptual_loss: 5.8625
# Epoch 16/500
# 440/440 [==============================] - 7186s 16s/step - total_loss: 1.8109 - scce_loss: 1.0955 - perceptual_loss: 0.7154 - val_total_loss: 10.4398 - val_scce_loss: 4.6502 - val_perceptual_loss: 5.7896
# Epoch 17/500
# 440/440 [==============================] - 7211s 16s/step - total_loss: 1.6700 - scce_loss: 1.0873 - perceptual_loss: 0.5827 - val_total_loss: 10.5159 - val_scce_loss: 4.7154 - val_perceptual_loss: 5.8005
# Epoch 18/500
# 440/440 [==============================] - 7165s 16s/step - total_loss: 1.5743 - scce_loss: 1.0186 - perceptual_loss: 0.5557 - val_total_loss: 9.9733 - val_scce_loss: 4.2914 - val_perceptual_loss: 5.6819
# Epoch 19/500
# 440/440 [==============================] - 7203s 16s/step - total_loss: 1.5885 - scce_loss: 1.0477 - perceptual_loss: 0.5408 - val_total_loss: 10.4197 - val_scce_loss: 4.6427 - val_perceptual_loss: 5.7770
# Epoch 20/500
# 440/440 [==============================] - 7229s 16s/step - total_loss: 1.6477 - scce_loss: 1.0779 - perceptual_loss: 0.5698 - val_total_loss: 10.7246 - val_scce_loss: 4.9212 - val_perceptual_loss: 5.8034
# Epoch 21/500
# 440/440 [==============================] - 7202s 16s/step - total_loss: 1.6784 - scce_loss: 1.0868 - perceptual_loss: 0.5916 - val_total_loss: 10.6632 - val_scce_loss: 4.6994 - val_perceptual_loss: 5.9639
# Epoch 22/500
# 440/440 [==============================] - 7166s 16s/step - total_loss: 1.6510 - scce_loss: 1.0662 - perceptual_loss: 0.5848 - val_total_loss: 10.5432 - val_scce_loss: 4.7984 - val_perceptual_loss: 5.7449
# Epoch 23/500
# 440/440 [==============================] - 7167s 16s/step - total_loss: 1.6563 - scce_loss: 1.0731 - perceptual_loss: 0.5832 - val_total_loss: 10.1179 - val_scce_loss: 4.4206 - val_perceptual_loss: 5.6973
# Epoch 24/500
# 440/440 [==============================] - 7156s 16s/step - total_loss: 1.6864 - scce_loss: 1.0928 - perceptual_loss: 0.5936 - val_total_loss: 10.3394 - val_scce_loss: 4.4181 - val_perceptual_loss: 5.9214
# Epoch 25/500
# 440/440 [==============================] - 7146s 16s/step - total_loss: 1.6406 - scce_loss: 1.0727 - perceptual_loss: 0.5679 - val_total_loss: 9.9434 - val_scce_loss: 4.2270 - val_perceptual_loss: 5.7164
# Epoch 26/500
# 440/440 [==============================] - 7162s 16s/step - total_loss: 3.1308 - scce_loss: 1.2809 - perceptual_loss: 1.8499 - val_total_loss: 10.2048 - val_scce_loss: 4.4178 - val_perceptual_loss: 5.7870
# Epoch 27/500
# 440/440 [==============================] - 7149s 16s/step - total_loss: 1.6809 - scce_loss: 1.0941 - perceptual_loss: 0.5869 - val_total_loss: 10.1885 - val_scce_loss: 4.5108 - val_perceptual_loss: 5.6778
# Epoch 28/500
# 440/440 [==============================] - 7246s 16s/step - total_loss: 1.6368 - scce_loss: 1.0751 - perceptual_loss: 0.5617 - val_total_loss: 10.2628 - val_scce_loss: 4.4261 - val_perceptual_loss: 5.8367
# Epoch 29/500
# 440/440 [==============================] - 7194s 16s/step - total_loss: 1.6091 - scce_loss: 1.0519 - perceptual_loss: 0.5571 - val_total_loss: 10.4015 - val_scce_loss: 4.5377 - val_perceptual_loss: 5.8637
# Epoch 30/500
# 440/440 [==============================] - 7195s 16s/step - total_loss: 1.5700 - scce_loss: 0.9534 - perceptual_loss: 0.6166 - val_total_loss: 10.2646 - val_scce_loss: 4.4936 - val_perceptual_loss: 5.7710
# Epoch 31/500
# 440/440 [==============================] - 7098s 16s/step - total_loss: 1.4758 - scce_loss: 0.9541 - perceptual_loss: 0.5217 - val_total_loss: 10.2208 - val_scce_loss: 4.4715 - val_perceptual_loss: 5.7494
# Epoch 32/500
# 440/440 [==============================] - 7130s 16s/step - total_loss: 1.7082 - scce_loss: 1.1376 - perceptual_loss: 0.5706 - val_total_loss: 10.1194 - val_scce_loss: 4.2668 - val_perceptual_loss: 5.8526
# Epoch 33/500
# 440/440 [==============================] - 7176s 16s/step - total_loss: 1.6696 - scce_loss: 1.0664 - perceptual_loss: 0.6032 - val_total_loss: 10.0340 - val_scce_loss: 4.2698 - val_perceptual_loss: 5.7642
# Epoch 34/500
# 440/440 [==============================] - 7167s 16s/step - total_loss: 1.6215 - scce_loss: 1.0465 - perceptual_loss: 0.5750 - val_total_loss: 10.1225 - val_scce_loss: 4.3746 - val_perceptual_loss: 5.7478
# Epoch 35/500
# 440/440 [==============================] - 7148s 16s/step - total_loss: 1.6242 - scce_loss: 1.0362 - perceptual_loss: 0.5880 - val_total_loss: 10.0571 - val_scce_loss: 4.3028 - val_perceptual_loss: 5.7543
# Epoch 36/500
# 440/440 [==============================] - 7226s 16s/step - total_loss: 1.6688 - scce_loss: 1.1134 - perceptual_loss: 0.5554 - val_total_loss: 10.1331 - val_scce_loss: 4.2945 - val_perceptual_loss: 5.8385
# Epoch 37/500
# 440/440 [==============================] - 7196s 16s/step - total_loss: 1.6086 - scce_loss: 1.0370 - perceptual_loss: 0.5716 - val_total_loss: 9.8147 - val_scce_loss: 4.1318 - val_perceptual_loss: 5.6829
# Epoch 38/500
# 440/440 [==============================] - 7224s 16s/step - total_loss: 1.6507 - scce_loss: 1.0624 - perceptual_loss: 0.5883 - val_total_loss: 10.1042 - val_scce_loss: 4.4073 - val_perceptual_loss: 5.6969
# Epoch 39/500
#  55/440 [==>...........................] - ETA: 30:30 - total_loss: 1.7123 - scce_loss: 1.1575 - perceptual_loss: 0.5548
