# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0, 1, 2, 3, 4, 5, 6, 7"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
for device in tf.config.list_physical_devices("GPU"):
    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-08-10 15:39:01.387388: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-10 15:39:04.566038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22302 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.567097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22302 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:25:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.567952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22302 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.568708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22302 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.569595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 22302 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.570400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 22302 MB memory:  -> device: 5, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.571209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 22302 MB memory:  -> device: 6, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2022-08-10 15:39:04.572015: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 22302 MB memory:  -> device: 7, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:e1:00.0, compute capability: 8.6

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/moving_mnist_video.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
#dataset_length = 1578 
dataset_length = 10000
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = normalize(element)
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
dataset = (dataset.shuffle(5000, reshuffle_each_iteration=True, seed=8)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(64)
                          #.map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.padded_batch(64)
                              #.map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
take_train = [2, 8, 10, 16, 22, 33, 34, 49]
train_sample_data = postprocess({key: value[take_train] for key, value in train_sample_data.items()})
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
take_validation = [9, 14, 36, 42, 45, 47, 49, 63]
validation_sample_data = postprocess({key: value[take_validation] for key, value in validation_sample_data.items()})
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_images(train_sample_data["last_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = "../../../logs/ganime/transformers/moving_mnist_video_2022-08-09_06-30-56" #get_logdir("../../../logs/ganime/transformers", experiment_name="moving_mnist_video")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='val_total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
images = train_sample_data["y"][:,0,...]

# %%
train_sample_data["y"].shape
# Out:
# TensorShape([8, 20, 64, 64, 3])

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 512, 16, 16) = 131072 dimensions.
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# 2022-08-10 15:39:19.075536: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-08-10 15:39:20.696432: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# Some layers of TFGPT2LMHeadModel were not initialized from the model checkpoint at gpt2-medium and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Restoring weights from ../../../checkpoints/moving_mnist_video/checkpoint

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, initial_epoch=147, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 148/2000
# 2022-08-10 15:44:33.037730: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:33.950972: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:34.819413: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:35.891875: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:37.197757: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:38.581642: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:39.897410: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-10 15:44:41.666732: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 62/62 [==============================] - 793s 9s/step - total_loss: 0.5100 - scce_loss: 0.5100 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6305 - val_scce_loss: 0.6305 - val_perceptual_loss: 0.0000e+00
# Epoch 149/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.5074 - scce_loss: 0.5074 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6309 - val_scce_loss: 0.6309 - val_perceptual_loss: 0.0000e+00
# Epoch 150/2000
# 62/62 [==============================] - 459s 7s/step - total_loss: 0.5058 - scce_loss: 0.5058 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6240 - val_scce_loss: 0.6240 - val_perceptual_loss: 0.0000e+00
# Epoch 151/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.5048 - scce_loss: 0.5048 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6284 - val_scce_loss: 0.6284 - val_perceptual_loss: 0.0000e+00
# Epoch 152/2000
# 62/62 [==============================] - 458s 7s/step - total_loss: 0.5036 - scce_loss: 0.5036 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6149 - val_scce_loss: 0.6149 - val_perceptual_loss: 0.0000e+00
# Epoch 153/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.5031 - scce_loss: 0.5031 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6422 - val_scce_loss: 0.6422 - val_perceptual_loss: 0.0000e+00
# Epoch 154/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.5031 - scce_loss: 0.5031 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6284 - val_scce_loss: 0.6284 - val_perceptual_loss: 0.0000e+00
# Epoch 155/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.5021 - scce_loss: 0.5021 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6444 - val_scce_loss: 0.6444 - val_perceptual_loss: 0.0000e+00
# Epoch 156/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.5028 - scce_loss: 0.5028 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6491 - val_scce_loss: 0.6491 - val_perceptual_loss: 0.0000e+00
# Epoch 157/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4995 - scce_loss: 0.4995 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6539 - val_scce_loss: 0.6539 - val_perceptual_loss: 0.0000e+00
# Epoch 158/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4982 - scce_loss: 0.4982 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6276 - val_scce_loss: 0.6276 - val_perceptual_loss: 0.0000e+00
# Epoch 159/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4992 - scce_loss: 0.4992 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6335 - val_scce_loss: 0.6335 - val_perceptual_loss: 0.0000e+00
# Epoch 160/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4987 - scce_loss: 0.4987 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6429 - val_scce_loss: 0.6429 - val_perceptual_loss: 0.0000e+00
# Epoch 161/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4994 - scce_loss: 0.4994 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6370 - val_scce_loss: 0.6370 - val_perceptual_loss: 0.0000e+00
# Epoch 162/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4992 - scce_loss: 0.4992 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6571 - val_scce_loss: 0.6571 - val_perceptual_loss: 0.0000e+00
# Epoch 163/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4980 - scce_loss: 0.4980 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6310 - val_scce_loss: 0.6310 - val_perceptual_loss: 0.0000e+00
# Epoch 164/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4970 - scce_loss: 0.4970 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6502 - val_scce_loss: 0.6502 - val_perceptual_loss: 0.0000e+00
# Epoch 165/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4971 - scce_loss: 0.4971 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6337 - val_scce_loss: 0.6337 - val_perceptual_loss: 0.0000e+00
# Epoch 166/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4961 - scce_loss: 0.4961 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6545 - val_scce_loss: 0.6545 - val_perceptual_loss: 0.0000e+00
# Epoch 167/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4952 - scce_loss: 0.4952 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6443 - val_scce_loss: 0.6443 - val_perceptual_loss: 0.0000e+00
# Epoch 168/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4967 - scce_loss: 0.4967 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6429 - val_scce_loss: 0.6429 - val_perceptual_loss: 0.0000e+00
# Epoch 169/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4957 - scce_loss: 0.4957 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6460 - val_scce_loss: 0.6460 - val_perceptual_loss: 0.0000e+00
# Epoch 170/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4955 - scce_loss: 0.4955 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6348 - val_scce_loss: 0.6348 - val_perceptual_loss: 0.0000e+00
# Epoch 171/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4927 - scce_loss: 0.4927 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6353 - val_scce_loss: 0.6353 - val_perceptual_loss: 0.0000e+00
# Epoch 172/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4937 - scce_loss: 0.4937 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6530 - val_scce_loss: 0.6530 - val_perceptual_loss: 0.0000e+00
# Epoch 173/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4953 - scce_loss: 0.4953 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6431 - val_scce_loss: 0.6431 - val_perceptual_loss: 0.0000e+00
# Epoch 174/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4930 - scce_loss: 0.4930 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6467 - val_scce_loss: 0.6467 - val_perceptual_loss: 0.0000e+00
# Epoch 175/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4944 - scce_loss: 0.4944 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6505 - val_scce_loss: 0.6505 - val_perceptual_loss: 0.0000e+00
# Epoch 176/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4946 - scce_loss: 0.4946 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6303 - val_scce_loss: 0.6303 - val_perceptual_loss: 0.0000e+00
# Epoch 177/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4928 - scce_loss: 0.4928 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6324 - val_scce_loss: 0.6324 - val_perceptual_loss: 0.0000e+00
# Epoch 178/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4922 - scce_loss: 0.4922 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6427 - val_scce_loss: 0.6427 - val_perceptual_loss: 0.0000e+00
# Epoch 179/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4924 - scce_loss: 0.4924 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6482 - val_scce_loss: 0.6482 - val_perceptual_loss: 0.0000e+00
# Epoch 180/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4914 - scce_loss: 0.4914 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6424 - val_scce_loss: 0.6424 - val_perceptual_loss: 0.0000e+00
# Epoch 181/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4922 - scce_loss: 0.4922 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6536 - val_scce_loss: 0.6536 - val_perceptual_loss: 0.0000e+00
# Epoch 182/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4924 - scce_loss: 0.4924 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6332 - val_scce_loss: 0.6332 - val_perceptual_loss: 0.0000e+00
# Epoch 183/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4925 - scce_loss: 0.4925 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6242 - val_scce_loss: 0.6242 - val_perceptual_loss: 0.0000e+00
# Epoch 184/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4907 - scce_loss: 0.4907 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6518 - val_scce_loss: 0.6518 - val_perceptual_loss: 0.0000e+00
# Epoch 185/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4916 - scce_loss: 0.4916 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6579 - val_scce_loss: 0.6579 - val_perceptual_loss: 0.0000e+00
# Epoch 186/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4896 - scce_loss: 0.4896 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6609 - val_scce_loss: 0.6609 - val_perceptual_loss: 0.0000e+00
# Epoch 187/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4892 - scce_loss: 0.4892 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6527 - val_scce_loss: 0.6527 - val_perceptual_loss: 0.0000e+00
# Epoch 188/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4905 - scce_loss: 0.4905 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6726 - val_scce_loss: 0.6726 - val_perceptual_loss: 0.0000e+00
# Epoch 189/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4868 - scce_loss: 0.4868 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6384 - val_scce_loss: 0.6384 - val_perceptual_loss: 0.0000e+00
# Epoch 190/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4897 - scce_loss: 0.4897 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6617 - val_scce_loss: 0.6617 - val_perceptual_loss: 0.0000e+00
# Epoch 191/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4902 - scce_loss: 0.4902 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6445 - val_scce_loss: 0.6445 - val_perceptual_loss: 0.0000e+00
# Epoch 192/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4878 - scce_loss: 0.4878 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6708 - val_scce_loss: 0.6708 - val_perceptual_loss: 0.0000e+00
# Epoch 193/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4885 - scce_loss: 0.4885 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6451 - val_scce_loss: 0.6451 - val_perceptual_loss: 0.0000e+00
# Epoch 194/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4863 - scce_loss: 0.4863 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6415 - val_scce_loss: 0.6415 - val_perceptual_loss: 0.0000e+00
# Epoch 195/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4867 - scce_loss: 0.4867 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6498 - val_scce_loss: 0.6498 - val_perceptual_loss: 0.0000e+00
# Epoch 196/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4880 - scce_loss: 0.4880 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6598 - val_scce_loss: 0.6598 - val_perceptual_loss: 0.0000e+00
# Epoch 197/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4862 - scce_loss: 0.4862 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6591 - val_scce_loss: 0.6591 - val_perceptual_loss: 0.0000e+00
# Epoch 198/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4849 - scce_loss: 0.4849 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6555 - val_scce_loss: 0.6555 - val_perceptual_loss: 0.0000e+00
# Epoch 199/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4832 - scce_loss: 0.4832 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6656 - val_scce_loss: 0.6656 - val_perceptual_loss: 0.0000e+00
# Epoch 200/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4840 - scce_loss: 0.4840 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6585 - val_scce_loss: 0.6585 - val_perceptual_loss: 0.0000e+00
# Epoch 201/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4846 - scce_loss: 0.4846 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6719 - val_scce_loss: 0.6719 - val_perceptual_loss: 0.0000e+00
# Epoch 202/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4836 - scce_loss: 0.4836 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6599 - val_scce_loss: 0.6599 - val_perceptual_loss: 0.0000e+00
# Epoch 203/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4827 - scce_loss: 0.4827 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6647 - val_scce_loss: 0.6647 - val_perceptual_loss: 0.0000e+00
# Epoch 204/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4841 - scce_loss: 0.4841 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6614 - val_scce_loss: 0.6614 - val_perceptual_loss: 0.0000e+00
# Epoch 205/2000
# 62/62 [==============================] - 392s 6s/step - total_loss: 0.4832 - scce_loss: 0.4832 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6631 - val_scce_loss: 0.6631 - val_perceptual_loss: 0.0000e+00
# Epoch 206/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4807 - scce_loss: 0.4807 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6529 - val_scce_loss: 0.6529 - val_perceptual_loss: 0.0000e+00
# Epoch 207/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4809 - scce_loss: 0.4809 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6565 - val_scce_loss: 0.6565 - val_perceptual_loss: 0.0000e+00
# Epoch 208/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4816 - scce_loss: 0.4816 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6620 - val_scce_loss: 0.6620 - val_perceptual_loss: 0.0000e+00
# Epoch 209/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4803 - scce_loss: 0.4803 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6681 - val_scce_loss: 0.6681 - val_perceptual_loss: 0.0000e+00
# Epoch 210/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4834 - scce_loss: 0.4834 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6534 - val_scce_loss: 0.6534 - val_perceptual_loss: 0.0000e+00
# Epoch 211/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4819 - scce_loss: 0.4819 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6692 - val_scce_loss: 0.6692 - val_perceptual_loss: 0.0000e+00
# Epoch 212/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4782 - scce_loss: 0.4782 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6630 - val_scce_loss: 0.6630 - val_perceptual_loss: 0.0000e+00
# Epoch 213/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4793 - scce_loss: 0.4793 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6847 - val_scce_loss: 0.6847 - val_perceptual_loss: 0.0000e+00
# Epoch 214/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4789 - scce_loss: 0.4789 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6645 - val_scce_loss: 0.6645 - val_perceptual_loss: 0.0000e+00
# Epoch 215/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4791 - scce_loss: 0.4791 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6467 - val_scce_loss: 0.6467 - val_perceptual_loss: 0.0000e+00
# Epoch 216/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4788 - scce_loss: 0.4788 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6695 - val_scce_loss: 0.6695 - val_perceptual_loss: 0.0000e+00
# Epoch 217/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4774 - scce_loss: 0.4774 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6805 - val_scce_loss: 0.6805 - val_perceptual_loss: 0.0000e+00
# Epoch 218/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4787 - scce_loss: 0.4787 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6725 - val_scce_loss: 0.6725 - val_perceptual_loss: 0.0000e+00
# Epoch 219/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4770 - scce_loss: 0.4770 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6627 - val_scce_loss: 0.6627 - val_perceptual_loss: 0.0000e+00
# Epoch 220/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4769 - scce_loss: 0.4769 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6766 - val_scce_loss: 0.6766 - val_perceptual_loss: 0.0000e+00
# Epoch 221/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4789 - scce_loss: 0.4789 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6672 - val_scce_loss: 0.6672 - val_perceptual_loss: 0.0000e+00
# Epoch 222/2000
# 62/62 [==============================] - 404s 7s/step - total_loss: 0.4772 - scce_loss: 0.4772 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6735 - val_scce_loss: 0.6735 - val_perceptual_loss: 0.0000e+00
# Epoch 223/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4777 - scce_loss: 0.4777 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6776 - val_scce_loss: 0.6776 - val_perceptual_loss: 0.0000e+00
# Epoch 224/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4784 - scce_loss: 0.4784 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6737 - val_scce_loss: 0.6737 - val_perceptual_loss: 0.0000e+00
# Epoch 225/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4754 - scce_loss: 0.4754 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6785 - val_scce_loss: 0.6785 - val_perceptual_loss: 0.0000e+00
# Epoch 226/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4781 - scce_loss: 0.4781 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6793 - val_scce_loss: 0.6793 - val_perceptual_loss: 0.0000e+00
# Epoch 227/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4765 - scce_loss: 0.4765 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6655 - val_scce_loss: 0.6655 - val_perceptual_loss: 0.0000e+00
# Epoch 228/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4748 - scce_loss: 0.4748 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6688 - val_scce_loss: 0.6688 - val_perceptual_loss: 0.0000e+00
# Epoch 229/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4734 - scce_loss: 0.4734 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6896 - val_scce_loss: 0.6896 - val_perceptual_loss: 0.0000e+00
# Epoch 230/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4759 - scce_loss: 0.4759 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6945 - val_scce_loss: 0.6945 - val_perceptual_loss: 0.0000e+00
# Epoch 231/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4741 - scce_loss: 0.4741 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6737 - val_scce_loss: 0.6737 - val_perceptual_loss: 0.0000e+00
# Epoch 232/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4745 - scce_loss: 0.4745 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6830 - val_scce_loss: 0.6830 - val_perceptual_loss: 0.0000e+00
# Epoch 233/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4744 - scce_loss: 0.4744 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6809 - val_scce_loss: 0.6809 - val_perceptual_loss: 0.0000e+00
# Epoch 234/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4749 - scce_loss: 0.4749 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6963 - val_scce_loss: 0.6963 - val_perceptual_loss: 0.0000e+00
# Epoch 235/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4735 - scce_loss: 0.4735 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6642 - val_scce_loss: 0.6642 - val_perceptual_loss: 0.0000e+00
# Epoch 236/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4758 - scce_loss: 0.4758 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6505 - val_scce_loss: 0.6505 - val_perceptual_loss: 0.0000e+00
# Epoch 237/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4738 - scce_loss: 0.4738 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6828 - val_scce_loss: 0.6828 - val_perceptual_loss: 0.0000e+00
# Epoch 238/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4717 - scce_loss: 0.4717 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6630 - val_scce_loss: 0.6630 - val_perceptual_loss: 0.0000e+00
# Epoch 239/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4734 - scce_loss: 0.4734 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7085 - val_scce_loss: 0.7085 - val_perceptual_loss: 0.0000e+00
# Epoch 240/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4752 - scce_loss: 0.4752 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6764 - val_scce_loss: 0.6764 - val_perceptual_loss: 0.0000e+00
# Epoch 241/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4731 - scce_loss: 0.4731 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6684 - val_scce_loss: 0.6684 - val_perceptual_loss: 0.0000e+00
# Epoch 242/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4723 - scce_loss: 0.4723 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6846 - val_scce_loss: 0.6846 - val_perceptual_loss: 0.0000e+00
# Epoch 243/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4719 - scce_loss: 0.4719 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6883 - val_scce_loss: 0.6883 - val_perceptual_loss: 0.0000e+00
# Epoch 244/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4708 - scce_loss: 0.4708 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6672 - val_scce_loss: 0.6672 - val_perceptual_loss: 0.0000e+00
# Epoch 245/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4717 - scce_loss: 0.4717 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7084 - val_scce_loss: 0.7084 - val_perceptual_loss: 0.0000e+00
# Epoch 246/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4711 - scce_loss: 0.4711 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6711 - val_scce_loss: 0.6711 - val_perceptual_loss: 0.0000e+00
# Epoch 247/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4716 - scce_loss: 0.4716 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6931 - val_scce_loss: 0.6931 - val_perceptual_loss: 0.0000e+00
# Epoch 248/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4703 - scce_loss: 0.4703 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6870 - val_scce_loss: 0.6870 - val_perceptual_loss: 0.0000e+00
# Epoch 249/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4704 - scce_loss: 0.4704 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6859 - val_scce_loss: 0.6859 - val_perceptual_loss: 0.0000e+00
# Epoch 250/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4702 - scce_loss: 0.4702 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6971 - val_scce_loss: 0.6971 - val_perceptual_loss: 0.0000e+00
# Epoch 251/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4703 - scce_loss: 0.4703 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6745 - val_scce_loss: 0.6745 - val_perceptual_loss: 0.0000e+00
# Epoch 252/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4696 - scce_loss: 0.4696 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6985 - val_scce_loss: 0.6985 - val_perceptual_loss: 0.0000e+00
# Epoch 253/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4691 - scce_loss: 0.4691 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6693 - val_scce_loss: 0.6693 - val_perceptual_loss: 0.0000e+00
# Epoch 254/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4697 - scce_loss: 0.4697 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6790 - val_scce_loss: 0.6790 - val_perceptual_loss: 0.0000e+00
# Epoch 255/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4700 - scce_loss: 0.4700 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6950 - val_scce_loss: 0.6950 - val_perceptual_loss: 0.0000e+00
# Epoch 256/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4683 - scce_loss: 0.4683 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6912 - val_scce_loss: 0.6912 - val_perceptual_loss: 0.0000e+00
# Epoch 257/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4687 - scce_loss: 0.4687 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6751 - val_scce_loss: 0.6751 - val_perceptual_loss: 0.0000e+00
# Epoch 258/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4675 - scce_loss: 0.4675 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6714 - val_scce_loss: 0.6714 - val_perceptual_loss: 0.0000e+00
# Epoch 259/2000
# 62/62 [==============================] - 392s 6s/step - total_loss: 0.4665 - scce_loss: 0.4665 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6547 - val_scce_loss: 0.6547 - val_perceptual_loss: 0.0000e+00
# Epoch 260/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4684 - scce_loss: 0.4684 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6842 - val_scce_loss: 0.6842 - val_perceptual_loss: 0.0000e+00
# Epoch 261/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4670 - scce_loss: 0.4670 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6747 - val_scce_loss: 0.6747 - val_perceptual_loss: 0.0000e+00
# Epoch 262/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4676 - scce_loss: 0.4676 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6804 - val_scce_loss: 0.6804 - val_perceptual_loss: 0.0000e+00
# Epoch 263/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4678 - scce_loss: 0.4678 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6713 - val_scce_loss: 0.6713 - val_perceptual_loss: 0.0000e+00
# Epoch 264/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4666 - scce_loss: 0.4666 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6706 - val_scce_loss: 0.6706 - val_perceptual_loss: 0.0000e+00
# Epoch 265/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4673 - scce_loss: 0.4673 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6708 - val_scce_loss: 0.6708 - val_perceptual_loss: 0.0000e+00
# Epoch 266/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4632 - scce_loss: 0.4632 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6751 - val_scce_loss: 0.6751 - val_perceptual_loss: 0.0000e+00
# Epoch 267/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4671 - scce_loss: 0.4671 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6815 - val_scce_loss: 0.6815 - val_perceptual_loss: 0.0000e+00
# Epoch 268/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4656 - scce_loss: 0.4656 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6530 - val_scce_loss: 0.6530 - val_perceptual_loss: 0.0000e+00
# Epoch 269/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4661 - scce_loss: 0.4661 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6638 - val_scce_loss: 0.6638 - val_perceptual_loss: 0.0000e+00
# Epoch 270/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4658 - scce_loss: 0.4658 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6677 - val_scce_loss: 0.6677 - val_perceptual_loss: 0.0000e+00
# Epoch 271/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4645 - scce_loss: 0.4645 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6847 - val_scce_loss: 0.6847 - val_perceptual_loss: 0.0000e+00
# Epoch 272/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4650 - scce_loss: 0.4650 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7124 - val_scce_loss: 0.7124 - val_perceptual_loss: 0.0000e+00
# Epoch 273/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4650 - scce_loss: 0.4650 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6887 - val_scce_loss: 0.6887 - val_perceptual_loss: 0.0000e+00
# Epoch 274/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4629 - scce_loss: 0.4629 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6764 - val_scce_loss: 0.6764 - val_perceptual_loss: 0.0000e+00
# Epoch 275/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4664 - scce_loss: 0.4664 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6783 - val_scce_loss: 0.6783 - val_perceptual_loss: 0.0000e+00
# Epoch 276/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4653 - scce_loss: 0.4653 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6843 - val_scce_loss: 0.6843 - val_perceptual_loss: 0.0000e+00
# Epoch 277/2000
# 62/62 [==============================] - 402s 6s/step - total_loss: 0.4637 - scce_loss: 0.4637 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6970 - val_scce_loss: 0.6970 - val_perceptual_loss: 0.0000e+00
# Epoch 278/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4654 - scce_loss: 0.4654 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6752 - val_scce_loss: 0.6752 - val_perceptual_loss: 0.0000e+00
# Epoch 279/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4620 - scce_loss: 0.4620 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6796 - val_scce_loss: 0.6796 - val_perceptual_loss: 0.0000e+00
# Epoch 280/2000
# 62/62 [==============================] - 392s 6s/step - total_loss: 0.4641 - scce_loss: 0.4641 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6869 - val_scce_loss: 0.6869 - val_perceptual_loss: 0.0000e+00
# Epoch 281/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4625 - scce_loss: 0.4625 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6624 - val_scce_loss: 0.6624 - val_perceptual_loss: 0.0000e+00
# Epoch 282/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4639 - scce_loss: 0.4639 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7063 - val_scce_loss: 0.7063 - val_perceptual_loss: 0.0000e+00
# Epoch 283/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4646 - scce_loss: 0.4646 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6691 - val_scce_loss: 0.6691 - val_perceptual_loss: 0.0000e+00
# Epoch 284/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4632 - scce_loss: 0.4632 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6711 - val_scce_loss: 0.6711 - val_perceptual_loss: 0.0000e+00
# Epoch 285/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4627 - scce_loss: 0.4627 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6715 - val_scce_loss: 0.6715 - val_perceptual_loss: 0.0000e+00
# Epoch 286/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4629 - scce_loss: 0.4629 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6897 - val_scce_loss: 0.6897 - val_perceptual_loss: 0.0000e+00
# Epoch 287/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4628 - scce_loss: 0.4628 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7133 - val_scce_loss: 0.7133 - val_perceptual_loss: 0.0000e+00
# Epoch 288/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4621 - scce_loss: 0.4621 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6668 - val_scce_loss: 0.6668 - val_perceptual_loss: 0.0000e+00
# Epoch 289/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4608 - scce_loss: 0.4608 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6849 - val_scce_loss: 0.6849 - val_perceptual_loss: 0.0000e+00
# Epoch 290/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4615 - scce_loss: 0.4615 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6809 - val_scce_loss: 0.6809 - val_perceptual_loss: 0.0000e+00
# Epoch 291/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4612 - scce_loss: 0.4612 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6764 - val_scce_loss: 0.6764 - val_perceptual_loss: 0.0000e+00
# Epoch 292/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4613 - scce_loss: 0.4613 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6935 - val_scce_loss: 0.6935 - val_perceptual_loss: 0.0000e+00
# Epoch 293/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4608 - scce_loss: 0.4608 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6922 - val_scce_loss: 0.6922 - val_perceptual_loss: 0.0000e+00
# Epoch 294/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4613 - scce_loss: 0.4613 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6747 - val_scce_loss: 0.6747 - val_perceptual_loss: 0.0000e+00
# Epoch 295/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4607 - scce_loss: 0.4607 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6887 - val_scce_loss: 0.6887 - val_perceptual_loss: 0.0000e+00
# Epoch 296/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4612 - scce_loss: 0.4612 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6963 - val_scce_loss: 0.6963 - val_perceptual_loss: 0.0000e+00
# Epoch 297/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4597 - scce_loss: 0.4597 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6900 - val_scce_loss: 0.6900 - val_perceptual_loss: 0.0000e+00
# Epoch 298/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4610 - scce_loss: 0.4610 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6798 - val_scce_loss: 0.6798 - val_perceptual_loss: 0.0000e+00
# Epoch 299/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4596 - scce_loss: 0.4596 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6702 - val_scce_loss: 0.6702 - val_perceptual_loss: 0.0000e+00
# Epoch 300/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4596 - scce_loss: 0.4596 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6915 - val_scce_loss: 0.6915 - val_perceptual_loss: 0.0000e+00
# Epoch 301/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4599 - scce_loss: 0.4599 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6990 - val_scce_loss: 0.6990 - val_perceptual_loss: 0.0000e+00
# Epoch 302/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4608 - scce_loss: 0.4608 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6835 - val_scce_loss: 0.6835 - val_perceptual_loss: 0.0000e+00
# Epoch 303/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4595 - scce_loss: 0.4595 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6727 - val_scce_loss: 0.6727 - val_perceptual_loss: 0.0000e+00
# Epoch 304/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4605 - scce_loss: 0.4605 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6837 - val_scce_loss: 0.6837 - val_perceptual_loss: 0.0000e+00
# Epoch 305/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4584 - scce_loss: 0.4584 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6725 - val_scce_loss: 0.6725 - val_perceptual_loss: 0.0000e+00
# Epoch 306/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4596 - scce_loss: 0.4596 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6997 - val_scce_loss: 0.6997 - val_perceptual_loss: 0.0000e+00
# Epoch 307/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4576 - scce_loss: 0.4576 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6754 - val_scce_loss: 0.6754 - val_perceptual_loss: 0.0000e+00
# Epoch 308/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4580 - scce_loss: 0.4580 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6927 - val_scce_loss: 0.6927 - val_perceptual_loss: 0.0000e+00
# Epoch 309/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4571 - scce_loss: 0.4571 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6900 - val_scce_loss: 0.6900 - val_perceptual_loss: 0.0000e+00
# Epoch 310/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4579 - scce_loss: 0.4579 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6863 - val_scce_loss: 0.6863 - val_perceptual_loss: 0.0000e+00
# Epoch 311/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4577 - scce_loss: 0.4577 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6950 - val_scce_loss: 0.6950 - val_perceptual_loss: 0.0000e+00
# Epoch 312/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4561 - scce_loss: 0.4561 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6956 - val_scce_loss: 0.6956 - val_perceptual_loss: 0.0000e+00
# Epoch 313/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4570 - scce_loss: 0.4570 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6937 - val_scce_loss: 0.6937 - val_perceptual_loss: 0.0000e+00
# Epoch 314/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4570 - scce_loss: 0.4570 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6721 - val_scce_loss: 0.6721 - val_perceptual_loss: 0.0000e+00
# Epoch 315/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4570 - scce_loss: 0.4570 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6873 - val_scce_loss: 0.6873 - val_perceptual_loss: 0.0000e+00
# Epoch 316/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4567 - scce_loss: 0.4567 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6853 - val_scce_loss: 0.6853 - val_perceptual_loss: 0.0000e+00
# Epoch 317/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4558 - scce_loss: 0.4558 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6823 - val_scce_loss: 0.6823 - val_perceptual_loss: 0.0000e+00
# Epoch 318/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4564 - scce_loss: 0.4564 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6972 - val_scce_loss: 0.6972 - val_perceptual_loss: 0.0000e+00
# Epoch 319/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4553 - scce_loss: 0.4553 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6855 - val_scce_loss: 0.6855 - val_perceptual_loss: 0.0000e+00
# Epoch 320/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4552 - scce_loss: 0.4552 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7034 - val_scce_loss: 0.7034 - val_perceptual_loss: 0.0000e+00
# Epoch 321/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4571 - scce_loss: 0.4571 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7009 - val_scce_loss: 0.7009 - val_perceptual_loss: 0.0000e+00
# Epoch 322/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4568 - scce_loss: 0.4568 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6920 - val_scce_loss: 0.6920 - val_perceptual_loss: 0.0000e+00
# Epoch 323/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4563 - scce_loss: 0.4563 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6861 - val_scce_loss: 0.6861 - val_perceptual_loss: 0.0000e+00
# Epoch 324/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4543 - scce_loss: 0.4543 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6842 - val_scce_loss: 0.6842 - val_perceptual_loss: 0.0000e+00
# Epoch 325/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4556 - scce_loss: 0.4556 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6959 - val_scce_loss: 0.6959 - val_perceptual_loss: 0.0000e+00
# Epoch 326/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4526 - scce_loss: 0.4526 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6915 - val_scce_loss: 0.6915 - val_perceptual_loss: 0.0000e+00
# Epoch 327/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4556 - scce_loss: 0.4556 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6984 - val_scce_loss: 0.6984 - val_perceptual_loss: 0.0000e+00
# Epoch 328/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4528 - scce_loss: 0.4528 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6918 - val_scce_loss: 0.6918 - val_perceptual_loss: 0.0000e+00
# Epoch 329/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4552 - scce_loss: 0.4552 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6999 - val_scce_loss: 0.6999 - val_perceptual_loss: 0.0000e+00
# Epoch 330/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4560 - scce_loss: 0.4560 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7069 - val_scce_loss: 0.7069 - val_perceptual_loss: 0.0000e+00
# Epoch 331/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4551 - scce_loss: 0.4551 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6969 - val_scce_loss: 0.6969 - val_perceptual_loss: 0.0000e+00
# Epoch 332/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4541 - scce_loss: 0.4541 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7018 - val_scce_loss: 0.7018 - val_perceptual_loss: 0.0000e+00
# Epoch 333/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4550 - scce_loss: 0.4550 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6918 - val_scce_loss: 0.6918 - val_perceptual_loss: 0.0000e+00
# Epoch 334/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4550 - scce_loss: 0.4550 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6772 - val_scce_loss: 0.6772 - val_perceptual_loss: 0.0000e+00
# Epoch 335/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4532 - scce_loss: 0.4532 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6876 - val_scce_loss: 0.6876 - val_perceptual_loss: 0.0000e+00
# Epoch 336/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4532 - scce_loss: 0.4532 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6998 - val_scce_loss: 0.6998 - val_perceptual_loss: 0.0000e+00
# Epoch 337/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4539 - scce_loss: 0.4539 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6948 - val_scce_loss: 0.6948 - val_perceptual_loss: 0.0000e+00
# Epoch 338/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4531 - scce_loss: 0.4531 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6805 - val_scce_loss: 0.6805 - val_perceptual_loss: 0.0000e+00
# Epoch 339/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4528 - scce_loss: 0.4528 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6878 - val_scce_loss: 0.6878 - val_perceptual_loss: 0.0000e+00
# Epoch 340/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4535 - scce_loss: 0.4535 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6780 - val_scce_loss: 0.6780 - val_perceptual_loss: 0.0000e+00
# Epoch 341/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4504 - scce_loss: 0.4504 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7070 - val_scce_loss: 0.7070 - val_perceptual_loss: 0.0000e+00
# Epoch 342/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4526 - scce_loss: 0.4526 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6954 - val_scce_loss: 0.6954 - val_perceptual_loss: 0.0000e+00
# Epoch 343/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4529 - scce_loss: 0.4529 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6846 - val_scce_loss: 0.6846 - val_perceptual_loss: 0.0000e+00
# Epoch 344/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4522 - scce_loss: 0.4522 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7170 - val_scce_loss: 0.7170 - val_perceptual_loss: 0.0000e+00
# Epoch 345/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4523 - scce_loss: 0.4523 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6795 - val_scce_loss: 0.6795 - val_perceptual_loss: 0.0000e+00
# Epoch 346/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4508 - scce_loss: 0.4508 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6976 - val_scce_loss: 0.6976 - val_perceptual_loss: 0.0000e+00
# Epoch 347/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4524 - scce_loss: 0.4524 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6940 - val_scce_loss: 0.6940 - val_perceptual_loss: 0.0000e+00
# Epoch 348/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4518 - scce_loss: 0.4518 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7086 - val_scce_loss: 0.7086 - val_perceptual_loss: 0.0000e+00
# Epoch 349/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4517 - scce_loss: 0.4517 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6737 - val_scce_loss: 0.6737 - val_perceptual_loss: 0.0000e+00
# Epoch 350/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4521 - scce_loss: 0.4521 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6884 - val_scce_loss: 0.6884 - val_perceptual_loss: 0.0000e+00
# Epoch 351/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4529 - scce_loss: 0.4529 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6840 - val_scce_loss: 0.6840 - val_perceptual_loss: 0.0000e+00
# Epoch 352/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4516 - scce_loss: 0.4516 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7192 - val_scce_loss: 0.7192 - val_perceptual_loss: 0.0000e+00
# Epoch 353/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4511 - scce_loss: 0.4511 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7128 - val_scce_loss: 0.7128 - val_perceptual_loss: 0.0000e+00
# Epoch 354/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4510 - scce_loss: 0.4510 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7139 - val_scce_loss: 0.7139 - val_perceptual_loss: 0.0000e+00
# Epoch 355/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4510 - scce_loss: 0.4510 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7164 - val_scce_loss: 0.7164 - val_perceptual_loss: 0.0000e+00
# Epoch 356/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4512 - scce_loss: 0.4512 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6902 - val_scce_loss: 0.6902 - val_perceptual_loss: 0.0000e+00
# Epoch 357/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4502 - scce_loss: 0.4502 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7000 - val_scce_loss: 0.7000 - val_perceptual_loss: 0.0000e+00
# Epoch 358/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4488 - scce_loss: 0.4488 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.6998 - val_scce_loss: 0.6998 - val_perceptual_loss: 0.0000e+00
# Epoch 359/2000
# ...
# Epoch 874/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4207 - scce_loss: 0.4207 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7319 - val_scce_loss: 0.7319 - val_perceptual_loss: 0.0000e+00
# Epoch 875/2000
# 62/62 [==============================] - 398s 6s/step - total_loss: 0.4203 - scce_loss: 0.4203 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7273 - val_scce_loss: 0.7273 - val_perceptual_loss: 0.0000e+00
# Epoch 876/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4190 - scce_loss: 0.4190 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7447 - val_scce_loss: 0.7447 - val_perceptual_loss: 0.0000e+00
# Epoch 877/2000
# 62/62 [==============================] - 397s 6s/step - total_loss: 0.4210 - scce_loss: 0.4210 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7368 - val_scce_loss: 0.7368 - val_perceptual_loss: 0.0000e+00
# Epoch 878/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4214 - scce_loss: 0.4214 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7461 - val_scce_loss: 0.7461 - val_perceptual_loss: 0.0000e+00
# Epoch 879/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4207 - scce_loss: 0.4207 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7452 - val_scce_loss: 0.7452 - val_perceptual_loss: 0.0000e+00
# Epoch 880/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4223 - scce_loss: 0.4223 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7502 - val_scce_loss: 0.7502 - val_perceptual_loss: 0.0000e+00
# Epoch 881/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4225 - scce_loss: 0.4225 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7333 - val_scce_loss: 0.7333 - val_perceptual_loss: 0.0000e+00
# Epoch 882/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4189 - scce_loss: 0.4189 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7232 - val_scce_loss: 0.7232 - val_perceptual_loss: 0.0000e+00
# Epoch 883/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4216 - scce_loss: 0.4216 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7594 - val_scce_loss: 0.7594 - val_perceptual_loss: 0.0000e+00
# Epoch 884/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4192 - scce_loss: 0.4192 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7525 - val_scce_loss: 0.7525 - val_perceptual_loss: 0.0000e+00
# Epoch 885/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4206 - scce_loss: 0.4206 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7508 - val_scce_loss: 0.7508 - val_perceptual_loss: 0.0000e+00
# Epoch 886/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4209 - scce_loss: 0.4209 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7518 - val_scce_loss: 0.7518 - val_perceptual_loss: 0.0000e+00
# Epoch 887/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4207 - scce_loss: 0.4207 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7500 - val_scce_loss: 0.7500 - val_perceptual_loss: 0.0000e+00
# Epoch 888/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4207 - scce_loss: 0.4207 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7466 - val_scce_loss: 0.7466 - val_perceptual_loss: 0.0000e+00
# Epoch 889/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4185 - scce_loss: 0.4185 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7255 - val_scce_loss: 0.7255 - val_perceptual_loss: 0.0000e+00
# Epoch 890/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4197 - scce_loss: 0.4197 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7295 - val_scce_loss: 0.7295 - val_perceptual_loss: 0.0000e+00
# Epoch 891/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4206 - scce_loss: 0.4206 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7279 - val_scce_loss: 0.7279 - val_perceptual_loss: 0.0000e+00
# Epoch 892/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4201 - scce_loss: 0.4201 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7171 - val_scce_loss: 0.7171 - val_perceptual_loss: 0.0000e+00
# Epoch 893/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4191 - scce_loss: 0.4191 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7302 - val_scce_loss: 0.7302 - val_perceptual_loss: 0.0000e+00
# Epoch 894/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4196 - scce_loss: 0.4196 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7474 - val_scce_loss: 0.7474 - val_perceptual_loss: 0.0000e+00
# Epoch 895/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4213 - scce_loss: 0.4213 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7255 - val_scce_loss: 0.7255 - val_perceptual_loss: 0.0000e+00
# Epoch 896/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4211 - scce_loss: 0.4211 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7153 - val_scce_loss: 0.7153 - val_perceptual_loss: 0.0000e+00
# Epoch 897/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4202 - scce_loss: 0.4202 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7399 - val_scce_loss: 0.7399 - val_perceptual_loss: 0.0000e+00
# Epoch 898/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4197 - scce_loss: 0.4197 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7263 - val_scce_loss: 0.7263 - val_perceptual_loss: 0.0000e+00
# Epoch 899/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4209 - scce_loss: 0.4209 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7264 - val_scce_loss: 0.7264 - val_perceptual_loss: 0.0000e+00
# Epoch 900/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4212 - scce_loss: 0.4212 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7489 - val_scce_loss: 0.7489 - val_perceptual_loss: 0.0000e+00
# Epoch 901/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4199 - scce_loss: 0.4199 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7253 - val_scce_loss: 0.7253 - val_perceptual_loss: 0.0000e+00
# Epoch 902/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4195 - scce_loss: 0.4195 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7368 - val_scce_loss: 0.7368 - val_perceptual_loss: 0.0000e+00
# Epoch 903/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4215 - scce_loss: 0.4215 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7638 - val_scce_loss: 0.7638 - val_perceptual_loss: 0.0000e+00
# Epoch 904/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4198 - scce_loss: 0.4198 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7406 - val_scce_loss: 0.7406 - val_perceptual_loss: 0.0000e+00
# Epoch 905/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4210 - scce_loss: 0.4210 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7427 - val_scce_loss: 0.7427 - val_perceptual_loss: 0.0000e+00
# Epoch 906/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4191 - scce_loss: 0.4191 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7173 - val_scce_loss: 0.7173 - val_perceptual_loss: 0.0000e+00
# Epoch 907/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4196 - scce_loss: 0.4196 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7282 - val_scce_loss: 0.7282 - val_perceptual_loss: 0.0000e+00
# Epoch 908/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4193 - scce_loss: 0.4193 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7417 - val_scce_loss: 0.7417 - val_perceptual_loss: 0.0000e+00
# Epoch 909/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4206 - scce_loss: 0.4206 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7326 - val_scce_loss: 0.7326 - val_perceptual_loss: 0.0000e+00
# Epoch 910/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4213 - scce_loss: 0.4213 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7325 - val_scce_loss: 0.7325 - val_perceptual_loss: 0.0000e+00
# Epoch 911/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4212 - scce_loss: 0.4212 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7363 - val_scce_loss: 0.7363 - val_perceptual_loss: 0.0000e+00
# Epoch 912/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4203 - scce_loss: 0.4203 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7486 - val_scce_loss: 0.7486 - val_perceptual_loss: 0.0000e+00
# Epoch 913/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4194 - scce_loss: 0.4194 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7303 - val_scce_loss: 0.7303 - val_perceptual_loss: 0.0000e+00
# Epoch 914/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4201 - scce_loss: 0.4201 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7135 - val_scce_loss: 0.7135 - val_perceptual_loss: 0.0000e+00
# Epoch 915/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4198 - scce_loss: 0.4198 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7229 - val_scce_loss: 0.7229 - val_perceptual_loss: 0.0000e+00
# Epoch 916/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4199 - scce_loss: 0.4199 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7346 - val_scce_loss: 0.7346 - val_perceptual_loss: 0.0000e+00
# Epoch 917/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4203 - scce_loss: 0.4203 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7340 - val_scce_loss: 0.7340 - val_perceptual_loss: 0.0000e+00
# Epoch 918/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4179 - scce_loss: 0.4179 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7449 - val_scce_loss: 0.7449 - val_perceptual_loss: 0.0000e+00
# Epoch 919/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4207 - scce_loss: 0.4207 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7277 - val_scce_loss: 0.7277 - val_perceptual_loss: 0.0000e+00
# Epoch 920/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4215 - scce_loss: 0.4215 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7482 - val_scce_loss: 0.7482 - val_perceptual_loss: 0.0000e+00
# Epoch 921/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4180 - scce_loss: 0.4180 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7467 - val_scce_loss: 0.7467 - val_perceptual_loss: 0.0000e+00
# Epoch 922/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4203 - scce_loss: 0.4203 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7436 - val_scce_loss: 0.7436 - val_perceptual_loss: 0.0000e+00
# Epoch 923/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4209 - scce_loss: 0.4209 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7346 - val_scce_loss: 0.7346 - val_perceptual_loss: 0.0000e+00
# Epoch 924/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4200 - scce_loss: 0.4200 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7280 - val_scce_loss: 0.7280 - val_perceptual_loss: 0.0000e+00
# Epoch 925/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4199 - scce_loss: 0.4199 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7223 - val_scce_loss: 0.7223 - val_perceptual_loss: 0.0000e+00
# Epoch 926/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4185 - scce_loss: 0.4185 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7277 - val_scce_loss: 0.7277 - val_perceptual_loss: 0.0000e+00
# Epoch 927/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4197 - scce_loss: 0.4197 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7569 - val_scce_loss: 0.7569 - val_perceptual_loss: 0.0000e+00
# Epoch 928/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4202 - scce_loss: 0.4202 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7333 - val_scce_loss: 0.7333 - val_perceptual_loss: 0.0000e+00
# Epoch 929/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4204 - scce_loss: 0.4204 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7325 - val_scce_loss: 0.7325 - val_perceptual_loss: 0.0000e+00
# Epoch 930/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4188 - scce_loss: 0.4188 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7235 - val_scce_loss: 0.7235 - val_perceptual_loss: 0.0000e+00
# Epoch 931/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4187 - scce_loss: 0.4187 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7492 - val_scce_loss: 0.7492 - val_perceptual_loss: 0.0000e+00
# Epoch 932/2000
# 62/62 [==============================] - 393s 6s/step - total_loss: 0.4196 - scce_loss: 0.4196 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7241 - val_scce_loss: 0.7241 - val_perceptual_loss: 0.0000e+00
# Epoch 933/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4161 - scce_loss: 0.4161 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7585 - val_scce_loss: 0.7585 - val_perceptual_loss: 0.0000e+00
# Epoch 934/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4203 - scce_loss: 0.4203 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7301 - val_scce_loss: 0.7301 - val_perceptual_loss: 0.0000e+00
# Epoch 935/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4189 - scce_loss: 0.4189 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7240 - val_scce_loss: 0.7240 - val_perceptual_loss: 0.0000e+00
# Epoch 936/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4179 - scce_loss: 0.4179 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7413 - val_scce_loss: 0.7413 - val_perceptual_loss: 0.0000e+00
# Epoch 937/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4201 - scce_loss: 0.4201 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7342 - val_scce_loss: 0.7342 - val_perceptual_loss: 0.0000e+00
# Epoch 938/2000
# 62/62 [==============================] - 396s 6s/step - total_loss: 0.4199 - scce_loss: 0.4199 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7247 - val_scce_loss: 0.7247 - val_perceptual_loss: 0.0000e+00
# Epoch 939/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4187 - scce_loss: 0.4187 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7236 - val_scce_loss: 0.7236 - val_perceptual_loss: 0.0000e+00
# Epoch 940/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4205 - scce_loss: 0.4205 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7255 - val_scce_loss: 0.7255 - val_perceptual_loss: 0.0000e+00
# Epoch 941/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4179 - scce_loss: 0.4179 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7242 - val_scce_loss: 0.7242 - val_perceptual_loss: 0.0000e+00
# Epoch 942/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4184 - scce_loss: 0.4184 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7437 - val_scce_loss: 0.7437 - val_perceptual_loss: 0.0000e+00
# Epoch 943/2000
# 62/62 [==============================] - 395s 6s/step - total_loss: 0.4187 - scce_loss: 0.4187 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7219 - val_scce_loss: 0.7219 - val_perceptual_loss: 0.0000e+00
# Epoch 944/2000
# 62/62 [==============================] - 394s 6s/step - total_loss: 0.4180 - scce_loss: 0.4180 - perceptual_loss: 0.0000e+00 - val_total_loss: 0.7177 - val_scce_loss: 0.7177 - val_perceptual_loss: 0.0000e+00
# Epoch 945/2000
# 15/62 [======>.......................] - ETA: 3:47 - total_loss: 0.4194 - scce_loss: 0.4194 - perceptual_loss: 0.0000e+00

# %%
with strategy.scope():
    generated_videos = model(train_sample_data, training=False)

# %%
display_videos(generated_videos, 2, 4)

# %%
display_videos(train_sample_data["y"], 1, 4)
