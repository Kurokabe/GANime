# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0, 1, 2, 3, 4, 5, 6, 7"
os.environ["TF_GPU_ALLOCATOR"]="cuda_malloc_async"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
#for device in tf.config.list_physical_devices("GPU"):
#    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-08-18 01:34:45.600052: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-18 01:34:48.506533: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 0
# 2022-08-18 01:34:48.506730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22302 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.507801: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 1
# 2022-08-18 01:34:48.507839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22302 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:25:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.508710: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 2
# 2022-08-18 01:34:48.508741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22302 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.509541: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 3
# 2022-08-18 01:34:48.509571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22302 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.510397: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 4
# 2022-08-18 01:34:48.510430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 22302 MB memory:  -> device: 4, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.511236: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 5
# 2022-08-18 01:34:48.511268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 22302 MB memory:  -> device: 5, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.512065: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 6
# 2022-08-18 01:34:48.512097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 22302 MB memory:  -> device: 6, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2022-08-18 01:34:48.512898: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:214] Using CUDA malloc Async allocator for GPU: 7
# 2022-08-18 01:34:48.512930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 22302 MB memory:  -> device: 7, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:e1:00.0, compute capability: 8.6

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.ReductionToOneDevice())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/moving_mnist_video.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
#dataset_length = 1578 
dataset_length = 10000
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = element[:10]
    element = normalize(element)
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
dataset = (dataset.shuffle(5000, reshuffle_each_iteration=True, seed=8)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(64)
                          #.map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.padded_batch(64)
                              #.map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            .map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
take_train = [2, 8, 10, 16, 22, 33, 34, 49]
train_sample_data = postprocess({key: value[take_train] for key, value in train_sample_data.items()})
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
take_validation = [9, 14, 36, 42, 45, 47, 49, 63]
validation_sample_data = postprocess({key: value[take_validation] for key, value in validation_sample_data.items()})
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_images(train_sample_data["last_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(validation_sample_data["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = "../../../logs/ganime/transformers/moving_mnist_video_large_2022-08-15_13-50-36" #get_logdir("../../../logs/ganime/transformers", experiment_name="moving_mnist_video_large_test")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
images = train_sample_data["y"][:,0,...]

# %%
train_sample_data["y"].shape
# Out:
# TensorShape([8, 10, 64, 64, 3])

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 512, 16, 16) = 131072 dimensions.
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# 2022-08-18 01:35:01.364819: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-08-18 01:35:02.745436: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# Some layers of TFGPT2LMHeadModel were not initialized from the model checkpoint at gpt2-large and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Restoring weights from ../../../checkpoints/moving_mnist_video_gpt2_large/checkpoint

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, initial_epoch=1037, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 1038/2000
# 2022-08-18 01:41:06.676324: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:07.559539: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:08.386892: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:09.517037: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:10.996914: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:12.471378: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:13.819992: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 2022-08-18 01:41:15.136277: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 15/15 [==============================] - 730s 27s/step - total_loss: 0.9000 - scce_loss: 0.4283 - perceptual_loss: 0.4717 - val_total_loss: 1.1859 - val_scce_loss: 0.5039 - val_perceptual_loss: 0.6821
# Epoch 1039/2000
# 15/15 [==============================] - 286s 20s/step - total_loss: 0.8921 - scce_loss: 0.4282 - perceptual_loss: 0.4639 - val_total_loss: 1.1932 - val_scce_loss: 0.5004 - val_perceptual_loss: 0.6928
# Epoch 1040/2000
# 15/15 [==============================] - 283s 20s/step - total_loss: 0.8880 - scce_loss: 0.4269 - perceptual_loss: 0.4610 - val_total_loss: 1.1932 - val_scce_loss: 0.5025 - val_perceptual_loss: 0.6906
# Epoch 1041/2000
# 15/15 [==============================] - 284s 20s/step - total_loss: 0.8799 - scce_loss: 0.4241 - perceptual_loss: 0.4558 - val_total_loss: 1.1859 - val_scce_loss: 0.5006 - val_perceptual_loss: 0.6853
# Epoch 1042/2000
# 15/15 [==============================] - 156s 10s/step - total_loss: 0.9001 - scce_loss: 0.4262 - perceptual_loss: 0.4739 - val_total_loss: 1.1938 - val_scce_loss: 0.4999 - val_perceptual_loss: 0.6938
# Epoch 1043/2000
# 15/15 [==============================] - 158s 11s/step - total_loss: 0.9096 - scce_loss: 0.4291 - perceptual_loss: 0.4805 - val_total_loss: 1.1995 - val_scce_loss: 0.5004 - val_perceptual_loss: 0.6991
# Epoch 1044/2000
# 15/15 [==============================] - 157s 11s/step - total_loss: 0.9174 - scce_loss: 0.4268 - perceptual_loss: 0.4907 - val_total_loss: 1.1820 - val_scce_loss: 0.4994 - val_perceptual_loss: 0.6826
# Epoch 1045/2000
# 15/15 [==============================] - 157s 11s/step - total_loss: 0.8800 - scce_loss: 0.4244 - perceptual_loss: 0.4556 - val_total_loss: 1.1991 - val_scce_loss: 0.5025 - val_perceptual_loss: 0.6966
# Epoch 1046/2000
# 15/15 [==============================] - 161s 11s/step - total_loss: 0
2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8623 - scce_loss: 0.4146 - perceptual_loss: 0.4477 - val_total_loss: 1.1856 - val_scce_loss: 0.5050 - val_perceptual_loss: 0.6806
# Epoch 1957/2000
# 15/15 [==============================] - 161s 11s/step - total_loss: 0.8567 - scce_loss: 0.4163 - perceptual_loss: 0.4404 - val_total_loss: 1.1924 - val_scce_loss: 0.5067 - val_perceptual_loss: 0.6857
# Epoch 1958/2000
# 15/15 [==============================] - 163s 11s/step - total_loss: 0.8518 - scce_loss: 0.4148 - perceptual_loss: 0.4370 - val_total_loss: 1.1655 - val_scce_loss: 0.5039 - val_perceptual_loss: 0.6616
# Epoch 1959/2000
# 15/15 [==============================] - 161s 11s/step - total_loss: 0.8465 - scce_loss: 0.4142 - perceptual_loss: 0.4323 - val_total_loss: 1.1842 - val_scce_loss: 0.5044 - val_perceptual_loss: 0.6798
# Epoch 1960/2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8369 - scce_loss: 0.4089 - perceptual_loss: 0.4280 - val_total_loss: 1.1754 - val_scce_loss: 0.5055 - val_perceptual_loss: 0.6698
# Epoch 1961/2000
# 15/15 [==============================] - 166s 11s/step - total_loss: 0.8466 - scce_loss: 0.4135 - perceptual_loss: 0.4331 - val_total_loss: 1.1977 - val_scce_loss: 0.5098 - val_perceptual_loss: 0.6879
# Epoch 1962/2000
# 15/15 [==============================] - 167s 11s/step - total_loss: 0.8564 - scce_loss: 0.4159 - perceptual_loss: 0.4405 - val_total_loss: 1.1787 - val_scce_loss: 0.5061 - val_perceptual_loss: 0.6727
# Epoch 1963/2000
# 15/15 [==============================] - 167s 11s/step - total_loss: 0.8588 - scce_loss: 0.4163 - perceptual_loss: 0.4425 - val_total_loss: 1.1775 - val_scce_loss: 0.5077 - val_perceptual_loss: 0.6698
# Epoch 1964/2000
# 15/15 [==============================] - 168s 11s/step - total_loss: 0.8759 - scce_loss: 0.4186 - perceptual_loss: 0.4574 - val_total_loss: 1.1883 - val_scce_loss: 0.5094 - val_perceptual_loss: 0.6790
# Epoch 1965/2000
# 15/15 [==============================] - 169s 11s/step - total_loss: 0.8242 - scce_loss: 0.4107 - perceptual_loss: 0.4135 - val_total_loss: 1.1895 - val_scce_loss: 0.5072 - val_perceptual_loss: 0.6823
# Epoch 1966/2000
# 15/15 [==============================] - 169s 11s/step - total_loss: 0.8573 - scce_loss: 0.4147 - perceptual_loss: 0.4426 - val_total_loss: 1.1779 - val_scce_loss: 0.5065 - val_perceptual_loss: 0.6714
# Epoch 1967/2000
# 15/15 [==============================] - 169s 11s/step - total_loss: 0.8408 - scce_loss: 0.4126 - perceptual_loss: 0.4282 - val_total_loss: 1.1869 - val_scce_loss: 0.5105 - val_perceptual_loss: 0.6764
# Epoch 1968/2000
# 15/15 [==============================] - 170s 11s/step - total_loss: 0.8360 - scce_loss: 0.4119 - perceptual_loss: 0.4241 - val_total_loss: 1.1816 - val_scce_loss: 0.5083 - val_perceptual_loss: 0.6733
# Epoch 1969/2000
# 15/15 [==============================] - 169s 11s/step - total_loss: 0.8406 - scce_loss: 0.4112 - perceptual_loss: 0.4294 - val_total_loss: 1.1786 - val_scce_loss: 0.5072 - val_perceptual_loss: 0.6714
# Epoch 1970/2000
# 15/15 [==============================] - 167s 11s/step - total_loss: 0.8535 - scce_loss: 0.4138 - perceptual_loss: 0.4397 - val_total_loss: 1.1817 - val_scce_loss: 0.5064 - val_perceptual_loss: 0.6753
# Epoch 1971/2000
# 15/15 [==============================] - 162s 11s/step - total_loss: 0.
# 15/15 [==============================] - 166s 11s/step - total_loss: 0.8381 - scce_loss: 0.4119 - perceptual_loss: 0.4262 - val_total_loss: 1.1819 - val_scce_loss: 0.5079 - val_perceptual_loss: 0.6740
# Epoch 1987/2000
# 15/15 [==============================] - 167s 11s/step - total_loss: 0.8307 - scce_loss: 0.4115 - perceptual_loss: 0.4192 - val_total_loss: 1.1820 - val_scce_loss: 0.5053 - val_perceptual_loss: 0.6767
# Epoch 1988/2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8323 - scce_loss: 0.4122 - perceptual_loss: 0.4202 - val_total_loss: 1.1827 - val_scce_loss: 0.5056 - val_perceptual_loss: 0.6771
# Epoch 1989/2000
# 15/15 [==============================] - 165s 11s/step - total_loss: 0.8461 - scce_loss: 0.4138 - perceptual_loss: 0.4323 - val_total_loss: 1.1861 - val_scce_loss: 0.5070 - val_perceptual_loss: 0.6792
# Epoch 1990/2000
# 15/15 [==============================] - 165s 11s/step - total_loss: 0.8592 - scce_loss: 0.4158 - perceptual_loss: 0.4435 - val_total_loss: 1.1587 - val_scce_loss: 0.5055 - val_perceptual_loss: 0.6532
# Epoch 1991/2000
# 15/15 [==============================] - 165s 11s/step - total_loss: 0.8551 - scce_loss: 0.4157 - perceptual_loss: 0.4394 - val_total_loss: 1.1717 - val_scce_loss: 0.5047 - val_perceptual_loss: 0.6671
# Epoch 1992/2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8372 - scce_loss: 0.4110 - perceptual_loss: 0.4262 - val_total_loss: 1.1825 - val_scce_loss: 0.5077 - val_perceptual_loss: 0.6747
# Epoch 1993/2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8605 - scce_loss: 0.4151 - perceptual_loss: 0.4454 - val_total_loss: 1.1808 - val_scce_loss: 0.5091 - val_perceptual_loss: 0.6717
# Epoch 1994/2000
# 15/15 [==============================] - 164s 11s/step - total_loss: 0.8297 - scce_loss: 0.4111 - perceptual_loss: 0.4187 - val_total_loss: 1.1919 - val_scce_loss: 0.5085 - val_perceptual_loss: 0.6834
# Epoch 1995/2000
# 15/15 [==============================] - 165s 11s/step - total_loss: 0.8457 - scce_loss: 0.4123 - perceptual_loss: 0.4334 - val_total_loss: 1.1860 - val_scce_loss: 0.5082 - val_perceptual_loss: 0.6778
# Epoch 1996/2000
# 15/15 [==============================] - 162s 11s/step - total_loss: 0.8607 - scce_loss: 0.4164 - perceptual_loss: 0.4442 - val_total_loss: 1.1840 - val_scce_loss: 0.5079 - val_perceptual_loss: 0.6761
# Epoch 1997/2000
# 15/15 [==============================] - 166s 11s/step - total_loss: 0.8515 - scce_loss: 0.4139 - perceptual_loss: 0.4375 - val_total_loss: 1.1956 - val_scce_loss: 0.5081 - val_perceptual_loss: 0.6874
# Epoch 1998/2000
# 15/15 [==============================] - 162s 11s/step - total_loss: 0.8511 - scce_loss: 0.4142 - perceptual_loss: 0.4369 - val_total_loss: 1.1803 - val_scce_loss: 0.5064 - val_perceptual_loss: 0.6739
# Epoch 1999/2000
# 15/15 [==============================] - 163s 11s/step - total_loss: 0.8528 - scce_loss: 0.4121 - perceptual_loss: 0.4407 - val_total_loss: 1.1831 - val_scce_loss: 0.5068 - val_perceptual_loss: 0.6764
# Epoch 2000/2000
# 15/15 [==============================] - 163s 11s/step - total_loss: 0.8453 - scce_loss: 0.4146 - perceptual_loss: 0.4307 - val_total_loss: 1.1790 - val_scce_loss: 0.5063 - val_perceptual_loss: 0.6727

# %%
model.save_weights("../../../checkpoints/moving_mnist_video_gpt2_large/checkpoint")
