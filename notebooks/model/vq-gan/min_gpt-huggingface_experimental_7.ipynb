# %% [markdown]
# Test with best model

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../../")

# %% [markdown]
# from tensorflow.keras import mixed_precision
#
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_global_policy(policy)
# print('Compute dtype: %s' % policy.compute_dtype)
# print('Variable dtype: %s' % policy.variable_dtype)

# %%
import tensorflow as tf
for device in tf.config.list_physical_devices("GPU"):
    tf.config.experimental.set_memory_growth(device, True)

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
from ganime.model.vqgan_clean.experimental.net2net_v3 import Net2Net
import tensorflow_addons as tfa
from datetime import datetime
from tqdm.auto import tqdm
from pyprojroot.pyprojroot import here

tf.get_logger().setLevel('WARNING')
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2022-07-20 06:19:26.224601: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-20 06:19:26.628465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22297 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

# %%
cfg = omegaconf.OmegaConf.load(here("configs/kny_transformer_light.yaml"))
#cfg = omegaconf.OmegaConf.load(here("configs/default_transformer.yaml"))
batch_size = cfg["train"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["train"]["n_epochs"]
sample_batch_size = 8

# %%
dataset_length = 689
num_batch = dataset_length / batch_size

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     first_frame = element[0,...]
#     last_frame = element[2,...]
#
#     y = element[0:3,...]
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %%
drop_prob = 0.0 #0.2

# %% [markdown]
# def preprocess(element):
#     element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
#     element = tf.cast(element, tf.float32) / 255.0
#     #num_elements_to_keep = tf.random.uniform(shape=(1,), minval=5, maxval=tf.shape(element)[0], dtype=tf.int32)
#     #remainder = tf.shape(element)[0] - num_elements_to_keep[0]
#     idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
#     element = element[idx_to_keep]
#
#     #element = element[:10,...]
#     first_frame = element[0,...]
#     last_frame = element[-1,...]
#
#     y = element
#
#     return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0]}

# %% [markdown]
# def video_to_ragged(element):
#     element["y"] = tf.RaggedTensor.from_tensor(tf.expand_dims(element["y"], 0))
#     return element
# def squeeze_ragged(element):
#     element["y"] = tf.squeeze(element["y"], axis=1)
#     return element
# def to_tensor(element):
#     element["y"] = element["y"].to_tensor()
#     return element

# %% [markdown]
# dataset = VideoDataset("../../../data/moving_mnist_tfrecords").load()
# dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True)
#            .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
#            #.map(video_to_ragged, num_parallel_calls=tf.data.AUTOTUNE)
#            )

# %% [markdown]
# train_size = int(dataset_length * 0.8)
# validation_size = int(dataset_length * 0.1)
# test_size = int(dataset_length * 0.1)

# %% [markdown]
# train_ds = dataset.take(train_size)#.batch(global_batch_size)
# validation_ds = dataset.skip(train_size).take(validation_size)#.batch(global_batch_size)
# test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.batch(global_batch_size)

# %% [markdown]
# train_sample_data = next(train_ds
#                           .padded_batch(batch_size)
#                           .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
# validation_sample_data = next(validation_ds.padded_batch(batch_size).as_numpy_iterator())

# %% [markdown]
# train_ds = (train_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# validation_ds = (validation_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))
# test_ds = (test_ds.apply(
#                         tf.data.experimental.dense_to_ragged_batch(batch_size=batch_size, drop_remainder=True))
#             .prefetch(tf.data.AUTOTUNE))

# %%
def preprocess(element):
    element = tf.reshape(element, (tf.shape(element)[0], tf.shape(element)[1], tf.shape(element)[2], 3))
    element = tf.cast(element, tf.float32) / 255.0
    n_frames = tf.shape(element)[0]
    
    remaining_frames = tf.reverse(tf.range(n_frames), axis=[0])
    
    idx_to_keep = tf.random.uniform((tf.shape(element)[0],)) > drop_prob
    element = element[idx_to_keep]
    remaining_frames = remaining_frames[idx_to_keep]
    
    first_frame = element[0,...]
    last_frame = element[-1,...]
    
    y = element
    
    return {"first_frame": first_frame, "last_frame": last_frame, "y": y, "n_frames": tf.shape(element)[0], "remaining_frames": remaining_frames}
def postprocess(batch):
    min_frames = tf.reduce_min(batch["n_frames"])
    first_frame_idx = tf.constant(0)
    frames_to_keep = min_frames - 2
    
    y = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
    remaining_frames = tf.TensorArray(tf.int32, size=0, dynamic_size=True, clear_after_read=False)
    
    for i in tf.range(tf.shape(batch["y"])[0]):
        num_frames = batch["n_frames"][i]
        last_frame_idx = num_frames - 1
        all_indices = tf.range(1, num_frames - 1)
        indices = tf.sort(tf.random.shuffle(all_indices)[:frames_to_keep])
        indices = tf.concat([[first_frame_idx], indices, [last_frame_idx]], axis=0)
        y = y.write(i, tf.gather(batch["y"][i], indices))
        remaining_frames = remaining_frames.write(i, tf.gather(batch["remaining_frames"][i], indices))
        
    batch["remaining_frames"] = remaining_frames.stack()
    batch["y"] = y.stack()
    batch["n_frames"] = tf.repeat(min_frames, tf.shape(batch["y"])[0])
    
    return batch

# %%
dataset = VideoDataset("../../../data/kny/videos_tfrecords_light").load()
dataset = (dataset.shuffle(dataset_length, reshuffle_each_iteration=True, seed=3)
           .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
           )

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .padded_batch(sample_batch_size)#.map(postprocess)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds
                              .padded_batch(sample_batch_size)#.map(postprocess)
                              .as_numpy_iterator())
test_sample_data = next(test_ds
                              .padded_batch(sample_batch_size)#.map(postprocess)
                              .as_numpy_iterator())

# %%
train_ds = (train_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.padded_batch(global_batch_size, drop_remainder=True)
            #.map(postprocess, num_parallel_calls=tf.data.AUTOTUNE)
            .prefetch(tf.data.AUTOTUNE))

# %%
train_sample_data["n_frames"]
# Out:
# array([15, 21,  5, 17, 26, 17, 19, 18], dtype=int32)

# %%
display_images(train_sample_data["first_frame"], 2, 4)
plt.show()

# %%
display_videos(train_sample_data["y"], 2, 4)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(validation_sample_data["y"], 2, 4)
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# train_ds = strategy.experimental_distribute_dataset(train_ds)
# validation_ds = strategy.experimental_distribute_dataset(validation_ds)
# test_ds = strategy.experimental_distribute_dataset(test_ds)

# %%
from ganime.utils.callbacks import TensorboardVideo, get_logdir
import os

logdir = get_logdir("../../../logs/ganime/transformers", experiment_name="kny_light")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_video_callback = TensorboardVideo(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.001,
    patience=50,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='val_total_loss', save_best_only=True, save_weights_only=True)
#callbacks = [tensorboard_callback, early_stopping, checkpointing, tensorboard_video_callback]
callbacks = [tensorboard_callback, checkpointing, tensorboard_video_callback]

# %%
images = train_sample_data["y"][:,0,...]

# %%
train_sample_data["y"].shape
# Out:
# (8, 26, 64, 128, 3)

# %%
with strategy.scope():
    model = Net2Net(**cfg["model"], trainer_config=cfg["train"], num_replicas=strategy.num_replicas_in_sync)
    #model.build(train_sample_data["y"].shape)#first_stage_model.build(train_sample_data["y"].shape[1:])
    model.first_stage_model.build(train_sample_data["y"].shape[1:])
# Out:
# Working with z of shape (1, 128, 8, 8) = 8192 dimensions.
# VQLPIPSWithDiscriminator running with hinge loss.
# using method  own_embeddings
# 2022-07-20 06:21:10.515415: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-07-20 06:21:11.157824: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# All model checkpoint layers were used when initializing TFGPT2Model.
#
# Some layers of TFGPT2Model were not initialized from the model checkpoint at gpt2-medium and are newly initialized: ['transformer/weight:0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Restoring weights from ../../../checkpoints/kny_video_light/checkpoint

# %% [markdown]
# for i in range(10):
#     pbar = tqdm(train_ds)
#     for data in pbar:
#         output = strategy.run(model.train_step, args=(data,))
#         pbar.set_postfix(loss=output["loss"].numpy())

# %%
model.fit(train_ds, validation_data=validation_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
#model.fit(train_ds, epochs=cfg["train"]["n_epochs"], callbacks=callbacks)
# Out:
# Epoch 1/2000
# 2022-07-15 03:00:51.673054: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 68/68 [==============================] - 478s 7s/step - total_loss: 11.9945 - scce_loss: 9.1677 - perceptual_loss: 2.8268 - val_total_loss: 9.3655 - val_scce_loss: 6.5126 - val_perceptual_loss: 2.8529
# Epoch 2/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 9.5996 - scce_loss: 5.9356 - perceptual_loss: 3.6640 - val_total_loss: 11.3689 - val_scce_loss: 6.3791 - val_perceptual_loss: 4.9899
# Epoch 3/2000
# 68/68 [==============================] - 417s 6s/step - total_loss:
2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 1.3606 - scce_loss: 0.9556 - perceptual_loss: 0.4050 - val_total_loss: 6.3347 - val_scce_loss: 3.4524 - val_perceptual_loss: 2.8823
# Epoch 33/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.3593 - scce_loss: 0.9585 - perceptual_loss: 0.4008 - val_total_loss: 6.8315 - val_scce_loss: 3.4917 - val_perceptual_loss: 3.3399
# Epoch 34/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 1.2567 - scce_loss: 0.8723 - perceptual_loss: 0.3843 - val_total_loss: 7.0879 - val_scce_loss: 3.8392 - val_perceptual_loss: 3.2487
# Epoch 35/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 1.2619 - scce_loss: 0.8875 - perceptual_loss: 0.3743 - val_total_loss: 6.3618 - val_scce_loss: 3.3730 - val_perceptual_loss: 2.9889
# Epoch 36/2000
# 68/68 [==============================] - 428s 6s/step - total_loss: 1.2535 - scce_loss: 0.8677 - perceptual_loss: 0.3858 - val_total_loss: 5.4454 - val_scce_loss: 3.0876 - val_perceptual_loss: 2.3578
# Epoch 37/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 1.2074 - scce_loss: 0.8421 - perceptual_loss: 0.3653 - val_total_loss: 6.1316 - val_scce_loss: 3.4233 - val_perceptual_loss: 2.7083
# Epoch 38/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 1.2190 - scce_loss: 0.8562 - perceptual_loss: 0.3629 - val_total_loss: 6.9191 - val_scce_loss: 3.6313 - val_perceptual_loss: 3.2877
# Epoch 39/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.2299 - scce_loss: 0.8642 - perceptual_loss: 0.3657 - val_total_loss: 7.1107 - val_scce_loss: 3.6618 - val_perceptual_loss: 3.4489
# Epoch 40/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 1.2190 - scce_loss: 0.8532 - perceptual_loss: 0.3658 - val_total_loss: 6.2508 - val_scce_loss: 3.5165 - val_perceptual_loss: 2.7344
# Epoch 41/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 1.2098 - scce_loss: 0.8434 - perceptual_loss: 0.3664 - val_total_loss: 6.0883 - val_scce_loss: 3.3631 - val_perceptual_loss: 2.7252
# Epoch 42/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 1.1745 - scce_loss: 0.8122 - perceptual_loss: 0.3623 - val_total_loss: 5.7573 - val_scce_loss: 3.3906 - val_perceptual_loss: 2.3667
# Epoch 43/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 1.1376 - scce_loss: 0.7965 - perceptual_loss: 0.3411 - val_total_loss: 6.0486 - val_scce_loss: 3.2007 - val_perceptual_loss: 2.8479
# Epoch 44/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 1.1421 - scce_loss: 0.8025 - perceptual_loss: 0.3395 - val_total_loss: 6.0439 - val_scce_loss: 3.2148 - val_perceptual_loss: 2.8291
# Epoch 45/2000
# 68/68 [==============================] - 428s 6s/step - total_loss: 1.1205 - scce_loss: 0.7779 - perceptual_loss: 0.3426 - val_total_loss: 5.4412 - val_scce_loss: 3.4217 - val_perceptual_loss: 2.0195
# Epoch 46/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 1.1561 - scce_loss: 0.7960 - perceptual_loss: 0.3601 - val_total_loss: 6.2556 - val_scce_loss: 3.3986 - val_perceptual_loss: 2.8570
# Epoch 47/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.1270 - scce_loss: 0.7823 - perceptual_loss: 0.3447 - val_total_loss: 5.6732 - val_scce_loss: 3.2366 - val_perceptual_loss: 2.4365
# Epoch 48/2000
# 68/68 [==============================] - 425s 6s/step - total_loss: 1.1016 - scce_loss: 0.7698 - perceptual_loss: 0.3317 - val_total_loss: 5.4214 - val_scce_loss: 3.2746 - val_perceptual_loss: 2.1467
# Epoch 49/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.1289 - scce_loss: 0.7746 - perceptual_loss: 0.3543 - val_total_loss: 6.1191 - val_scce_loss: 3.1844 - val_perceptual_loss: 2.9347
# Epoch 50/2000
# 68/68 [==============================] - 425s 6s/step - total_loss: 1.0961 - scce_loss: 0.7625 - perceptual_loss: 0.3336 - val_total_loss: 5.1625 - val_scce_loss: 2.8391 - val_perceptual_loss: 2.3235
# Epoch 51/2000
# 68/68 [==============================] - 426s 6s/step - total_loss: 1.1151 - scce_loss: 0.7741 - perceptual_loss: 0.3411 - val_total_loss: 4.6146 - val_scce_loss: 2.6390 - val_perceptual_loss: 1.9756
# Epoch 52/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 1.0858 - scce_loss: 0.7490 - perceptual_loss: 0.3368 - val_total_loss: 4.8821 - val_scce_loss: 2.8013 - val_perceptual_loss: 2.0808
# Epoch 53/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 1.0716 - scce_loss: 0.7306 - perceptual_loss: 0.3410 - val_total_loss: 5.5402 - val_scce_loss: 3.3086 - val_perceptual_loss: 2.2316
# Epoch 54/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 1.0913 - scce_loss: 0.7601 - perceptual_loss: 0.3312 - val_total_loss: 5.5964 - val_scce_loss: 3.1985 - val_perceptual_loss: 2.3980
# Epoch 55/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.0671 - scce_loss: 0.7465 - perceptual_loss: 0.3207 - val_total_loss: 4.9190 - val_scce_loss: 2.8224 - val_perceptual_loss: 2.0966
# Epoch 56/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 1.0691 - scce_loss: 0.7483 - perceptual_loss: 0.3207 - val_total_loss: 4.8451 - val_scce_loss: 2.8414 - val_perceptual_loss: 2.0037
# Epoch 57/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 1.0542 - scce_loss: 0.7236 - perceptual_loss: 0.3306 - val_total_loss: 4.9485 - val_scce_loss: 2.7400 - val_perceptual_loss: 2.2086
# Epoch 58/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 1.0613 - scce_loss: 0.7260 - perceptual_loss: 0.3353 - val_total_loss: 4.9634 - val_scce_loss: 2.8740 - val_perceptual_loss: 2.0894
# Epoch 59/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 1.0452 - scce_loss: 0.7116 - perceptual_loss: 0.3336 - val_total_loss: 5.6062 - val_scce_loss: 3.0229 - val_perceptual_loss: 2.5833
# Epoch 60/2000
# 68/68 [==============================] - 415s 6s/step - total_loss:
2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.9682 - scce_loss: 0.6634 - perceptual_loss: 0.3048 - val_total_loss: 4.4059 - val_scce_loss: 2.3228 - val_perceptual_loss: 2.0830
# Epoch 76/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 0.9436 - scce_loss: 0.6427 - perceptual_loss: 0.3009 - val_total_loss: 3.9852 - val_scce_loss: 2.3961 - val_perceptual_loss: 1.5891
# Epoch 77/2000
# 68/68 [==============================] - 404s 6s/step - total_loss: 0.9788 - scce_loss: 0.6615 - perceptual_loss: 0.3174 - val_total_loss: 4.4462 - val_scce_loss: 2.5333 - val_perceptual_loss: 1.9129
# Epoch 78/2000
# 68/68 [==============================] - 405s 6s/step - total_loss: 0.9462 - scce_loss: 0.6315 - perceptual_loss: 0.3147 - val_total_loss: 4.4517 - val_scce_loss: 2.5864 - val_perceptual_loss: 1.8653
# Epoch 79/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.9064 - scce_loss: 0.6038 - perceptual_loss: 0.3026 - val_total_loss: 4.3497 - val_scce_loss: 2.6450 - val_perceptual_loss: 1.7047
# Epoch 80/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.9161 - scce_loss: 0.6208 - perceptual_loss: 0.2953 - val_total_loss: 3.5867 - val_scce_loss: 2.1331 - val_perceptual_loss: 1.4536
# Epoch 81/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.8947 - scce_loss: 0.6028 - perceptual_loss: 0.2919 - val_total_loss: 3.9970 - val_scce_loss: 2.0009 - val_perceptual_loss: 1.9961
# Epoch 82/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.9065 - scce_loss: 0.6125 - perceptual_loss: 0.2939 - val_total_loss: 4.3459 - val_scce_loss: 2.1336 - val_perceptual_loss: 2.2123
# Epoch 83/2000
# 68/68 [==============================] - 404s 6s/step - total_loss: 0.9383 - scce_loss: 0.6404 - perceptual_loss: 0.2979 - val_total_loss: 3.9957 - val_scce_loss: 2.3131 - val_perceptual_loss: 1.6826
# Epoch 84/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.8967 - scce_loss: 0.6030 - perceptual_loss: 0.2938 - val_total_loss: 4.1200 - val_scce_loss: 2.3063 - val_perceptual_loss: 1.8137
# Epoch 85/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 0.9142 - scce_loss: 0.6256 - perceptual_loss: 0.2887 - val_total_loss: 4.0512 - val_scce_loss: 2.3477 - val_perceptual_loss: 1.7035
# Epoch 86/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 0.9113 - scce_loss: 0.6230 - perceptual_loss: 0.2883 - val_total_loss: 4.0117 - val_scce_loss: 2.1724 - val_perceptual_loss: 1.8393
# Epoch 87/2000
# 68/68 [==============================] - 433s 6s/step - total_loss: 0.9012 - scce_loss: 0.5980 - perceptual_loss: 0.3032 - val_total_loss: 3.0154 - val_scce_loss: 1.9191 - val_perceptual_loss: 1.0963
# Epoch 88/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.8933 - scce_loss: 0.5982 - perceptual_loss: 0.2951 - val_total_loss: 3.5865 - val_scce_loss: 1.9808 - val_perceptual_loss: 1.6057
# Epoch 89/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.8972 - scce_loss: 0.6003 - perceptual_loss: 0.2969 - val_total_loss: 3.7911 - val_scce_loss: 2.1968 - val_perceptual_loss: 1.5943
# Epoch 90/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.8675 - scce_loss: 0.5781 - perceptual_loss: 0.2894 - val_total_loss: 4.5371 - val_scce_loss: 2.3191 - val_perceptual_loss: 2.2181
# Epoch 91/2000
# 68/68 [==============================] - 430s 6s/step - total_loss: 0.8928 - scce_loss: 0.6145 - perceptual_loss: 0.2783 - val_total_loss: 2.8518 - val_scce_loss: 1.6944 - val_perceptual_loss: 1.1574
# Epoch 92/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.8720 - scce_loss: 0.5793 - perceptual_loss: 0.2927 - val_total_loss: 4.2245 - val_scce_loss: 2.2850 - val_perceptual_loss: 1.9394
# Epoch 93/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 0.8845 - scce_loss: 0.5908 - perceptual_loss: 0.2937 - val_total_loss: 3.0660 - val_scce_loss: 1.7253 - val_perceptual_loss: 1.3407
# Epoch 94/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 0.8680 - scce_loss: 0.5870 - perceptual_loss: 0.2810 - val_total_loss: 3.7310 - val_scce_loss: 2.0550 - val_perceptual_loss: 1.6760
# Epoch 95/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.8713 - scce_loss: 0.5837 - perceptual_loss: 0.2876 - val_total_loss: 2.9263 - val_scce_loss: 1.7695 - val_perceptual_loss: 1.1568
# Epoch 96/2000
# 68/68 [==============================] - 407s 6s/step - total_loss: 0.8766 - scce_loss: 0.5869 - perceptual_loss: 0.2897 - val_total_loss: 3.6696 - val_scce_loss: 2.2275 - val_perceptual_loss: 1.4420
# Epoch 97/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.8438 - scce_loss: 0.5661 - perceptual_loss: 0.2777 - val_total_loss: 3.3258 - val_scce_loss: 2.1094 - val_perceptual_loss: 1.2163
# Epoch 98/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.8578 - scce_loss: 0.5685 - perceptual_loss: 0.2893 - val_total_loss: 2.8212 - val_scce_loss: 1.5899 - val_perceptual_loss: 1.2313
# Epoch 99/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.8377 - scce_loss: 0.5501 - perceptual_loss: 0.2876 - val_total_loss: 2.8642 - val_scce_loss: 1.8831 - val_perceptual_loss: 0.9811
# Epoch 100/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 0.8391 - scce_loss: 0.5519 - perceptual_loss: 0.2872 - val_total_loss: 3.4793 - val_scce_loss: 2.0541 - val_perceptual_loss: 1.4251
# Epoch 101/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.8516 - scce_loss: 0.5564 - perceptual_loss: 0.2952 - val_total_loss: 3.3650 - val_scce_loss: 2.1141 - val_perceptual_loss: 1.2509
# Epoch 102/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.8279 - scce_loss: 0.5581 - perceptual_loss: 0.2697 - val_total_loss: 3.2533 - val_scce_loss: 2.0077 - val_perceptual_loss: 1.2456
# Epoch 103/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 0.7994 - scce_loss: 0.5282 - perceptual_loss: 0.2712 - val_total_loss: 2.9860 - val_scce_loss: 1.6250 - val_perceptual_loss: 1.3611
# Epoch 104/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 0.8082 - scce_loss: 0.5319 - perceptual_loss: 0.2764 - val_total_loss: 2.9875 - val_scce_loss: 1.8690 - val_perceptual_loss: 1.1185
# Epoch 105/2000
# 68/68 [==============================] - 421s 6s/step - total_loss: 0.7947 - scce_loss: 0.5193 - perceptual_loss: 0.2754 - val_total_loss: 2.4944 - val_scce_loss: 1.5776 - val_perceptual_loss: 0.9168
# Epoch 106/2000
# 68/68 [==============================] - 438s 6s/step - total_loss: 0.7677 - scce_loss: 0.5093 - perceptual_loss: 0.2583 - val_total_loss: 2.6093 - val_scce_loss: 1.5739 - val_perceptual_loss: 1.0354
# Epoch 107/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.8030 - scce_loss: 0.5211 - perceptual_loss: 0.2819 - val_total_loss: 3.1396 - val_scce_loss: 1.8617 - val_perceptual_loss: 1.2779
# Epoch 108/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.7909 - scce_loss: 0.5257 - perceptual_loss: 0.2652 - val_total_loss: 3.1947 - val_scce_loss: 1.8715 - val_perceptual_loss: 1.3232
# Epoch 109/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 0.7978 - scce_loss: 0.5240 - perceptual_loss: 0.2739 - val_total_loss: 2.4958 - val_scce_loss: 1.3540 - val_perceptual_loss: 1.1418
# Epoch 110/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.7941 - scce_loss: 0.5185 - perceptual_loss: 0.2756 - val_total_loss: 3.0786 - val_scce_loss: 2.0092 - val_perceptual_loss: 1.0694
# Epoch 111/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.7691 - scce_loss: 0.4898 - perceptual_loss: 0.2793 - val_total_loss: 2.7824 - val_scce_loss: 1.5594 - val_perceptual_loss: 1.2231
# Epoch 112/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.8069 - scce_loss: 0.5339 - perceptual_loss: 0.2730 - val_total_loss: 2.8535 - val_scce_loss: 1.7391 - val_perceptual_loss: 1.1144
# Epoch 113/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.8195 - scce_loss: 0.5371 - perceptual_loss: 0.2824 - val_total_loss: 2.8349 - val_scce_loss: 1.6808 - val_perceptual_loss: 1.1540
# Epoch 114/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.7794 - scce_loss: 0.5120 - perceptual_loss: 0.2675 - val_total_loss: 3.1965 - val_scce_loss: 2.0768 - val_perceptual_loss: 1.1197
# Epoch 115/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.7604 - scce_loss: 0.4970 - perceptual_loss: 0.2634 - val_total_loss: 2.6331 - val_scce_loss: 1.4339 - val_perceptual_loss: 1.1992
# Epoch 116/2000
# 68/68 [==============================] - 428s 6s/step - total_loss: 0.7882 - scce_loss: 0.5178 - perceptual_loss: 0.2705 - val_total_loss: 2.2957 - val_scce_loss: 1.4233 - val_perceptual_loss: 0.8724
# Epoch 117/2000
# 68/68 [==============================] - 433s 6s/step - total_loss: 0.7619 - scce_loss: 0.4959 - perceptual_loss: 0.2660 - val_total_loss: 2.2707 - val_scce_loss: 1.3935 - val_perceptual_loss: 0.8772
# Epoch 118/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.7610 - scce_loss: 0.5055 - perceptual_loss: 0.2555 - val_total_loss: 3.4347 - val_scce_loss: 1.7697 - val_perceptual_loss: 1.6650
# Epoch 119/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 0.7822 - scce_loss: 0.5129 - perceptual_loss: 0.2693 - val_total_loss: 2.6806 - val_scce_loss: 1.5779 - val_perceptual_loss: 1.1028
# Epoch 120/2000
# 68/68 [==============================] - 409s 6s/step - total_loss: 0.7398 - scce_loss: 0.4789 - perceptual_loss: 0.2609 - val_total_loss: 2.3188 - val_scce_loss: 1.4605 - val_perceptual_loss: 0.8583
# Epoch 121/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.7316 - scce_loss: 0.4871 - perceptual_loss: 0.2446 - val_total_loss: 3.0854 - val_scce_loss: 1.8482 - val_perceptual_loss: 1.2372
# Epoch 122/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.7656 - scce_loss: 0.4985 - perceptual_loss: 0.2671 - val_total_loss: 2.6853 - val_scce_loss: 1.5810 - val_perceptual_loss: 1.1043
# Epoch 123/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.7529 - scce_loss: 0.4961 - perceptual_loss: 0.2568 - val_total_loss: 2.8712 - val_scce_loss: 1.5623 - val_perceptual_loss: 1.3089
# Epoch 124/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.7543 - scce_loss: 0.4831 - perceptual_loss: 0.2712 - val_total_loss: 2.7196 - val_scce_loss: 1.6524 - val_perceptual_loss: 1.0672
# Epoch 125/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 0.7597 - scce_loss: 0.4831 - perceptual_loss: 0.2766 - val_total_loss: 2.4795 - val_scce_loss: 1.4459 - val_perceptual_loss: 1.0336
# Epoch 126/2000
# 68/68 [==============================] - 421s 6s/step - total_loss: 0.7303 - scce_loss: 0.4740 - perceptual_loss: 0.2563 - val_total_loss: 2.4509 - val_scce_loss: 1.5446 - val_perceptual_loss: 0.9063
# Epoch 127/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.7183 - scce_loss: 0.4626 - perceptual_loss: 0.2558 - val_total_loss: 3.3265 - val_scce_loss: 1.9677 - val_perceptual_loss: 1.3588
# Epoch 128/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 0.7178 - scce_loss: 0.4627 - perceptual_loss: 0.2551 - val_total_loss: 2.7594 - val_scce_loss: 1.6598 - val_perceptual_loss: 1.0997
# Epoch 129/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.7270 - scce_loss: 0.4694 - perceptual_loss: 0.2576 - val_total_loss: 3.1942 - val_scce_loss: 2.0158 - val_perceptual_loss: 1.1784
# Epoch 130/2000
# 68/68 [==============================] - 412s 6s/step - total_loss: 0.7286 - scce_loss: 0.4649 - perceptual_loss: 0.2637 - val_total_loss: 3.1642 - val_scce_loss: 1.8258 - val_perceptual_loss: 1.3384
# Epoch 131/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.7177 - scce_loss: 0.4677 - perceptual_loss: 0.2500 - val_total_loss: 2.3628 - val_scce_loss: 1.4378 - val_perceptual_loss: 0.9250
# Epoch 132/2000
# 68/68 [==============================] - 407s 6s/step - total_loss: 0.7352 - scce_loss: 0.4769 - perceptual_loss: 0.2584 - val_total_loss: 2.3945 - val_scce_loss: 1.4832 - val_perceptual_loss: 0.9113
2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.6780 - scce_loss: 0.4406 - perceptual_loss: 0.2374 - val_total_loss: 2.0459 - val_scce_loss: 1.3044 - val_perceptual_loss: 0.7415
# Epoch 150/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6772 - scce_loss: 0.4361 - perceptual_loss: 0.2411 - val_total_loss: 2.3420 - val_scce_loss: 1.3834 - val_perceptual_loss: 0.9586
# Epoch 151/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.6739 - scce_loss: 0.4200 - perceptual_loss: 0.2538 - val_total_loss: 2.3612 - val_scce_loss: 1.4060 - val_perceptual_loss: 0.9552
# Epoch 152/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6753 - scce_loss: 0.4365 - perceptual_loss: 0.2388 - val_total_loss: 1.9897 - val_scce_loss: 1.2008 - val_perceptual_loss: 0.7889
# Epoch 153/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.6782 - scce_loss: 0.4304 - perceptual_loss: 0.2478 - val_total_loss: 2.1866 - val_scce_loss: 1.3567 - val_perceptual_loss: 0.8299
# Epoch 154/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.6980 - scce_loss: 0.4391 - perceptual_loss: 0.2589 - val_total_loss: 2.1946 - val_scce_loss: 1.4165 - val_perceptual_loss: 0.7781
# Epoch 155/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.6661 - scce_loss: 0.4217 - perceptual_loss: 0.2444 - val_total_loss: 2.1830 - val_scce_loss: 1.2703 - val_perceptual_loss: 0.9127
# Epoch 156/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.6447 - scce_loss: 0.4105 - perceptual_loss: 0.2341 - val_total_loss: 2.1269 - val_scce_loss: 1.3304 - val_perceptual_loss: 0.7964
# Epoch 157/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6667 - scce_loss: 0.4165 - perceptual_loss: 0.2503 - val_total_loss: 2.6946 - val_scce_loss: 1.6623 - val_perceptual_loss: 1.0323
# Epoch 158/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6652 - scce_loss: 0.4252 - perceptual_loss: 0.2399 - val_total_loss: 2.5552 - val_scce_loss: 1.7023 - val_perceptual_loss: 0.8530
# Epoch 159/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6692 - scce_loss: 0.4236 - perceptual_loss: 0.2456 - val_total_loss: 2.3370 - val_scce_loss: 1.3534 - val_perceptual_loss: 0.9836
# Epoch 160/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.6695 - scce_loss: 0.4222 - perceptual_loss: 0.2473 - val_total_loss: 2.1797 - val_scce_loss: 1.2413 - val_perceptual_loss: 0.9383
# Epoch 161/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.6400 - scce_loss: 0.4086 - perceptual_loss: 0.2314 - val_total_loss: 2.6440 - val_scce_loss: 1.5067 - val_perceptual_loss: 1.1373
# Epoch 162/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 0.6668 - scce_loss: 0.4219 - perceptual_loss: 0.2449 - val_total_loss: 2.9790 - val_scce_loss: 1.6436 - val_perceptual_loss: 1.3354
# Epoch 163/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.6459 - scce_loss: 0.4069 - perceptual_loss: 0.2390 - val_total_loss: 1.9869 - val_scce_loss: 1.2445 - val_perceptual_loss: 0.7424
# Epoch 164/2000
# 68/68 [==============================] - 416s 6s/step - total_loss:
2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.6318 - scce_loss: 0.3910 - perceptual_loss: 0.2408 - val_total_loss: 2.0910 - val_scce_loss: 1.2106 - val_perceptual_loss: 0.8804
# Epoch 181/2000
# 68/68 [==============================] - 427s 6s/step - total_loss: 0.5961 - scce_loss: 0.3759 - perceptual_loss: 0.2201 - val_total_loss: 1.5079 - val_scce_loss: 0.9837 - val_perceptual_loss: 0.5241
# Epoch 182/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6109 - scce_loss: 0.3880 - perceptual_loss: 0.2229 - val_total_loss: 2.8808 - val_scce_loss: 1.5566 - val_perceptual_loss: 1.3242
# Epoch 183/2000
# 68/68 [==============================] - 410s 6s/step - total_loss: 0.6326 - scce_loss: 0.3991 - perceptual_loss: 0.2335 - val_total_loss: 1.7018 - val_scce_loss: 0.8762 - val_perceptual_loss: 0.8256
# Epoch 184/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.6416 - scce_loss: 0.4059 - perceptual_loss: 0.2357 - val_total_loss: 1.6332 - val_scce_loss: 1.0443 - val_perceptual_loss: 0.5888
# Epoch 185/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.6135 - scce_loss: 0.3865 - perceptual_loss: 0.2270 - val_total_loss: 2.5280 - val_scce_loss: 1.4748 - val_perceptual_loss: 1.0533
# Epoch 186/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.5968 - scce_loss: 0.3732 - perceptual_loss: 0.2236 - val_total_loss: 1.5825 - val_scce_loss: 1.0308 - val_perceptual_loss: 0.5518
# Epoch 187/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.6093 - scce_loss: 0.3841 - perceptual_loss: 0.2252 - val_total_loss: 1.6194 - val_scce_loss: 1.0419 - val_perceptual_loss: 0.5775
# Epoch 188/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.6212 - scce_loss: 0.3815 - perceptual_loss: 0.2397 - val_total_loss: 2.0616 - val_scce_loss: 1.3231 - val_perceptual_loss: 0.7386
# Epoch 189/2000
# 68/68 [==============================] - 421s 6s/step - total_loss: 0.6061 - scce_loss: 0.3795 - perceptual_loss: 0.2267 - val_total_loss: 2.0291 - val_scce_loss: 1.1871 - val_perceptual_loss: 0.8420
# Epoch 190/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.6255 - scce_loss: 0.3917 - perceptual_loss: 0.2338 - val_total_loss: 2.6359 - val_scce_loss: 1.6421 - val_perceptual_loss: 0.9938
# Epoch 191/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6049 - scce_loss: 0.3763 - perceptual_loss: 0.2286 - val_total_loss: 1.8422 - val_scce_loss: 1.2384 - val_perceptual_loss: 0.6039
# Epoch 192/2000
# 68/68 [==============================] - 411s 6s/step - total_loss: 0.5985 - scce_loss: 0.3702 - perceptual_loss: 0.2284 - val_total_loss: 2.2258 - val_scce_loss: 1.4101 - val_perceptual_loss: 0.8157
# Epoch 193/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.5992 - scce_loss: 0.3737 - perceptual_loss: 0.2254 - val_total_loss: 2.6338 - val_scce_loss: 1.5965 - val_perceptual_loss: 1.0372
# Epoch 194/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.6013 - scce_loss: 0.3722 - perceptual_loss: 0.2290 - val_total_loss: 2.2300 - val_scce_loss: 1.3943 - val_perceptual_loss: 0.8357
# Epoch 195/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.6032 - scce_loss: 0.3743 - perceptual_loss: 0.2289 - val_total_loss: 2.3427 - val_scce_loss: 1.3691 - val_perceptual_loss: 0.9737
# Epoch 196/2000
# 68/68 [==============================] - 408s 6s/step - total_loss: 0.5955 - scce_loss: 0.3722 - perceptual_loss: 0.2234 - val_total_loss: 2.3975 - val_scce_loss: 1.2511 - val_perceptual_loss: 1.1463
# Epoch 197/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.6005 - scce_loss: 0.3769 - perceptual_loss: 0.2236 - val_total_loss: 1.8676 - val_scce_loss: 1.1220 - val_perceptual_loss: 0.7456
# Epoch 198/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.5875 - scce_loss: 0.3683 - perceptual_loss: 0.2192 - val_total_loss: 1.9067 - val_scce_loss: 1.1191 - val_perceptual_loss: 0.7875
# Epoch 199/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.5852 - scce_loss: 0.3643 - perceptual_loss: 0.2209 - val_total_loss: 2.0584 - val_scce_loss: 1.2773 - val_perceptual_loss: 0.7811
# Epoch 200/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.6073 - scce_loss: 0.3731 - perceptual_loss: 0.2342 - val_total_loss: 2.5227 - val_scce_loss: 1.3359 - val_perceptual_loss: 1.1868
# Epoch 201/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.6017 - scce_loss: 0.3750 - perceptual_loss: 0.2267 - val_total_loss: 1.9578 - val_scce_loss: 1.2255 - val_perceptual_loss: 0.7323
# Epoch 202/2000
# 68/68 [==============================] - 421s 6s/step - total_loss: 0.5764 - scce_loss: 0.3540 - perceptual_loss: 0.2224 - val_total_loss: 2.0131 - val_scce_loss: 1.2970 - val_perceptual_loss: 0.7162
# Epoch 203/2000
# 68/68 [==============================] - 413s 6s/step - total_loss: 0.5912 - scce_loss: 0.3643 - perceptual_loss: 0.2269 - val_total_loss: 1.6763 - val_scce_loss: 1.0834 - val_perceptual_loss: 0.5929
# Epoch 204/2000
# 68/68 [==============================] - 415s 6s/step - total_loss: 0.5875 - scce_loss: 0.3631 - perceptual_loss: 0.2244 - val_total_loss: 2.1279 - val_scce_loss: 1.2731 - val_perceptual_loss: 0.8548
# Epoch 205/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.5866 - scce_loss: 0.3642 - perceptual_loss: 0.2224 - val_total_loss: 1.8595 - val_scce_loss: 1.1924 - val_perceptual_loss: 0.6670
# Epoch 206/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.5851 - scce_loss: 0.3556 - perceptual_loss: 0.2295 - val_total_loss: 2.3737 - val_scce_loss: 1.3338 - val_perceptual_loss: 1.0400
# Epoch 207/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.5809 - scce_loss: 0.3622 - perceptual_loss: 0.2187 - val_total_loss: 1.9084 - val_scce_loss: 1.0684 - val_perceptual_loss: 0.8399
# Epoch 208/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.5909 - scce_loss: 0.3589 - perceptual_loss: 0.2319 - val_total_loss: 1.6371 - val_scce_loss: 1.0807 - val_perceptual_loss: 0.5565
# Epoch 209/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.5712 - scce_loss: 0.3571 - perceptual_loss: 0.2142 - val_total_loss: 2.2156 - val_scce_loss: 1.2616 - val_perceptual_loss: 0.9541
# Epoch 210/2000
# 68/68 [==============================] - 416s 6s/step - total_loss: 0.5821 - scce_loss: 0.3570 - perceptual_loss: 0.2250 - val_total_loss: 1.5129 - val_scce_loss: 0.9261 - val_perceptual_loss: 0.5868
# Epoch 211/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.5536 - scce_loss: 0.3414 - perceptual_loss: 0.2121 - val_total_loss: 1.9882 - val_scce_loss: 1.2059 - val_perceptual_loss: 0.7823
# Epoch 212/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.5768 - scce_loss: 0.3518 - perceptual_loss: 0.2251 - val_total_loss: 1.8483 - val_scce_loss: 1.1531 - val_perceptual_loss: 0.6952
# Epoch 213/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.5821 - scce_loss: 0.3662 - perceptual_loss: 0.2159 - val_total_loss: 1.6580 - val_scce_loss: 1.0508 - val_perceptual_loss: 0.6072
# Epoch 214/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.5817 - scce_loss: 0.3548 - perceptual_loss: 0.2268 - val_total_loss: 1.5216 - val_scce_loss: 0.9638 - val_perceptual_loss: 0.5577
# Epoch 215/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.5703 - scce_loss: 0.3523 - perceptual_loss: 0.2180 - val_total_loss: 1.7660 - val_scce_loss: 1.0583 - val_perceptual_loss: 0.7077
# Epoch 216/2000
# 68/68 [==============================] - 414s 6s/step - total_loss: 0.5678 - scce_loss: 0.3520 - perceptual_loss: 0.2158 - val_total_loss: 2.5981 - val_scce_loss: 1.4953 - val_perceptual_loss: 1.1028
# Epoch 217/2000
# 68/68 [==============================] - 421s 6s/step - total_loss: 0.5589 - scce_loss: 0.3369 - perceptual_loss: 0.2220 - val_total_loss: 2.6016 - val_scce_loss: 1.4751 - val_perceptual_loss: 1.1265
# Epoch 218/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.5830 - scce_loss: 0.3591 - perceptual_loss: 0.2238 - val_total_loss: 1.9222 - val_scce_loss: 1.2105 - val_perceptual_loss: 0.7117
# Epoch 219/2000
# 68/68 [==============================] - 425s 6s/step - total_loss: 0.5494 - scce_loss: 0.3431 - perceptual_loss: 0.2064 - val_total_loss: 1.7822 - val_scce_loss: 1.2313 - val_perceptual_loss: 0.5508
# Epoch 220/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.5606 - scce_loss: 0.3429 - perceptual_loss: 0.2176 - val_total_loss: 1.9541 - val_scce_loss: 1.2729 - val_perceptual_loss: 0.6812
# Epoch 221/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.5520 - scce_loss: 0.3380 - perceptual_loss: 0.2141 - val_total_loss: 2.2326 - val_scce_loss: 1.3867 - val_perceptual_loss: 0.8460
# Epoch 222/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.5591 - scce_loss: 0.3422 - perceptual_loss: 0.2169 - val_total_loss: 1.7565 - val_scce_loss: 1.1622 - val_perceptual_loss: 0.5943
# Epoch 223/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.5366 - scce_loss: 0.3271 - perceptual_loss: 0.2095 - val_total_loss: 1.7610 - val_scce_loss: 1.0404 - val_perceptual_loss: 0.7206
# Epoch 224/2000
# ...
# Epoch 529/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.3594 - scce_loss: 0.1709 - perceptual_loss: 0.1885 - val_total_loss: 0.9880 - val_scce_loss: 0.4632 - val_perceptual_loss: 0.5248
# Epoch 530/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.3567 - scce_loss: 0.1747 - perceptual_loss: 0.1820 - val_total_loss: 1.3227 - val_scce_loss: 0.7961 - val_perceptual_loss: 0.5266
# Epoch 531/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0
2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.3579 - scce_loss: 0.1744 - perceptual_loss: 0.1836 - val_total_loss: 1.2042 - val_scce_loss: 0.6970 - val_perceptual_loss: 0.5072
# Epoch 561/2000
# 68/68 [==============================] - 426s 6s/step - total_loss: 0.3489 - scce_loss: 0.1754 - perceptual_loss: 0.1735 - val_total_loss: 1.0074 - val_scce_loss: 0.6706 - val_perceptual_loss: 0.3368
# Epoch 562/2000
# 68/68 [==============================] - 428s 6s/step - total_loss: 0.3457 - scce_loss: 0.1725 - perceptual_loss: 0.1732 - val_total_loss: 1.3407 - val_scce_loss: 0.8513 - val_perceptual_loss: 0.4894
# Epoch 563/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.3554 - scce_loss: 0.1759 - perceptual_loss: 0.1795 - val_total_loss: 1.0938 - val_scce_loss: 0.6435 - val_perceptual_loss: 0.4503
# Epoch 564/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.3466 - scce_loss: 0.1712 - perceptual_loss: 0.1754 - val_total_loss: 1.2592 - val_scce_loss: 0.7598 - val_perceptual_loss: 0.4994
# Epoch 565/2000
# 68/68 [==============================] - 425s 6s/step - total_loss: 0.3499 - scce_loss: 0.1689 - perceptual_loss: 0.1810 - val_total_loss: 1.4470 - val_scce_loss: 0.8761 - val_perceptual_loss: 0.5709
# Epoch 566/2000
# 68/68 [==============================] - 418s 6s/step - total_loss: 0.3503 - scce_loss: 0.1651 - perceptual_loss: 0.1852 - val_total_loss: 1.4277 - val_scce_loss: 0.9460 - val_perceptual_loss: 0.4817
# Epoch 567/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.3461 - scce_loss: 0.1688 - perceptual_loss: 0.1772 - val_total_loss: 1.3358 - val_scce_loss: 0.7916 - val_perceptual_loss: 0.5442
# Epoch 568/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.3406 - scce_loss: 0.1662 - perceptual_loss: 0.1744 - val_total_loss: 1.0726 - val_scce_loss: 0.7860 - val_perceptual_loss: 0.2866
# Epoch 569/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.3353 - scce_loss: 0.1630 - perceptual_loss: 0.1723 - val_total_loss: 1.2805 - val_scce_loss: 0.7330 - val_perceptual_loss: 0.5474
# Epoch 570/2000
# 68/68 [==============================] - 423s 6s/step - total_loss: 0.3445 - scce_loss: 0.1670 - perceptual_loss: 0.1775 - val_total_loss: 1.1380 - val_scce_loss: 0.7136 - val_perceptual_loss: 0.4244
# Epoch 571/2000
# 68/68 [==============================] - 430s 6s/step - total_loss: 0.3368 - scce_loss: 0.1646 - perceptual_loss: 0.1722 - val_total_loss: 1.5176 - val_scce_loss: 0.7778 - val_perceptual_loss: 0.7398
# Epoch 572/2000
# 68/68 [==============================] - 440s 6s/step - total_loss: 0.3531 - scce_loss: 0.1712 - perceptual_loss: 0.1819 - val_total_loss: 0.7857 - val_scce_loss: 0.4685 - val_perceptual_loss: 0.3172
# Epoch 573/2000
# 68/68 [==============================] - 432s 6s/step - total_loss: 0.3536 - scce_loss: 0.1717 - perceptual_loss: 0.1819 - val_total_loss: 1.4071 - val_scce_loss: 0.6978 - val_perceptual_loss: 0.7093
# Epoch 574/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.3559 - scce_loss: 0.1729 - perceptual_loss: 0.1830 - val_total_loss: 1.7717 - val_scce_loss: 0.8010 - val_perceptual_loss: 0.9707
# Epoch 575/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0
2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.3516 - scce_loss: 0.1675 - perceptual_loss: 0.1841 - val_total_loss: 1.0344 - val_scce_loss: 0.6115 - val_perceptual_loss: 0.4229
# Epoch 593/2000
# 68/68 [==============================] - 424s 6s/step - total_loss: 0.3500 - scce_loss: 0.1699 - perceptual_loss: 0.1801 - val_total_loss: 1.2274 - val_scce_loss: 0.7231 - val_perceptual_loss: 0.5043
# Epoch 594/2000
# 68/68 [==============================] - 422s 6s/step - total_loss: 0.3449 - scce_loss: 0.1624 - perceptual_loss: 0.1825 - val_total_loss: 1.1088 - val_scce_loss: 0.7228 - val_perceptual_loss: 0.3860
# Epoch 595/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.3699 - scce_loss: 0.1796 - perceptual_loss: 0.1904 - val_total_loss: 1.6922 - val_scce_loss: 0.8230 - val_perceptual_loss: 0.8691
# Epoch 596/2000
# 68/68 [==============================] - 420s 6s/step - total_loss: 0.3628 - scce_loss: 0.1770 - perceptual_loss: 0.1858 - val_total_loss: 1.7035 - val_scce_loss: 1.0409 - val_perceptual_loss: 0.6626
# Epoch 597/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.3620 - scce_loss: 0.1827 - perceptual_loss: 0.1793 - val_total_loss: 1.1262 - val_scce_loss: 0.5817 - val_perceptual_loss: 0.5445
# Epoch 598/2000
# 68/68 [==============================] - 428s 6s/step - total_loss: 0.3519 - scce_loss: 0.1693 - perceptual_loss: 0.1825 - val_total_loss: 0.8961 - val_scce_loss: 0.5986 - val_perceptual_loss: 0.2976
# Epoch 599/2000
# 68/68 [==============================] - 417s 6s/step - total_loss: 0.3402 - scce_loss: 0.1628 - perceptual_loss: 0.1774 - val_total_loss: 0.9346 - val_scce_loss: 0.5884 - val_perceptual_loss: 0.3462
# Epoch 600/2000
# 68/68 [==============================] - 419s 6s/step - total_loss: 0.3369 - scce_loss: 0.1611 - perceptual_loss: 0.1758 - val_total_loss: 1.1770 - val_scce_loss: 0.6771 - val_perceptual_loss: 0.4999
# Epoch 601/2000
# 68/68 [==============================] - 425s 6s/step - total_loss: 0.3407 - scce_loss: 0.1644 - perceptual_loss: 0.1763 - val_total_loss: 1.8869 - val_scce_loss: 1.0858 - val_perceptual_loss: 0.8011
# Epoch 602/2000
# 64/68 [===========================>..] - ETA: 23s - total_loss: 0.3470 - scce_loss: 0.1653 - perceptual_loss: 0.1817

# %%
with strategy.scope():
    generated_videos = model(sample, training=False)

# %%
for sample in validation_ds.take(1):
    vid = display_videos(sample["y"], n_rows=2, n_cols=4)
vid
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
display_videos(generated_videos, sample["y"], n_rows=2, n_cols=4)
# Out:
# <video width="1152" height="648" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
generated_videos.shape
# Out:
# TensorShape([8, 24, 64, 128, 3])

# %%
validation_sample_data["y"].shape
# Out:
# (8, 24, 64, 128, 3)

# %%
display_videos(train_sample_data["y"], 1, 4)

# %%
train_sample_data["remaining_frames"]
