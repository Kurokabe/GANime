# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0,2,3"
os.environ["NCCL_DEBUG"]="WARN"
#os.environ["NCCL_P2P_LEVEL"]="NODE"

# %%
import sys
sys.path.append("../../../")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import omegaconf
import numpy as np
import matplotlib.pyplot as plt
from ganime.data.experimental import ImageDataset, VideoDataset
from ganime.model.vqgan_clean.vqgan import VQGAN
from ganime.visualization.videos import display_videos
from ganime.visualization.images import display_images
import tensorflow as tf
from datetime import datetime
from tqdm import tqdm
import os
from pyprojroot.pyprojroot import here
#tf.get_logger().setLevel('ERROR')
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.8.0 and strictly below 2.11.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.7.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
for device in tf.config.list_physical_devices("GPU"):
    tf.config.experimental.set_memory_growth(device, True)

# %%
strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')

# %%
cfg = omegaconf.OmegaConf.load(here("configs/kny_image_full_vgg19_256.yaml"))

# %%
num_workers = len(tf.config.list_physical_devices("GPU"))
batch_size = cfg["trainer"]["batch_size"] 
global_batch_size = batch_size * strategy.num_replicas_in_sync
n_epochs = cfg["trainer"]["n_epochs"] 
sample_batch_size = 8

# %%
dataset_length = 34045 # KNY
# dataset_length = 310153 #KNY full
#dataset_length = 20*10000 # MNIST
num_batch = dataset_length / batch_size

# %%
# Normalizing the images to [-1, 1]
def normalize(image):
    image = (tf.cast(image, tf.float32) / 127.5) - 1

    return image

# %%
def random_crop(image, img_height=64, img_width=128):
    cropped_image = tf.image.random_crop(image, size=[img_height, img_width, 3])

    return cropped_image

# %%
@tf.function()
def random_jitter(image):
    # Resizing to 72x142
    image = tf.image.resize(image, [288, 576], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

    # Random cropping back to 64x128
    image = random_crop(image, img_height=256, img_width=512)

    if tf.random.uniform(()) > 0.5:
        # Random mirroring
        image = tf.image.flip_left_right(image)

    return image

# %%
def preprocess(image):
    image = tf.reshape(image, (tf.shape(image)[0], tf.shape(image)[1], 3))
    image = random_jitter(image)
    image = normalize(image)
    return image, image

# %%
dataset = ImageDataset("../../../data/kny/images_tfrecords_light_256").load()
dataset = dataset.shuffle(dataset_length, reshuffle_each_iteration=True, seed=10).map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_size = int(dataset_length * 0.8)
validation_size = int(dataset_length * 0.1)
test_size = int(dataset_length * 0.1)

# %%
train_ds = dataset.take(train_size)
validation_ds = dataset.skip(train_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)
test_ds = dataset.skip(train_size + validation_size).take(validation_size)#.padded_batch(global_batch_size).map(postprocess)

# %%
train_sample_data = next(train_ds
                          .batch(sample_batch_size)
                          .prefetch(tf.data.AUTOTUNE).as_numpy_iterator())
validation_sample_data = next(validation_ds.batch(sample_batch_size).as_numpy_iterator())

# %%
train_ds = (train_ds.batch(global_batch_size, drop_remainder=True)
            .prefetch(tf.data.AUTOTUNE))
validation_ds = (validation_ds.batch(global_batch_size, drop_remainder=True)
            .prefetch(tf.data.AUTOTUNE))
test_ds = (test_ds.batch(global_batch_size, drop_remainder=True)
            .prefetch(tf.data.AUTOTUNE))

# %%
train_sample_data[0].shape
# Out:
# (8, 256, 512, 3)

# %%
display_images(train_sample_data[0], n_rows=2, n_cols=4)

# %%
from ganime.utils.callbacks import TensorboardImage, get_logdir

logdir = "../../../logs/ganime/vqgan/resolution_256_2022-10-24_06-23-29"#get_logdir("../../../logs/ganime/vqgan", experiment_name="resolution_256")
# Define the basic TensorBoard callback.
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_image_callback = TensorboardImage(logdir, train_sample_data, validation_sample_data)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_total_loss",
    min_delta=0.0001,
    patience=100,
    restore_best_weights=True,
)
checkpointing = tf.keras.callbacks.ModelCheckpoint(os.path.join(logdir, "checkpoint", "checkpoint"), monitor='val_reconstruction_loss', save_best_only=True, save_weights_only=True)
callbacks = [tensorboard_callback, tensorboard_image_callback, checkpointing]

# %%
# train_mean, train_var, train_std = dataset_statistics(train_ds)

# %%
from ganime.visualization.images import display_true_pred

# %%
with strategy.scope():
    vqgan = VQGAN(**cfg["model"], num_replicas=strategy.num_replicas_in_sync)
# Out:
# Working with z of shape (1, 256, 16, 16) = 65536 dimensions.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# VQLPIPSWithDiscriminator running with hinge loss.

# %%
with strategy.scope():
    gen_optimizer = tf.keras.optimizers.Adam(
                learning_rate=cfg["trainer"]["gen_lr"],
                beta_1=cfg["trainer"]["gen_beta_1"],
                beta_2=cfg["trainer"]["gen_beta_2"],
                clipnorm=cfg["trainer"]["gen_clip_norm"],
    )
    disc_optimizer = tf.keras.optimizers.Adam(
        learning_rate=cfg["trainer"]["disc_lr"],
        beta_1=cfg["trainer"]["disc_beta_1"],
        beta_2=cfg["trainer"]["disc_beta_2"],
        clipnorm=cfg["trainer"]["disc_clip_norm"],
    )
    vqgan.compile(gen_optimizer=gen_optimizer, disc_optimizer=disc_optimizer)

# %%
history = vqgan.fit(train_ds, initial_epoch=1, validation_data=validation_ds, epochs=n_epochs, callbacks=callbacks)
# Out:
# Epoch 2/10000
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 213 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 13 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 567/567 [==============================] - 1924s 3s/step - total_loss: 87.2963 - reconstruction_loss: 2.6309 - vq_loss: 84.6655 - disc_loss: 0.0000e+00 - val_total_loss: 98.6831 - val_reconstruction_loss: 2.5163 - val_vq_loss: 96.1668 - val_disc_loss: 0.0000e+00
# Epoch 3/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 94.5407 - reconstruction_loss: 2.5182 - vq_loss: 92.0225 - disc_loss: 0.0000e+00 - val_total_loss: 94.4632 - val_reconstruction_loss: 2.4784 - val_vq_loss: 91.9848 - val_disc_loss: 0.0000e+00
# Epoch 4/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 93.9291 - reconstruction_loss: 2.4564 - vq_loss: 91.4727 - disc_loss: 0.0000e+00 - val_total_loss: 98.7878 - val_reconstruction_loss: 2.4454 - val_vq_loss: 96.3424 - val_disc_loss: 0.0000e+00
# Epoch 5/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 90.3266 - reconstruction_loss: 2.4083 - vq_loss: 87.9184 - disc_loss: 0.0000e+00 - val_total_loss: 85.2071 - val_reconstruction_loss: 2.3898 - val_vq_loss: 82.8172 - val_disc_loss: 0.0000e+00
# Epoch 6/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 84.5460 - reconstruction_loss: 2.3663 - vq_loss: 82.1797 - disc_loss: 0.0000e+00 - val_total_loss: 80.5751 - val_reconstruction_loss: 2.3365 - val_vq_loss: 78.2386 - val_disc_loss: 0.0000e+00
# Epoch 7/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 79.2805 - reconstruction_loss: 2.3289 - vq_loss: 76.9516 - disc_loss: 0.0000e+00 - val_total_loss: 76.9057 - val_reconstruction_loss: 2.3249 - val_vq_loss: 74.5807 - val_disc_loss: 0.0000e+00
# Epoch 8/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 74.8070 - reconstruction_loss: 2.2918 - vq_loss: 72.5152 - disc_loss: 0.0000e+00 - val_total_loss: 76.9570 - val_reconstruction_loss: 2.2818 - val_vq_loss: 74.6752 - val_disc_loss: 0.0000e+00
# Epoch 9/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 72.1118 - reconstruction_loss: 2.2650 - vq_loss: 69.8468 - disc_loss: 0.0000e+00 - val_total_loss: 69.5614 - val_reconstruction_loss: 2.2560 - val_vq_loss: 67.3054 - val_disc_loss: 0.0000e+00
# Epoch 10/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 69.0112 - reconstruction_loss: 2.2399 - vq_loss: 66.7713 - disc_loss: 0.0000e+00 - val_total_loss: 65.6343 - val_reconstruction_loss: 2.2188 - val_vq_loss: 63.4155 - val_disc_loss: 0.0000e+00
# Epoch 11/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 67.3364 - reconstruction_loss: 2.2111 - vq_loss: 65.1254 - disc_loss: 0.0000e+00 - val_total_loss: 70.1552 - val_reconstruction_loss: 2.2107 - val_vq_loss: 67.9445 - val_disc_loss: 0.0000e+00
# Epoch 12/10000
# 567/567 [==============================] - 1689s 3s/step - total_loss: 66.0182 - reconstruction_loss: 2.1882 - vq_loss: 63.8300 - disc_loss: 0.0000e+00 - val_total_loss: 70.2720 - val_reconstruction_loss: 2.1596 - val_vq_loss: 68.1125 - val_disc_loss: 0.0000e+00
# Epoch 13/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 65.5250 - reconstruction_loss: 2.1684 - vq_loss: 63.3566 - disc_loss: 0.0000e+00 - val_total_loss: 66.1254 - val_reconstruction_loss: 2.1298 - val_vq_loss: 63.9956 - val_disc_loss: 0.0000e+00
# Epoch 14/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 65.3039 - reconstruction_loss: 2.1447 - vq_loss: 63.1593 - disc_loss: 0.0000e+00 - val_total_loss: 64.8488 - val_reconstruction_loss: 2.1457 - val_vq_loss: 62.7031 - val_disc_loss: 0.0000e+00
# Epoch 15/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 65.9227 - reconstruction_loss: 2.1280 - vq_loss: 63.7948 - disc_loss: 0.0000e+00 - val_total_loss: 71.9424 - val_reconstruction_loss: 2.1306 - val_vq_loss: 69.8119 - val_disc_loss: 0.0000e+00
# Epoch 16/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 66.8537 - reconstruction_loss: 2.1151 - vq_loss: 64.7386 - disc_loss: 0.0000e+00 - val_total_loss: 64.2430 - val_reconstruction_loss: 2.0904 - val_vq_loss: 62.1526 - val_disc_loss: 0.0000e+00
# Epoch 17/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 67.9521 - reconstruction_loss: 2.0958 - vq_loss: 65.8564 - disc_loss: 0.0000e+00 - val_total_loss: 68.3986 - val_reconstruction_loss: 2.0890 - val_vq_loss: 66.3096 - val_disc_loss: 0.0000e+00
# Epoch 18/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 69.6667 - reconstruction_loss: 2.0816 - vq_loss: 67.5851 - disc_loss: 0.0000e+00 - val_total_loss: 69.2519 - val_reconstruction_loss: 2.0792 - val_vq_loss: 67.1727 - val_disc_loss: 0.0000e+00
# Epoch 19/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 71.1654 - reconstruction_loss: 2.0682 - vq_loss: 69.0972 - disc_loss: 0.0000e+00 - val_total_loss: 67.6053 - val_reconstruction_loss: 2.0621 - val_vq_loss: 65.5432 - val_disc_loss: 0.0000e+00
# Epoch 20/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 73.0564 - reconstruction_loss: 2.0517 - vq_loss: 71.0047 - disc_loss: 0.0000e+00 - val_total_loss: 74.2324 - val_reconstruction_loss: 2.0276 - val_vq_loss: 72.2048 - val_disc_loss: 0.0000e+00
# Epoch 21/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 75.1718 - reconstruction_loss: 2.0403 - vq_loss: 73.1315 - disc_loss: 0.0000e+00 - val_total_loss: 74.8532 - val_reconstruction_loss: 1.9973 - val_vq_loss: 72.8559 - val_disc_loss: 0.0000e+00
# Epoch 22/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 77.2403 - reconstruction_loss: 2.0262 - vq_loss: 75.2141 - disc_loss: 0.0000e+00 - val_total_loss: 85.5729 - val_reconstruction_loss: 2.0447 - val_vq_loss: 83.5281 - val_disc_loss: 0.0000e+00
# Epoch 23/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 79.0055 - reconstruction_loss: 2.0140 - vq_loss: 76.9915 - disc_loss: 0.0000e+00 - val_total_loss: 83.3940 - val_reconstruction_loss: 2.0175 - val_vq_loss: 81.3766 - val_disc_loss: 0.0000e+00
# Epoch 24/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 80.9285 - reconstruction_loss: 2.0073 - vq_loss: 78.9213 - disc_loss: 0.0000e+00 - val_total_loss: 79.5207 - val_reconstruction_loss: 1.9970 - val_vq_loss: 77.5237 - val_disc_loss: 0.0000e+00
# Epoch 25/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 82.6327 - reconstruction_loss: 1.9936 - vq_loss: 80.6390 - disc_loss: 0.0000e+00 - val_total_loss: 82.7585 - val_reconstruction_loss: 1.9632 - val_vq_loss: 80.7953 - val_disc_loss: 0.0000e+00
# Epoch 26/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 84.1684 - reconstruction_loss: 1.9825 - vq_loss: 82.1858 - disc_loss: 0.0000e+00 - val_total_loss: 89.2986 - val_reconstruction_loss: 1.9796 - val_vq_loss: 87.3189 - val_disc_loss: 0.0000e+00
# Epoch 27/10000
# 567/567 [==============================] - 1683s 3s/step - total_loss: 85.5434 - reconstruction_loss: 1.9706 - vq_loss: 83.5728 - disc_loss: 0.0000e+00 - val_total_loss: 86.7807 - val_reconstruction_loss: 1.9741 - val_vq_loss: 84.8066 - val_disc_loss: 0.0000e+00
# Epoch 28/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 87.6070 - reconstruction_loss: 1.9597 - vq_loss: 85.6473 - disc_loss: 0.0000e+00 - val_total_loss: 86.0268 - val_reconstruction_loss: 1.9520 - val_vq_loss: 84.0748 - val_disc_loss: 0.0000e+00
# Epoch 29/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 89.2032 - reconstruction_loss: 1.9539 - vq_loss: 87.2492 - disc_loss: 0.0000e+00 - val_total_loss: 93.6622 - val_reconstruction_loss: 1.9350 - val_vq_loss: 91.7272 - val_disc_loss: 0.0000e+00
# Epoch 30/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 90.2622 - reconstruction_loss: 1.9450 - vq_loss: 88.3172 - disc_loss: 0.0000e+00 - val_total_loss: 90.6397 - val_reconstruction_loss: 1.9443 - val_vq_loss: 88.6954 - val_disc_loss: 0.0000e+00
# Epoch 31/10000
# 567/567 [==============================] - 1689s 3s/step - total_loss: 92.1475 - reconstruction_loss: 1.9346 - vq_loss: 90.2129 - disc_loss: 0.0000e+00 - val_total_loss: 96.4176 - val_reconstruction_loss: 1.9200 - val_vq_loss: 94.4976 - val_disc_loss: 0.0000e+00
# Epoch 32/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 93.6898 - reconstruction_loss: 1.9285 - vq_loss: 91.7613 - disc_loss: 0.0000e+00 - val_total_loss: 97.8844 - val_reconstruction_loss: 1.9201 - val_vq_loss: 95.9643 - val_disc_loss: 0.0000e+00
# Epoch 33/10000
# 567/567 [==============================] - 1691s 3s/step - total_loss: 94.8270 - reconstruction_loss: 1.9178 - vq_loss: 92.9092 - disc_loss: 0.0000e+00 - val_total_loss: 96.7111 - val_reconstruction_loss: 1.9080 - val_vq_loss: 94.8031 - val_disc_loss: 0.0000e+00
# Epoch 34/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 96.0290 - reconstruction_loss: 1.9089 - vq_loss: 94.1202 - disc_loss: 0.0000e+00 - val_total_loss: 94.1531 - val_reconstruction_loss: 1.9082 - val_vq_loss: 92.2449 - val_disc_loss: 0.0000e+00
# Epoch 35/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 97.0045 - reconstruction_loss: 1.9005 - vq_loss: 95.1040 - disc_loss: 0.0000e+00 - val_total_loss: 100.1831 - val_reconstruction_loss: 1.8906 - val_vq_loss: 98.2924 - val_disc_loss: 0.0000e+00
# Epoch 36/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 98.3928 - reconstruction_loss: 1.8959 - vq_loss: 96.4969 - disc_loss: 0.0000e+00 - val_total_loss: 97.8443 - val_reconstruction_loss: 1.8804 - val_vq_loss: 95.9639 - val_disc_loss: 0.0000e+00
# Epoch 37/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 98.9425 - reconstruction_loss: 1.8828 - vq_loss: 97.0598 - disc_loss: 0.0000e+00 - val_total_loss: 95.4650 - val_reconstruction_loss: 1.8679 - val_vq_loss: 93.5971 - val_disc_loss: 0.0000e+00
# Epoch 38/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 100.3584 - reconstruction_loss: 1.8789 - vq_loss: 98.4795 - disc_loss: 0.0000e+00 - val_total_loss: 102.6918 - val_reconstruction_loss: 1.8759 - val_vq_loss: 100.8158 - val_disc_loss: 0.0000e+00
# Epoch 39/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 100.9839 - reconstruction_loss: 1.8717 - vq_loss: 99.1122 - disc_loss: 0.0000e+00 - val_total_loss: 102.0284 - val_reconstruction_loss: 1.8774 - val_vq_loss: 100.1510 - val_disc_loss: 0.0000e+00
# Epoch 40/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 101.1187 - reconstruction_loss: 1.8636 - vq_loss: 99.2551 - disc_loss: 0.0000e+00 - val_total_loss: 101.5077 - val_reconstruction_loss: 1.8698 - val_vq_loss: 99.6378 - val_disc_loss: 0.0000e+00
# Epoch 41/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 102.0331 - reconstruction_loss: 1.8603 - vq_loss: 100.1728 - disc_loss: 0.0000e+00 - val_total_loss: 108.0153 - val_reconstruction_loss: 1.8770 - val_vq_loss: 106.1383 - val_disc_loss: 0.0000e+00
# Epoch 42/10000
# 567/567 [==============================] - 1689s 3s/step - total_loss: 102.5309 - reconstruction_loss: 1.8578 - vq_loss: 100.6731 - disc_loss: 0.0000e+00 - val_total_loss: 101.6075 - val_reconstruction_loss: 1.8504 - val_vq_loss: 99.7571 - val_disc_loss: 0.0000e+00
# Epoch 43/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 102.3201 - reconstruction_loss: 1.8447 - vq_loss: 100.4754 - disc_loss: 0.0000e+00 - val_total_loss: 102.3875 - val_reconstruction_loss: 1.8505 - val_vq_loss: 100.5370 - val_disc_loss: 0.0000e+00
# Epoch 44/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 102.6862 - reconstruction_loss: 1.8412 - vq_loss: 100.8450 - disc_loss: 0.0000e+00 - val_total_loss: 103.4551 - val_reconstruction_loss: 1.8521 - val_vq_loss: 101.6030 - val_disc_loss: 0.0000e+00
# Epoch 45/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 102.5253 - reconstruction_loss: 1.8333 - vq_loss: 100.6920 - disc_loss: 0.0000e+00 - val_total_loss: 102.1837 - val_reconstruction_loss: 1.8440 - val_vq_loss: 100.3397 - val_disc_loss: 0.0000e+00
# Epoch 46/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 102.8343 - reconstruction_loss: 1.8271 - vq_loss: 101.0072 - disc_loss: 0.0000e+00 - val_total_loss: 98.2743 - val_reconstruction_loss: 1.8221 - val_vq_loss: 96.4521 - val_disc_loss: 0.0000e+00
# Epoch 47/10000
# 567/567 [==============================] - 1692s 3s/step - total_loss: 103.0616 - reconstruction_loss: 1.8176 - vq_loss: 101.2440 - disc_loss: 0.0000e+00 - val_total_loss: 98.5049 - val_reconstruction_loss: 1.8080 - val_vq_loss: 96.6969 - val_disc_loss: 0.0000e+00
# Epoch 48/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 103.4314 - reconstruction_loss: 1.8137 - vq_loss: 101.6177 - disc_loss: 0.0000e+00 - val_total_loss: 110.1640 - val_reconstruction_loss: 1.8296 - val_vq_loss: 108.3344 - val_disc_loss: 0.0000e+00
# Epoch 49/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 103.7064 - reconstruction_loss: 1.8071 - vq_loss: 101.8992 - disc_loss: 0.0000e+00 - val_total_loss: 108.4378 - val_reconstruction_loss: 1.8041 - val_vq_loss: 106.6337 - val_disc_loss: 0.0000e+00
# Epoch 50/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 104.0995 - reconstruction_loss: 1.8020 - vq_loss: 102.2975 - disc_loss: 0.0000e+00 - val_total_loss: 112.2609 - val_reconstruction_loss: 1.7952 - val_vq_loss: 110.4657 - val_disc_loss: 0.0000e+00
# Epoch 51/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 104.8074 - reconstruction_loss: 1.7977 - vq_loss: 103.0096 - disc_loss: 0.0000e+00 - val_total_loss: 103.7192 - val_reconstruction_loss: 1.7799 - val_vq_loss: 101.9393 - val_disc_loss: 0.0000e+00
# Epoch 52/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 105.0255 - reconstruction_loss: 1.7903 - vq_loss: 103.2352 - disc_loss: 0.0000e+00 - val_total_loss: 98.4769 - val_reconstruction_loss: 1.7940 - val_vq_loss: 96.6829 - val_disc_loss: 0.0000e+00
# Epoch 53/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 105.1137 - reconstruction_loss: 1.7858 - vq_loss: 103.3279 - disc_loss: 0.0000e+00 - val_total_loss: 105.9716 - val_reconstruction_loss: 1.7731 - val_vq_loss: 104.1985 - val_disc_loss: 0.0000e+00
# Epoch 54/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 105.4155 - reconstruction_loss: 1.7797 - vq_loss: 103.6358 - disc_loss: 0.0000e+00 - val_total_loss: 98.7257 - val_reconstruction_loss: 1.7802 - val_vq_loss: 96.9455 - val_disc_loss: 0.0000e+00
# Epoch 55/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 106.3143 - reconstruction_loss: 1.7756 - vq_loss: 104.5387 - disc_loss: 0.0000e+00 - val_total_loss: 113.3060 - val_reconstruction_loss: 1.7933 - val_vq_loss: 111.5128 - val_disc_loss: 0.0000e+00
# Epoch 56/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 106.6145 - reconstruction_loss: 1.7723 - vq_loss: 104.8422 - disc_loss: 0.0000e+00 - val_total_loss: 105.8484 - val_reconstruction_loss: 1.7772 - val_vq_loss: 104.0712 - val_disc_loss: 0.0000e+00
# Epoch 57/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 107.3831 - reconstruction_loss: 1.7674 - vq_loss: 105.6157 - disc_loss: 0.0000e+00 - val_total_loss: 97.5091 - val_reconstruction_loss: 1.7662 - val_vq_loss: 95.7429 - val_disc_loss: 0.0000e+00
# Epoch 58/10000
# 567/567 [==============================] - 1683s 3s/step - total_loss: 108.0761 - reconstruction_loss: 1.7592 - vq_loss: 106.3169 - disc_loss: 0.0000e+00 - val_total_loss: 100.6758 - val_reconstruction_loss: 1.7683 - val_vq_loss: 98.9075 - val_disc_loss: 0.0000e+00
# Epoch 59/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 108.8288 - reconstruction_loss: 1.7564 - vq_loss: 107.0723 - disc_loss: 0.0000e+00 - val_total_loss: 113.1926 - val_reconstruction_loss: 1.7653 - val_vq_loss: 111.4273 - val_disc_loss: 0.0000e+00
# Epoch 60/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 109.5723 - reconstruction_loss: 1.7532 - vq_loss: 107.8191 - disc_loss: 0.0000e+00 - val_total_loss: 102.6520 - val_reconstruction_loss: 1.7564 - val_vq_loss: 100.8956 - val_disc_loss: 0.0000e+00
# Epoch 61/10000
# 567/567 [==============================] - 1693s 3s/step - total_loss: 110.5400 - reconstruction_loss: 1.7475 - vq_loss: 108.7925 - disc_loss: 0.0000e+00 - val_total_loss: 115.9325 - val_reconstruction_loss: 1.7600 - val_vq_loss: 114.1724 - val_disc_loss: 0.0000e+00
# Epoch 62/10000
# 567/567 [==============================] - 1694s 3s/step - total_loss: 111.2059 - reconstruction_loss: 1.7435 - vq_loss: 109.4624 - disc_loss: 0.0000e+00 - val_total_loss: 113.0655 - val_reconstruction_loss: 1.7468 - val_vq_loss: 111.3188 - val_disc_loss: 0.0000e+00
# Epoch 63/10000
# 567/567 [==============================] - 1703s 3s/step - total_loss: 111.6774 - reconstruction_loss: 1.7418 - vq_loss: 109.9356 - disc_loss: 0.0000e+00 - val_total_loss: 109.8427 - val_reconstruction_loss: 1.7309 - val_vq_loss: 108.1118 - val_disc_loss: 0.0000e+00
# Epoch 64/10000
# 567/567 [==============================] - 1694s 3s/step - total_loss: 111.9022 - reconstruction_loss: 1.7354 - vq_loss: 110.1667 - disc_loss: 0.0000e+00 - val_total_loss: 110.3272 - val_reconstruction_loss: 1.7243 - val_vq_loss: 108.6028 - val_disc_loss: 0.0000e+00
# Epoch 65/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 112.4260 - reconstruction_loss: 1.7309 - vq_loss: 110.6951 - disc_loss: 0.0000e+00 - val_total_loss: 116.1977 - val_reconstruction_loss: 1.7347 - val_vq_loss: 114.4630 - val_disc_loss: 0.0000e+00
# Epoch 66/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 112.8360 - reconstruction_loss: 1.7274 - vq_loss: 111.1086 - disc_loss: 0.0000e+00 - val_total_loss: 116.2078 - val_reconstruction_loss: 1.7335 - val_vq_loss: 114.4743 - val_disc_loss: 0.0000e+00
# Epoch 67/10000
# 567/567 [==============================] - 1688s 3s/step - total_loss: 112.8775 - reconstruction_loss: 1.7182 - vq_loss: 111.1593 - disc_loss: 0.0000e+00 - val_total_loss: 111.2974 - val_reconstruction_loss: 1.7094 - val_vq_loss: 109.5880 - val_disc_loss: 0.0000e+00
# Epoch 68/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 112.9059 - reconstruction_loss: 1.7155 - vq_loss: 111.1904 - disc_loss: 0.0000e+00 - val_total_loss: 110.2337 - val_reconstruction_loss: 1.7149 - val_vq_loss: 108.5189 - val_disc_loss: 0.0000e+00
# Epoch 69/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 113.1838 - reconstruction_loss: 1.7129 - vq_loss: 111.4708 - disc_loss: 0.0000e+00 - val_total_loss: 109.1570 - val_reconstruction_loss: 1.7008 - val_vq_loss: 107.4562 - val_disc_loss: 0.0000e+00
# Epoch 70/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 113.2576 - reconstruction_loss: 1.7101 - vq_loss: 111.5475 - disc_loss: 0.0000e+00 - val_total_loss: 112.9053 - val_reconstruction_loss: 1.6929 - val_vq_loss: 111.2124 - val_disc_loss: 0.0000e+00
# Epoch 71/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 112.6520 - reconstruction_loss: 1.7048 - vq_loss: 110.9472 - disc_loss: 0.0000e+00 - val_total_loss: 115.9438 - val_reconstruction_loss: 1.7156 - val_vq_loss: 114.2282 - val_disc_loss: 0.0000e+00
# Epoch 72/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 112.4808 - reconstruction_loss: 1.7024 - vq_loss: 110.7784 - disc_loss: 0.0000e+00 - val_total_loss: 112.7487 - val_reconstruction_loss: 1.7045 - val_vq_loss: 111.0442 - val_disc_loss: 0.0000e+00
# Epoch 73/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 112.6493 - reconstruction_loss: 1.6995 - vq_loss: 110.9498 - disc_loss: 0.0000e+00 - val_total_loss: 112.3197 - val_reconstruction_loss: 1.6974 - val_vq_loss: 110.6223 - val_disc_loss: 0.0000e+00
# Epoch 74/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 111.5304 - reconstruction_loss: 1.6920 - vq_loss: 109.8383 - disc_loss: 0.0000e+00 - val_total_loss: 111.7166 - val_reconstruction_loss: 1.7071 - val_vq_loss: 110.0095 - val_disc_loss: 0.0000e+00
# Epoch 75/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 111.4838 - reconstruction_loss: 1.6869 - vq_loss: 109.7969 - disc_loss: 0.0000e+00 - val_total_loss: 116.9165 - val_reconstruction_loss: 1.6934 - val_vq_loss: 115.2231 - val_disc_loss: 0.0000e+00
# Epoch 76/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 111.3898 - reconstruction_loss: 1.6858 - vq_loss: 109.7040 - disc_loss: 0.0000e+00 - val_total_loss: 109.1173 - val_reconstruction_loss: 1.6909 - val_vq_loss: 107.4263 - val_disc_loss: 0.0000e+00
# Epoch 77/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 111.2462 - reconstruction_loss: 1.6842 - vq_loss: 109.5620 - disc_loss: 0.0000e+00 - val_total_loss: 113.5597 - val_reconstruction_loss: 1.6745 - val_vq_loss: 111.8852 - val_disc_loss: 0.0000e+00
# Epoch 78/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 110.8898 - reconstruction_loss: 1.6766 - vq_loss: 109.2131 - disc_loss: 0.0000e+00 - val_total_loss: 115.5283 - val_reconstruction_loss: 1.6587 - val_vq_loss: 113.8696 - val_disc_loss: 0.0000e+00
# Epoch 79/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 110.3683 - reconstruction_loss: 1.6710 - vq_loss: 108.6973 - disc_loss: 0.0000e+00 - val_total_loss: 108.2499 - val_reconstruction_loss: 1.6632 - val_vq_loss: 106.5867 - val_disc_loss: 0.0000e+00
# Epoch 80/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 110.5846 - reconstruction_loss: 1.6697 - vq_loss: 108.9148 - disc_loss: 0.0000e+00 - val_total_loss: 113.4053 - val_reconstruction_loss: 1.6828 - val_vq_loss: 111.7225 - val_disc_loss: 0.0000e+00
# Epoch 81/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 110.8058 - reconstruction_loss: 1.6672 - vq_loss: 109.1386 - disc_loss: 0.0000e+00 - val_total_loss: 105.2695 - val_reconstruction_loss: 1.6424 - val_vq_loss: 103.6271 - val_disc_loss: 0.0000e+00
# Epoch 82/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 110.8782 - reconstruction_loss: 1.6607 - vq_loss: 109.2175 - disc_loss: 0.0000e+00 - val_total_loss: 118.5456 - val_reconstruction_loss: 1.6617 - val_vq_loss: 116.8839 - val_disc_loss: 0.0000e+00
# Epoch 83/10000
# 567/567 [==============================] - 1692s 3s/step - total_loss: 111.1046 - reconstruction_loss: 1.6586 - vq_loss: 109.4461 - disc_loss: 0.0000e+00 - val_total_loss: 103.1911 - val_reconstruction_loss: 1.6497 - val_vq_loss: 101.5413 - val_disc_loss: 0.0000e+00
# Epoch 84/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 132.9750 - reconstruction_loss: 1.7704 - vq_loss: 130.6269 - disc_loss: 0.3530 - val_total_loss: 145.5586 - val_reconstruction_loss: 1.7594 - val_vq_loss: 143.7802 - val_disc_loss: 1.1045
# Epoch 85/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 143.6555 - reconstruction_loss: 1.8167 - vq_loss: 140.1577 - disc_loss: 0.0180 - val_total_loss: 155.2326 - val_reconstruction_loss: 1.7059 - val_vq_loss: 153.4367 - val_disc_loss: 1.3182
# Epoch 86/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 154.2233 - reconstruction_loss: 1.7808 - vq_loss: 150.5204 - disc_loss: 0.0083 - val_total_loss: 183.4985 - val_reconstruction_loss: 1.7508 - val_vq_loss: 181.5764 - val_disc_loss: 1.1232
# Epoch 87/10000
# 567/567 [==============================] - 1684s 3s/step - total_loss: 156.2197 - reconstruction_loss: 1.7785 - vq_loss: 152.3988 - disc_loss: 0.0030 - val_total_loss: 166.2812 - val_reconstruction_loss: 1.6941 - val_vq_loss: 164.5839 - val_disc_loss: 1.1735
# Epoch 88/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 165.5324 - reconstruction_loss: 1.7380 - vq_loss: 162.4900 - disc_loss: 0.0030 - val_total_loss: 131.6918 - val_reconstruction_loss: 1.7287 - val_vq_loss: 129.9059 - val_disc_loss: 0.9473
# Epoch 89/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 161.6252 - reconstruction_loss: 1.7465 - vq_loss: 158.7145 - disc_loss: 0.0043 - val_total_loss: 132.9911 - val_reconstruction_loss: 1.8158 - val_vq_loss: 131.3435 - val_disc_loss: 1.0255
# Epoch 90/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 152.9801 - reconstruction_loss: 1.7718 - vq_loss: 149.5084 - disc_loss: 0.0018 - val_total_loss: 160.7203 - val_reconstruction_loss: 1.7242 - val_vq_loss: 158.9348 - val_disc_loss: 0.9886
# Epoch 91/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 162.8501 - reconstruction_loss: 1.7583 - vq_loss: 159.6157 - disc_loss: 0.0015 - val_total_loss: 168.9653 - val_reconstruction_loss: 1.8237 - val_vq_loss: 167.1929 - val_disc_loss: 1.3976
# Epoch 92/10000
# 567/567 [==============================] - 1683s 3s/step - total_loss: 169.6909 - reconstruction_loss: 1.7614 - vq_loss: 166.0427 - disc_loss: 0.0012 - val_total_loss: 180.9463 - val_reconstruction_loss: 1.7471 - val_vq_loss: 179.2044 - val_disc_loss: 1.4525
# Epoch 93/10000
# 567/567 [==============================] - 1689s 3s/step - total_loss: 174.4895 - reconstruction_loss: 1.7242 - vq_loss: 171.5035 - disc_loss: 0.0021 - val_total_loss: 166.4689 - val_reconstruction_loss: 1.7086 - val_vq_loss: 164.8340 - val_disc_loss: 1.2414
# Epoch 94/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 175.6994 - reconstruction_loss: 1.7645 - vq_loss: 172.1911 - disc_loss: 2.6835e-04 - val_total_loss: 155.9660 - val_reconstruction_loss: 1.7832 - val_vq_loss: 154.2249 - val_disc_loss: 1.8350
# Epoch 95/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 183.9591 - reconstruction_loss: 1.7482 - vq_loss: 180.6203 - disc_loss: 7.7724e-04 - val_total_loss: 181.6665 - val_reconstruction_loss: 1.8691 - val_vq_loss: 179.7009 - val_disc_loss: 0.9935
# Epoch 96/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 178.3838 - reconstruction_loss: 1.7699 - vq_loss: 174.9887 - disc_loss: 0.0023 - val_total_loss: 161.8057 - val_reconstruction_loss: 1.7410 - val_vq_loss: 160.0706 - val_disc_loss: 1.2013
# Epoch 97/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 182.9028 - reconstruction_loss: 1.7445 - vq_loss: 179.7257 - disc_loss: 8.7547e-04 - val_total_loss: 196.6419 - val_reconstruction_loss: 1.8394 - val_vq_loss: 194.8565 - val_disc_loss: 1.2828
# Epoch 98/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 180.4606 - reconstruction_loss: 1.8017 - vq_loss: 176.7357 - disc_loss: 0.0017 - val_total_loss: 175.0926 - val_reconstruction_loss: 1.7515 - val_vq_loss: 173.3678 - val_disc_loss: 1.4180
# Epoch 99/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 179.7133 - reconstruction_loss: 1.7564 - vq_loss: 176.3182 - disc_loss: 6.3086e-04 - val_total_loss: 149.9519 - val_reconstruction_loss: 1.7845 - val_vq_loss: 148.2069 - val_disc_loss: 1.6720
# Epoch 100/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 164.2446 - reconstruction_loss: 1.8293 - vq_loss: 159.9691 - disc_loss: 0.0012 - val_total_loss: 161.0011 - val_reconstruction_loss: 1.7584 - val_vq_loss: 159.2947 - val_disc_loss: 1.3308
# Epoch 101/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 176.4402 - reconstruction_loss: 1.7497 - vq_loss: 173.3899 - disc_loss: 0.0023 - val_total_loss: 168.4120 - val_reconstruction_loss: 1.7734 - val_vq_loss: 166.7053 - val_disc_loss: 1.7443
# Epoch 102/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 177.0878 - reconstruction_loss: 1.7559 - vq_loss: 173.7926 - disc_loss: 2.0765e-04 - val_total_loss: 185.4119 - val_reconstruction_loss: 1.7601 - val_vq_loss: 183.7197 - val_disc_loss: 1.6533
# Epoch 103/10000
# 567/567 [==============================] - 1685s 3s/step - total_loss: 171.0190 - reconstruction_loss: 1.7938 - vq_loss: 166.9923 - disc_loss: 8.0065e-04 - val_total_loss: 134.3252 - val_reconstruction_loss: 1.7867 - val_vq_loss: 132.3863 - val_disc_loss: 1.1267
# Epoch 104/10000
# 567/567 [==============================] - 1683s 3s/step - total_loss: 159.3958 - reconstruction_loss: 1.8228 - vq_loss: 154.9140 - disc_loss: 1.1053e-04 - val_total_loss: 161.0702 - val_reconstruction_loss: 1.7731 - val_vq_loss: 159.1395 - val_disc_loss: 1.0793
# Epoch 105/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 151.1239 - reconstruction_loss: 1.8208 - vq_loss: 146.8640 - disc_loss: 6.4614e-05 - val_total_loss: 157.5759 - val_reconstruction_loss: 1.7987 - val_vq_loss: 155.6043 - val_disc_loss: 1.0759
# Epoch 106/10000
# 567/567 [==============================] - 1687s 3s/step - total_loss: 153.9007 - reconstruction_loss: 1.7938 - vq_loss: 149.4988 - disc_loss: 1.5783e-04 - val_total_loss: 138.4939 - val_reconstruction_loss: 1.7752 - val_vq_loss: 136.6796 - val_disc_loss: 1.3622
# Epoch 107/10000
# 567/567 [==============================] - 1693s 3s/step - total_loss: 156.0396 - reconstruction_loss: 1.8028 - vq_loss: 151.3855 - disc_loss: 1.1305e-04 - val_total_loss: 132.1634 - val_reconstruction_loss: 1.8057 - val_vq_loss: 130.1981 - val_disc_loss: 1.1168
# Epoch 108/10000
# 567/567 [==============================] - 1686s 3s/step - total_loss: 151.3024 - reconstruction_loss: 1.8044 - vq_loss: 146.9365 - disc_loss: 0.0000e+00 - val_total_loss: 160.0046 - val_reconstruction_loss: 1.8302 - val_vq_loss: 157.6759 - val_disc_loss: 1.1041
# Epoch 109/10000
# 567/567 [==============================] - 1683s 3s/step - total_loss: 147.8513 - reconstruction_loss: 1.7922 - vq_loss: 143.6437 - disc_loss: 0.0000e+00 - val_total_loss: 136.2665 - val_reconstruction_loss: 1.7871 - val_vq_loss: 134.1234 - val_disc_loss: 1.0911
# Epoch 110/10000
# 329/567 [================>.............] - ETA: 11:05 - total_loss: 150.7247 - reconstruction_loss: 1.7953 - vq_loss: 145.9958 - disc_loss: 1.0990e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-818d7e9bf0da> in <module>
# ----> 1 history = vqgan.fit(train_ds, initial_epoch=1, validation_data=validation_ds, epochs=n_epochs, callbacks=callbacks)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
with strategy.scope():
    x = train_sample_data[0]
    generated = vqgan(x[:10])[0]

# %%
quant, indices, _ = vqgan.encode(x[:10])

# %%
with strategy.scope():
    quant = vqgan.quantize.get_codebook_entry(
            [list(range(0, 128))], shape=(1, 8, 16, 128)
    )

    decoded = vqgan.decode(quant)

# %%
from ganime.model.vqgan_clean.discriminator.model import NLayerDiscriminator
with strategy.scope():
    discriminator = NLayerDiscriminator()

# %%
with strategy.scope():
    vqgan.discriminator = discriminator

# %%
model_input = tf.keras.layers.Input((256, 512, 6))
model = tf.keras.Model(inputs=[model_input], outputs=vqgan.discriminator.call(model_input))
model.summary()

# %%
disc_out = vqgan.discriminator(tf.concat([tf.ones((8, 256, 512, 3)), tf.image.resize(
            train_sample_data[0], [256, 512], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR
        )], axis=-1), training=False)

# %%
plt.imshow(disc_out[0, ..., -1], vmin=-20, vmax=20, cmap='RdBu_r')
plt.colorbar()

# %%
lengths = [789, 799, 814, 816 , 819 ,825 ,794 ,766 ,760 ,747,752 ,787 ,742 ,795 ,752 ,774 ,789, 
 770 ,786 ,770 ,813 ,805 ,802 ,787 ,744 ,800 ,890 ,732 ,830 ,762 ,667 ,751, 821 , 1541 ,
 784 ,801 ,788 ,768 ,768 ,787 ,726 ,705 ,647, 1102]

# %%
len(lengths)

# %%
sum(lengths)
